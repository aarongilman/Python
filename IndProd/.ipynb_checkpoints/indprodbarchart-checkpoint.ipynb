# %% [markdown]
# # Industrial Production Bar Chart

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import pandas_datareader.data as webdata

# %%
# Find names here: 
# https://research.stlouisfed.org/fred2/release/tables?rid=13&eid=49745

frednames = "INDPRO", "IPG3361T3S", "IPG325S", "IPG333S", \
            "IPG332S", "IPG311A2S", "IPG3364T9S", \
            "IPG334S", "IPMINE", "IPUTIL"
        
fdata = webdata.DataReader(frednames, "fred", 2014);

# %%
fdata[]
# Out:
#               INDPRO  IPG3361T3S  IPG325S  IPG333S   IPG332S  IPG311A2S  \
# DATE
# 2014-01-01  102.4621    105.6275  94.1400  93.9176  102.3430   100.7283
# 2014-02-01  103.2919    113.8893  94.1024  94.7688  103.8168   101.4951
# 2014-03-01  104.0896    113.8118  95.0838  95.6517  103.7205   101.5701
# 2014-04-01  104.2409    113.4577  95.0460  94.9704  103.7858   102.0919
# 2014-05-01  104.6541    115.3119  94.6675  95.7513  104.1817   101.4911
# 2014-06-01  105.1223    116.2292  95.4935  95.7553  104.9017   101.1762
# 2014-07-01  105.2073    120.8644  96.3318  96.2053  104.7902   100.3910
# 2014-08-01  105.1989    117.0991  96.8092  95.7936  103.7452   100.3291
# 2014-09-01  105.5750    115.4943  96.8511  95.2029  104.7366   100.7232
# 2014-10-01  105.6441    114.8966  96.5366  97.5589  104.6381   100.9708
# 2014-11-01  106.6868    121.0213  97.1967  98.2779  104.6256   102.1571
# 2014-12-01  106.5182    120.1839  97.5504  96.3668  104.5880   101.8913
# ...
