# %%
import pandas as pd

# %%
df = pd.read_table('https://download.bls.gov/pub/time.series/nb/nb.series')

# %%
df.keys()
# Out:
# Index([u'series_id', u'seasonal', u'ownership_code', u'estimate_code',
#        u'industry_code', u'occupation_code', u'subcell_code', u'datatype_code',
#        u'provision_code', u'survey_code', u'footnote_codes', u'begin_year',
#        u'begin_period', u'end_year', u'end_period'],
#       dtype='object')

# %%
df1 = df[(df['ownership_code'] == 1)
         & (df['provision_code'] == '088')]

# %%
##series = df1['series_id'].str.replace(' ', '').values[0]

# %%
df1
# Out:
#                            series_id seasonal  ownership_code  estimate_code  \
# 2915  NBU10700000000000020088               U               1              7
# 2948  NBU10700000000000120088               U               1              7
# 2981  NBU10700000000000220088               U               1              7
# 3014  NBU10700000000000420088               U               1              7
# 3045  NBU10700000000000520088               U               1              7
# 3078  NBU10700000000000620088               U               1              7
# 3111  NBU10700000000000720088               U               1              7
# 3144  NBU10700000000000820088               U               1              7
# 3149  NBU10700000000000920088               U               1              7
# 3154  NBU10700000000001020088               U               1              7
# 3159  NBU10700000000001120088               U               1              7
# ...

# %%
df = pd.read_table('https://download.bls.gov/pub/time.series/nb/nb.data.1.AllData')

# %%
df[df['series_id'].isin(df1['series_id'])].set_index(['series_id', 'year'])
# Out:
#                                     period         value footnote_codes
# series_id                      year
# NBU10700000000000020088        2010    A01         69.00
#                                2011    A01         69.00
#                                2012    A01         71.00
#                                2013    A01         72.00
#                                2014    A01         73.00
#                                2015    A01         73.00
#                                2016    A01         73.00
# NBU10700000000000120088        2010    A01         68.00
#                                2011    A01         67.00
#                                2012    A01         69.00
#                                2013    A01         70.00
#                                2014    A01         71.00
#                                2015    A01         71.00
#                                2016    A01         75.00
# NBU10700000000000220088        2010    A01         67.00
# ...

# %%
series
# Out:
# 'NBU10700000000002620088'

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

fgreen = 9,146,65


fig = plt.figure(figsize=(8,4.5))
ax = fig.add_subplot(111)
rect = matplotlib.patches.Rectangle((15,0), 12, 10, fc=(0,78/255,56/255,(19-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((15,10), 12, 15, fc=(0,78/255,56/255,(32-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((15,25), 12, 25, fc=(0,78/255,56/255,(66-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((15,50), 12, 25, fc=(0,78/255,56/255,(75-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((15,75), 12, 15, fc=(0,78/255,56/255,(84-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((15,90), 12, 10, fc=(0,78/255,56/255,(86-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((36,0), 12, 10, fc=(0,78/255,56/255,(31-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((36,10), 12, 15, fc=(0,78/255,56/255,(47-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((36,25), 12, 25, fc=(0,78/255,56/255,(77-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((36,50), 12, 25, fc=(0,78/255,56/255,(86-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((36,75), 12, 15, fc=(0,78/255,56/255,(92-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((36,90), 12, 10, fc=(0,78/255,56/255,(93-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
ax.axis('off')

ax.text(14, 5, 'Bottom 10%', fontsize=10, va='center', ha='right', weight='bold')
ax.text(14, 17.5, 'Bottom 25%', fontsize=10, va='center', ha='right', weight='bold')
ax.text(14, 37.5, '25 to 50%', fontsize=10, va='center', ha='right')
ax.text(14, 62.5, '50 to 75%', fontsize=10, va='center', ha='right')
ax.text(14, 82.5, 'Top 25%', fontsize=10, va='center', ha='right')
ax.text(14, 95, 'Top 10% of wages', fontsize=10, va='center', ha='right')

ax.text(27.5, 5, '19', fontsize=9, va='center', ha='left', weight='bold')
ax.text(27.5, 17.5, '32%', fontsize=9, va='center', ha='left', weight='bold')
ax.text(27.5, 37.5, '66', fontsize=9, va='center', ha='left')
ax.text(27.5, 62.5, '75', fontsize=9, va='center', ha='left')
ax.text(27.5, 82.5, '84', fontsize=9, va='center', ha='left')
ax.text(27.5, 95, '86%', fontsize=9, va='center', ha='left')

ax.text(48.5, 5, '31', fontsize=9, va='center', ha='left', weight='bold')
ax.text(48.5, 17.5, '47', fontsize=9, va='center', ha='left', weight='bold')
ax.text(48.5, 37.5, '77', fontsize=9, va='center', ha='left')
ax.text(48.5, 62.5, '86', fontsize=9, va='center', ha='left')
ax.text(48.5, 82.5, '92', fontsize=9, va='center', ha='left')
ax.text(48.5, 95, '93%', fontsize=9, va='center', ha='left')

ax.text(21, 104, '2010', fontsize=9, va='center', ha='center')
ax.text(42, 104, '2018', fontsize=9, va='center', ha='center')

ax.text(32, 112, 'Paid sick leave', fontsize=12, va='center', ha='center', weight='bold')

rect = matplotlib.patches.Rectangle((63,0), 12, 10, fc=(0,78/255,56/255,(39-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((63,10), 12, 15, fc=(0,78/255,56/255,(53-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((63,25), 12, 25, fc=(0,78/255,56/255,(84-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((63,50), 12, 25, fc=(0,78/255,56/255,(89-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((63,75), 12, 15, fc=(0,78/255,56/255,(89-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((63,90), 12, 10, fc=(0,78/255,56/255,(89-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((84,0), 12, 10, fc=(0,78/255,56/255,(41-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((84,10), 12, 15, fc=(0,78/255,56/255,(52-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((84,25), 12, 25, fc=(0,78/255,56/255,(83-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((84,50), 12, 25, fc=(0,78/255,56/255,(90-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((84,75), 12, 15, fc=(0,78/255,56/255,(91-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((84,90), 12, 10, fc=(0,78/255,56/255,(92-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
ax.axis('off')

ax.text(75.5, 5, '39', fontsize=9, va='center', ha='left')
ax.text(75.5, 17.5, '53', fontsize=9, va='center', ha='left')
ax.text(75.5, 37.5, '84', fontsize=9, va='center', ha='left')
ax.text(75.5, 62.5, '89', fontsize=9, va='center', ha='left')
ax.text(75.5, 82.5, '89', fontsize=9, va='center', ha='left')
ax.text(75.5, 95, '89%', fontsize=9, va='center', ha='left')

ax.text(96.5, 5, '41', fontsize=9, va='center', ha='left')
ax.text(96.5, 17.5, '52', fontsize=9, va='center', ha='left')
ax.text(96.5, 37.5, '83', fontsize=9, va='center', ha='left')
ax.text(96.5, 62.5, '90', fontsize=9, va='center', ha='left')
ax.text(96.5, 82.5, '91', fontsize=9, va='center', ha='left')
ax.text(96.5, 95, '92%', fontsize=9, va='center', ha='left')

ax.text(69, 104, '2010', fontsize=9, va='center', ha='center')
ax.text(90, 104, '2018', fontsize=9, va='center', ha='center')

ax.text(80, 112, 'Paid vacation', fontsize=12, va='center', ha='center')



rect = matplotlib.patches.Rectangle((113,0), 12, 10, fc=(0,78/255,56/255,(23-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((113,10), 12, 15, fc=(0,78/255,56/255,(38-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((113,25), 12, 25, fc=(0,78/255,56/255,(76-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((113,50), 12, 25, fc=(0,78/255,56/255,(86-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((113,75), 12, 15, fc=(0,78/255,56/255,(90-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((113,90), 12, 10, fc=(0,78/255,56/255,(92-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((134,0), 12, 10, fc=(0,78/255,56/255,(24-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((134,10), 12, 15, fc=(0,78/255,56/255,(35-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((134,25), 12, 25, fc=(0,78/255,56/255,(72-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((134,50), 12, 25, fc=(0,78/255,56/255,(86-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((134,75), 12, 15, fc=(0,78/255,56/255,(92-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
rect = matplotlib.patches.Rectangle((134,90), 12, 10, fc=(0,78/255,56/255,(93-13)/80), ec=(1,1,1,1), lw=4)
ax.add_patch(rect)
ax.axis('off')

ax.text(125.5, 5, '23', fontsize=9, va='center', ha='left')
ax.text(125.5, 17.5, '38', fontsize=9, va='center', ha='left')
ax.text(125.5, 37.5, '76', fontsize=9, va='center', ha='left')
ax.text(125.5, 62.5, '86', fontsize=9, va='center', ha='left')
ax.text(125.5, 82.5, '90', fontsize=9, va='center', ha='left')
ax.text(125.5, 95, '92%', fontsize=9, va='center', ha='left')

ax.text(145.5, 5, '24', fontsize=9, va='center', ha='left')
ax.text(145.5, 17.5, '35', fontsize=9, va='center', ha='left')
ax.text(145.5, 37.5, '72', fontsize=9, va='center', ha='left')
ax.text(145.5, 62.5, '86', fontsize=9, va='center', ha='left')
ax.text(145.5, 82.5, '92', fontsize=9, va='center', ha='left')
ax.text(145.5, 95, '93%', fontsize=9, va='center', ha='left')

ax.text(119, 104, '2010', fontsize=9, va='center', ha='center')
ax.text(140, 104, '2018', fontsize=9, va='center', ha='center')

ax.text(130, 112, 'Medical benefits', fontsize=12, va='center', ha='center')


rect = matplotlib.patches.Rectangle((-14,0), 70, 25, fc=(1,1,1,0), ec=(0,0,0,0.3), lw=2)
ax.add_patch(rect)

ax.text(-25, -8, 'Source: Bureau of Labor Statistics, Employee Benefits in the United States, March 2010 and March 2018', fontsize=9, va='center', ha='left')

ax.text(-25, 130, 'Employee access to benefits, 2010 and 2018', fontsize=16, va='center', ha='left', weight='bold')
ax.text(-22, 123, 'share of private industry workers with access to benefit, by wage group', fontsize=10, va='center', ha='left', style='italic')
plt.xlim([-15, 150])
plt.ylim([-1, 100])


plt.savefig('emp_psd.png', bbox_inches='tight', dpi=500)
plt.show()
