# %% [markdown]
# ### Example of reading CPS state files in pandas

# %%
import pandas as pd

# %%
df = pd.read_stata('cepr_org_2016.dta', convert_categoricals=False)

# %%
list(df.columns.values)
# Out:
# ['year',
#  'month',
#  'minsamp',
#  'hhid',
#  'hhid2',
#  'hrsample',
#  'hrsersuf',
#  'hhnum',
#  'hrlonglk',
#  'lineno',
#  'fnlwgt',
#  'orgwgt',
#  'lonwgt',
#  'famwgt',
#  'age',
#  'female',
#  'wbho',
#  'wbhao',
#  'wbhom',
#  'wbhaom',
#  'racehpia',
#  'racehpi',
#  'forborn',
#  'citizen',
#  'prcitshp',
#  'arrived',
#  'prinusyr',
#  'penatvty',
#  'pemntvty',
#  'pefntvty',
#  'vet',
#  'married',
#  'marstat',
#  'ownchild',
#  'ch02',
#  'ch05',
#  'ch35',
#  'ch613',
#  'ch1417',
#  'famrel84',
#  'famrel94',
#  'famrel',
#  'relahh',
#  'hoh79',
#  'refper',
#  'faminc',
#  'lfstat',
#  'empl',
#  'unem',
#  'nilf',
#  'selfemp',
#  'selfinc',
#  'pubsect',
#  'pubfed',
#  'pubst',
#  'publoc',
#  'cow1',
#  'cow2',
#  'unemdur',
#  'jobloser',
#  'jobleaver',
#  'entrant',
#  'unmem',
#  'uncov',
#  'union',
#  'schenrl',
#  'schhs',
#  'schcol',
#  'schft',
#  'schpt',
#  'multjob',
#  'multjobn',
#  'pdemp1',
#  'pdemp2',
#  'nmemp1',
#  'nmemp2',
# ...

# %%
sr = pd.io.stata.StataReader('cepr_org_2016.dta')
vl = sr.variable_labels()
sr.close()

# %%
vl
# Out:
# {u'abpaid': u'Paid for time off last week',
#  u'absent79': u'Why absent last week',
#  u'absent94': u'Why absent last week',
#  u'age': u'Age',
#  u'agric': u'Agriculture',
#  u'arrived': u'Year entered US',
#  u'blsimph': u'BLS allocated hourly earnings',
#  u'blsimpt': u'BLS allocated weekly hours',
#  u'blsimpw': u'BLS allocated weekly earnings',
#  u'cbsasz': u'CBSA Size',
#  u'centcity': u'Central city',
#  u'ch02': u'Child 0-2',
#  u'ch05': u'Child 0-5',
#  u'ch1417': u'Child 14-17',
#  u'ch35': u'Child 3-5',
#  u'ch613': u'Child 6-13',
#  u'citizen': u'US citizen',
#  u'cmsacode05': u'CSA Code',
#  u'cmsacode14': u'CSA Code',
#  u'cow1': u'Class of Worker, 1st job',
#  u'cow2': u'Class of Worker, 2nd job',
#  u'docc03': u'2-digit occupation',
#  u'docc70': u'2-digit occupation',
#  u'docc80': u'2-digit occupation',
#  u'earnwke': u'Weekly pay',
#  u'educ': u'Education level',
#  u'educ92': u'Education level, post-1991',
#  u'empl': u'Employed',
#  u'entrant': u'Entrant',
# ...
