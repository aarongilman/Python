# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    y=['Democrat', 'Republican'],
    x=[2.11, 40.18],
    hoverinfo = 'text',
    name='Total',
    text=['All other:<br>2.1 million','Republican total:<br>40.2 million'],
    orientation = 'h',
    marker = dict(
        color = ['rgba(25, 25, 112, 1.0)','rgba(176, 23, 31, 1.0)'],
        line = dict(
            color = 'rgba(72, 118, 255, 1.0)',
            width = 0)
    )
)
trace2 = go.Bar(
    y=['Democrat', 'Republican'],
    x=[8.6],
    hoverinfo = 'text',
    name='North Carolina',
    text=['North Carolina total:<br>8.6 million'],
    orientation = 'h',
    marker = dict(
        color = 'rgba(176, 226, 255, 1.0)',
        line = dict(
            color = 'rgba(58, 71, 80, 1.0)',
            width = 0)
    )
)

data = [trace1, trace2]
layout = {
  "annotations": [
    {
      "x": -0.18746031746, 
      "y": 1.28490338164, 
      "align": "left", 
      "font": {
        "family": "Balto", 
        "size": 15
      }, 
      "showarrow": False, 
      "text": "<b>People with one health insurance issuer by state governor political party</b><br>   <i>(Millions of people)</i>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.18, 
      "y": -0.263888888889, 
      "font": {
        "family": "Balto", 
        "size": 12
      }, 
      "showarrow": False, 
      "text": "Data sources: &nbsp;healthcare.gov and state exchanges, Census Bureau, National Governors Association", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 6.29721637427, 
      "y": 0.02, 
      "showarrow": False, 
      "text": "North<br>Carolina", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 0.894109516215, 
      "y": 0.27, 
      "arrowhead": 2, 
      "ax": 21, 
      "ay": -22, 
      "showarrow": True, 
      "text": "All others", 
      "xref": "x", 
      "yref": "y"
    }
  ], 
  "autosize": False, 
  "bargap": 0.5, 
  "bargroupgap": 0, 
  "barmode": "stack", 
  "height": 350, 
  "legend": {
    "x": 0.278215962441, 
    "y": 0.452777777778
  }, 
  "margin": {
    "r": 50, 
    "t": 80, 
    "b": 90, 
    "l": 90
  }, 
  "showlegend": False, 
  "title": "", 
  "width": 550, 
  "xaxis": {
    "autorange": True, 
    "range": [-0.191918706294, 42.3048378266], 
    "title": "", 
    "type": "linear", 
    "zerolinecolor": "rgb(127, 127, 127)"
  }, 
  "yaxis": {
    "autorange": False, 
    "range": [-0.4, 1.4], 
    "tickfont": {"size": 14}, 
    "ticksuffix": "  ", 
    "title": "", 
    "type": "category"
  }
}

fig = go.Figure(data=data, layout=layout)
py.plot(fig, filename='one_issuer_no')
# Out:
# u'https://plot.ly/~bdew/56'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    y=['Democrat', 'Republican'],
    x=[1.8, 20.7],
    hoverinfo = 'text',
    name='Total',
    text=['Democrat (ex-North Carolina):<br>1.8%','Republican:<br>20.7%'],
    orientation = 'h',
    marker = dict(
        color = ['rgba(25, 25, 112, 1.0)','rgba(176, 23, 31, 1.0)'],
        line = dict(
            color = 'rgba(72, 118, 255, 1.0)',
            width = 0)
    )
)

data = [trace1]
layout = {
  "annotations": [
    {
      "x": -0.18746031746, 
      "y": 1.28490338164, 
      "align": "left", 
      "font": {
        "family": "Balto", 
        "size": 15
      }, 
      "showarrow": False, 
      "text": "<b>Share of constituents with one health insurance issuer</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.18, 
      "y": -0.263888888889, 
      "font": {
        "family": "Balto", 
        "size": 12
      }, 
      "showarrow": False, 
      "text": "Data sources: &nbsp;healthcare.gov and state exchanges, Census Bureau, National Governors Association", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 21.9218633576, 
      "y": 0.99, 
      "showarrow": False, 
      "text": "20.7%", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 2.75418653804, 
      "y": 5.55111512313e-17, 
      "arrowhead": 2, 
      "ax": 21, 
      "ay": -22, 
      "showarrow": False, 
      "text": "1.8%", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": -0.170731707317, 
      "y": 1.16944444444, 
      "font": {
        "family": "Balto", 
        "size": 13
      }, 
      "showarrow": False, 
      "text": "(<i>By state governor political party, percent of total population, not including North Carolina</i>)", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "bargap": 0.5, 
  "height": 350, 
  "legend": {
    "x": 0.278215962441, 
    "y": 0.452777777778
  }, 
  "margin": {
    "r": 50, 
    "t": 80, 
    "b": 90, 
    "l": 90
  }, 
  "showlegend": False, 
  "title": "", 
  "width": 550, 
  "xaxis": {
    "autorange": True, 
    "range": [0, 23.0460614785], 
    "title": "", 
    "type": "linear", 
    "zerolinecolor": "rgb(127, 127, 127)"
  }, 
  "yaxis": {
    "autorange": False, 
    "range": [-0.4, 1.4], 
    "tickfont": {"size": 14}, 
    "ticksuffix": "  ", 
    "title": "", 
    "type": "category"
  }
}

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='one_issuer_pct')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bdew/58.embed" height="350px" width="550px"></iframe>
