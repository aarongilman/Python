# %% [markdown]
# ## U.S. Unemployment Rate Change by Metropolitan Statistical Area (MSA)

# %% [markdown]
# Created by Brian Dew (brianwdew@gmail.com), March 27, 2017.
#
# The goal of this notebook is to create a U.S. map that shows how unemployment rates are changing by city. '
#
# See https://www.bls.gov/lau/ for advance release information.
#
# https://download.bls.gov/pub/time.series/la/la.areamaps (list of codes of all local areas)
#
# http://gis.stackexchange.com/questions/198530/plotting-us-cities-on-a-map-with-matplotlib-and-basemap
#
# http://stackoverflow.com/questions/39742305/how-to-use-basemap-python-to-plot-us-with-50-states
#
# This folder on GitHub (https://github.com/bdecon/Python/Unemp_Map) contains four files needed to make the code work:
# 1. MSA.csv - contains the names, codes, and locations for metropolitan statistical areas
# 2. st99_d00.dbf - one of the files used for drawing state shapes
# 3. st99_d00.shp - main state shapefile
# 4. st99_d00.shx - final file for drawing state shapes

# %% [markdown]
# ### Obtaining the city locations and their unemployment rate change values
#
# First, we load the pandas and matplotlib libraries that will allow us to work with data and map it. The second step is to load both the data that do not change (city names, codes, and locations) and the data that do change (BLS unemployment rate estimates). The third step is to combine the two datasets.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from mpl_toolkits.basemap import Basemap as Basemap
# Settings for the map
m = Basemap(llcrnrlon=-121, llcrnrlat=20, urcrnrlon=-64, urcrnrlat=49,
            projection='lcc', lat_1=33, lat_2=45, lon_0=-95)

# %%
# CSV file contains city names, their BLS codes (Metropolitan 
# MTAs/NECTAs only), and their latitude and longitude
MSA = pd.read_csv('MSA.csv')

# BLS flat file contains the unemployment rate by month since 2015
url = 'https://download.bls.gov/pub/time.series/la/la.data.0.CurrentU15-19'
df = pd.read_table(url, sep='\s+')

# %%
MSA
# Out:
#                 fullname              fullcode   latitude   longitude  \
# 0         Bridgeport, CT  LAUMT097195000000003  41.167041  -73.204835
# 1            Danbury, CT  LAUMT097285000000003  41.394817  -73.454011
# 2           Hartford, CT  LAUMT097345000000003  41.763494  -72.683052
# 3          New Haven, CT  LAUMT097570000000003  41.308214  -72.925052
# 4            Norwich, CT  LAUMT097645000000003  41.524265  -72.075910
# 5          Waterbury, CT  LAUMT097870000000003  41.558152  -73.051496
# 6             Bangor, ME  LAUMT237075000000003  44.801182  -68.777814
# 7           Lewiston, ME  LAUMT237465000000003  44.100351  -70.214776
# 8           Portland, ME  LAUMT237675000000003  43.661028  -70.254859
# 9    Barnstable Town, MA  LAUMT257090000000003  41.652944  -70.282992
# 10            Boston, MA  LAUMT257165000000003  42.360482  -71.059568
# 11        Leominster, MA  LAUMT257450000000003  42.525091  -71.759794
# 12       New Bedford, MA  LAUMT257555000000003  41.636215  -70.934205
# 13        Pittsfield, MA  LAUMT257660000000003  42.450097  -73.245378
# 14       Springfield, MA  LAUMT257810000000003  42.101483  -72.589811
# 15         Worcester, MA  LAUMT257960000000003  42.262593  -71.802293
# 16             Dover, NH  LAUMT337305000000003  43.197862  -70.873670
# 17        Manchester, NH  LAUMT337495000000003  42.995640  -71.454789
# 18        Portsmouth, NH  LAUMT337690000000003  43.071755  -70.762553
# 19        Providence, RI  LAUMT447720000000003  41.823989  -71.412834
# 20        Burlington, VT  LAUMT507240000000003  44.472399  -73.211494
# 21           Abilene, TX  LAUMT481018000000003  32.446453  -99.733348
# 22             Akron, OH  LAUMT391042000000003  41.083064  -81.518485
# 23            Albany, GA  LAUMT131050000000003  31.578206  -84.155681
# 24            Albany, OR  LAUMT411054000000003  44.636507 -123.105932
# 25            Albany, NY  LAUMT361058000000003  42.651167  -73.754968
# 26       Albuquerque, NM  LAUMT351074000000003  35.084103 -106.650985
# 27        Alexandria, LA  LAUMT221078000000003  31.199004  -92.445137
# 28         Allentown, PA  LAUMT421090000000003  40.602206  -75.471279
# 29           Altoona, PA  LAUMT421102000000003  40.518681  -78.394736
# ..                   ...                   ...        ...         ...
# 361            Tyler, TX  LAUMT484634000000003  32.351260  -95.301062
# 362   Urban Honolulu, HI  LAUMT154652000000003  21.325852 -157.845315
# 363            Utica, NY  LAUMT364654000000003  43.100903  -75.232664
# 364         Valdosta, GA  LAUMT134666000000003  30.832702  -83.278485
# 365          Vallejo, CA  LAUMT064670000000003  38.104086 -122.256637
# 366         Victoria, TX  LAUMT484702000000003  28.805267  -97.003598
# 367         Vineland, NJ  LAUMT344722000000003  39.473152  -75.002026
# 368   Virginia Beach, VA  LAUMT514726000000003  36.852984  -75.977418
# 369          Visalia, CA  LAUMT064730000000003  36.330228 -119.292058
# 370             Waco, TX  LAUMT484738000000003  31.549333  -97.146669
# 371      Walla Walla, WA  LAUMT534746000000003  46.065000 -118.330278
# 372    Warner Robins, GA  LAUMT134758000000003  32.598313  -83.625677
# 373       Washington, DC  LAUMT114790000000003  38.894955  -77.036645
# 374         Waterloo, IA  LAUMT194794000000003  42.498286  -92.336869
# 375        Watertown, NY  LAUMT364806000000003  43.974784  -75.910756
# 376           Wausau, WI  LAUMT554814000000003  44.959602  -89.629824
# 377          Weirton, WV  LAUMT394826000000003  40.418957  -80.589517
# 378        Wenatchee, WA  LAUMT534830000000003  47.423460 -120.310349
# 379         Wheeling, WV  LAUMT544854000000003  40.063962  -80.720915
# 380          Wichita, KS  LAUMT204862000000003  37.692236  -97.337545
# 381    Wichita Falls, TX  LAUMT484866000000003  33.913709  -98.493387
# 382     Williamsport, PA  LAUMT424870000000003  41.249329  -77.002767
# 383       Wilmington, NC  LAUMT374890000000003  34.225728  -77.944711
# 384       Winchester, VA  LAUMT514902000000003  39.185218  -78.165240
# 385    Winston-Salem, NC  LAUMT374918000000003  36.099813  -80.244052
# 386           Yakima, WA  LAUMT534942000000003  46.601557 -120.510842
# 387             York, PA  LAUMT424962000000003  39.962398  -76.727392
# 388       Youngstown, OH  LAUMT394966000000003  41.099780  -80.649519
# 389        Yuba City, CA  LAUMT064970000000003  39.140448 -121.616911
# 390             Yuma, AZ  LAUMT044974000000003  32.665135 -114.476031
#
#                                              area_code
# 0    Bridgeport-Stamford-Norwalk, CT Metropolitan N...
# 1                       Danbury, CT Metropolitan NECTA
# 2    Hartford-West Hartford-East Hartford, CT Metro...
# 3                     New Haven, CT Metropolitan NECTA
# 4    Norwich-New London-Westerly, CT-RI Metropolita...
# 5                     Waterbury, CT Metropolitan NECTA
# 6                        Bangor, ME Metropolitan NECTA
# 7               Lewiston-Auburn, ME Metropolitan NECTA
# 8       Portland-South Portland, ME Metropolitan NECTA
# 9               Barnstable Town, MA Metropolitan NECTA
# 10   Boston-Cambridge-Nashua, MA-NH Metropolitan NECTA
# 11           Leominster-Gardner, MA Metropolitan NECTA
# 12                  New Bedford, MA Metropolitan NECTA
# 13                   Pittsfield, MA Metropolitan NECTA
# 14               Springfield, MA-CT Metropolitan NECTA
# 15                 Worcester, MA-CT Metropolitan NECTA
# 16              Dover-Durham, NH-ME Metropolitan NECTA
# 17                   Manchester, NH Metropolitan NECTA
# 18                Portsmouth, NH-ME Metropolitan NECTA
# 19        Providence-Warwick, RI-MA Metropolitan NECTA
# 20   Burlington-South Burlington, VT Metropolitan N...
# 21           Abilene, TX Metropolitan Statistical Area
# 22             Akron, OH Metropolitan Statistical Area
# 23            Albany, GA Metropolitan Statistical Area
# 24            Albany, OR Metropolitan Statistical Area
# 25   Albany-Schenectady-Troy, NY Metropolitan Stati...
# 26       Albuquerque, NM Metropolitan Statistical Area
# 27        Alexandria, LA Metropolitan Statistical Area
# 28   Allentown-Bethlehem-Easton, PA-NJ Metropolitan...
# 29           Altoona, PA Metropolitan Statistical Area
# ..                                                 ...
# 361            Tyler, TX Metropolitan Statistical Area
# 362   Urban Honolulu, HI Metropolitan Statistical Area
# 363       Utica-Rome, NY Metropolitan Statistical Area
# 364         Valdosta, GA Metropolitan Statistical Area
# 365  Vallejo-Fairfield, CA Metropolitan Statistical...
# 366         Victoria, TX Metropolitan Statistical Area
# 367  Vineland-Bridgeton, NJ Metropolitan Statistica...
# 368  Virginia Beach-Norfolk-Newport News, VA-NC Met...
# 369  Visalia-Porterville, CA Metropolitan Statistic...
# 370             Waco, TX Metropolitan Statistical Area
# 371      Walla Walla, WA Metropolitan Statistical Area
# 372    Warner Robins, GA Metropolitan Statistical Area
# 373  Washington-Arlington-Alexandria, DC-VA-MD-WV M...
# 374  Waterloo-Cedar Falls, IA Metropolitan Statisti...
# 375  Watertown-Fort Drum, NY Metropolitan Statistic...
# 376           Wausau, WI Metropolitan Statistical Area
# 377  Weirton-Steubenville, WV-OH Metropolitan Stati...
# 378        Wenatchee, WA Metropolitan Statistical Area
# 379      Wheeling, WV-OH Metropolitan Statistical Area
# 380          Wichita, KS Metropolitan Statistical Area
# 381    Wichita Falls, TX Metropolitan Statistical Area
# 382     Williamsport, PA Metropolitan Statistical Area
# 383       Wilmington, NC Metropolitan Statistical Area
# 384    Winchester, VA-WV Metropolitan Statistical Area
# 385    Winston-Salem, NC Metropolitan Statistical Area
# 386           Yakima, WA Metropolitan Statistical Area
# 387     York-Hanover, PA Metropolitan Statistical Area
# 388  Youngstown-Warren-Boardman, OH-PA Metropolitan...
# 389        Yuba City, CA Metropolitan Statistical Area
# 390             Yuma, AZ Metropolitan Statistical Area
#
# [391 rows x 5 columns]

# %%
# Take only the unemployment data for MSAs and monthly series 
# (M13 is annual average)
df = pd.DataFrame(df[df['series_id'].isin(MSA['fullcode']) 
                 & ~df['period'].isin(['M13'])])

# Clean up the date to convert it to pandas datetime
df.loc[:,'month'] = df['period'].replace(regex=True, 
                                         to_replace=r'M', 
                                         value=r'')
df.loc[:,'day'] = 1
df.loc[:,'date'] = pd.to_datetime(df[['year', 'month', 'day']])
df = df.set_index(['series_id','date'])

# Calculate one year change in unemployment rate for each MSA
df.loc[:,'value_ch'] = df['value'].diff(periods=12)
#df = df.dropna()

# Keep only the latest value for each MSA
df = df.reset_index().groupby(['series_id']).tail(1)
df.rename(columns={'series_id':'fullcode'}, inplace=True)

# Take the date for use in chart title
date = df['date'].iloc[0].strftime('%B %Y')

# Combine the two datasets and show 2 rows to verify 
unemp_list = df.merge(MSA, on='fullcode')

# %%
# From the change in unemployment rate, mark increases red, decreases green,
#   no change is gray. The size of the circle to draw is the absolute value 
#   of the change times 8. Alaska and Hawaii are shifted (Alaska is also 
#   scaled down) and locations are otherwise mapped.

for index, row in unemp_list.iterrows():
    x, y = m(row['longitude'],row['latitude'])
    if row['value_ch'] > 0:
        unemp_list.loc[index,'color'] = 'Red'
        unemp_list.loc[index,'size'] = abs(row['value_ch'])*8
    if row['value_ch'] < 0:
        unemp_list.loc[index,'color'] = 'Limegreen'
        unemp_list.loc[index,'size'] = abs(row['value_ch'])*8
    if row['value_ch'] == 0:
        unemp_list.loc[index,'color'] = 'Lightgray'
        unemp_list.loc[index,'size'] = 0.5   # Just to mark location
    if row['fullname'][-2:] == 'AK':
        unemp_list.loc[index,'x'] = 0.35 * x + 1100000
        unemp_list.loc[index,'y'] = 0.35 * y - 1300000
    elif row['fullname'][-2:] == 'HI':
        unemp_list.loc[index,'x'] = x + 5200000
        unemp_list.loc[index,'y'] = y - 1400000
    else:
        unemp_list.loc[index,'x'] = x
        unemp_list.loc[index,'y'] = y

# %% [markdown]
# ### Mapping the values
#
# The second part involves mapping the data. There are three map/shape files located in the same folder as the ipynb, which are read by the basemap package as U.S. states. To include Alaska and Hawaii, the values for these two states are transformed. Alaska is scaled down to 35 percent of it's actual size and moved, with Hawaii to fit underneath the continental U.S.

# %%
plt.gcf()
fig = plt.figure(figsize=(12,6))

# Read the shapefile contained in the same folder (and the two related files)
m.readshapefile('st99_d00', 'states', drawbounds=True, color='grey')
ax = plt.gca()

# Thanks to stackexchange for this solution to include Alaska and Hawaii
for i, shapedict in enumerate(m.states_info):
    # Translate the noncontiguous states:
    if shapedict['NAME'] in ['Alaska', 'Hawaii']:
        seg = m.states[int(shapedict['SHAPENUM'] - 1)]
        # Only include the 8 main islands of Hawaii 
        if shapedict['NAME'] == 'Hawaii' and float(shapedict['AREA']) > 0.005:
            seg = list(map(lambda (x,y): (x + 5200000, y-1400000), seg))
        # Alaska is large. Rescale it.
        elif shapedict['NAME'] == 'Alaska':
            seg = list(map(lambda (x,y): (0.35*x + 1100000, 0.35*y-1300000), seg))
        poly = Polygon(seg, facecolor='white', edgecolor='gray', linewidth=.5)
        ax.add_patch(poly)

# Plot each location, value, and color as identified in the previous section        
for index, row in unemp_list.iterrows():
    m.plot(row['x'], row['y'], marker='o', color=row['color'], alpha=0.5, 
           markersize = row['size'], markeredgecolor='Black', markeredgewidth=.25)

ax.axis('off')    # Remove default border
plt.title('One-year Change in Unemployment Rate, as of ' + date)
plt.annotate('Data Source: U.S. Bureau of Labor Statistics, Local Area Unemployment Statistics; \n' \
             'Code: https://github.com/bdecon/Python/tree/master/Unemp_Map',
             (0,0), (0, 0), fontsize=9, xycoords='axes fraction', textcoords='offset points', va='top')

# Legend 
l1 = plt.scatter([],[], marker='o',color='Limegreen', alpha=0.5, 
              s = 65, edgecolors='Black', linewidth=.25)
l2 = plt.scatter([],[], marker='o',color='Red', alpha=0.5, 
              s = 65, edgecolors='Black', linewidth=.25)

labels = ["$-$1%", "+1%"]

leg = plt.legend([l1, l2], labels, ncol=1, frameon=False, fontsize=8,
    handlelength=2, loc = 4, borderpad = 1.8,
    handletextpad=1, title='Legend', scatterpoints = 1)
plt.savefig('C:/Working/bdecon.github.io/Dash/unemp_map.png', bbox_inches='tight', dpi=200)
plt.show()
# Out:
# C:\Anaconda2\lib\site-packages\mpl_toolkits\basemap\__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# C:\Anaconda2\lib\site-packages\mpl_toolkits\basemap\__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
# generate html table with data
table = unemp_list[['area_code', 'value', 'value_ch']]
table.columns = ['Metropolitan Area Name', 'Unemp. rate', 'One-year change']
table = table.sort_values('One-year change') 
# Sortable css class allows for js script to sort each column
# https://www.kryogenix.org/code/browser/sorttable/
table.to_html('C:/Working/bdecon.github.io/Dash/unemp_table.html', border=0, 
              index=False, classes='sortable')

# %%
table
# Out:
#                                 Metropolitan Area Name  Unemp. rate  \
# 29         El Centro, CA Metropolitan Statistical Area         19.2
# 219       Ocean City, NJ Metropolitan Statistical Area          9.1
# 57    Grand Junction, CO Metropolitan Statistical Area          3.2
# 133  Michigan City-La Porte, IN Metropolitan Statis...          3.6
# 389           Casper, WY Metropolitan Statistical Area          5.5
# 371          Beckley, WV Metropolitan Statistical Area          5.6
# 136      Terre Haute, IN Metropolitan Statistical Area          3.4
# 124      Bloomington, IN Metropolitan Statistical Area          2.7
# 275      Grants Pass, OR Metropolitan Statistical Area          4.7
# 221  Vineland-Bridgeton, NJ Metropolitan Statistica...          5.7
# 59            Pueblo, CO Metropolitan Statistical Area          3.2
# 134           Muncie, IN Metropolitan Statistical Area          3.2
# 20              Yuma, AZ Metropolitan Statistical Area         16.3
# 131           Kokomo, IN Metropolitan Statistical Area          2.8
# 376      Wheeling, WV-OH Metropolitan Statistical Area          5.6
# 128       Fort Wayne, IN Metropolitan Statistical Area          2.5
# 271           Albany, OR Metropolitan Statistical Area          4.1
# 276          Medford, OR Metropolitan Statistical Area          4.3
# 116  Chicago-Naperville-Elgin, IL-IN-WI Metropolita...          4.2
# 58           Greeley, CO Metropolitan Statistical Area          2.1
# 266  Weirton-Steubenville, WV-OH Metropolitan Stati...          6.4
# 369        Wenatchee, WA Metropolitan Statistical Area          5.3
# 135  South Bend-Mishawaka, IN-MI Metropolitan Stati...          2.8
# 132  Lafayette-West Lafayette, IN Metropolitan Stat...          2.3
# 126   Elkhart-Goshen, IN Metropolitan Statistical Area          1.9
# 336           Odessa, TX Metropolitan Statistical Area          4.9
# 129  Indianapolis-Carmel-Anderson, IN Metropolitan ...          2.5
# 130  Indianapolis-Carmel-Anderson, IN Metropolitan ...          2.5
# 54   Colorado Springs, CO Metropolitan Statistical ...          2.5
# 212      Carson City, NV Metropolitan Statistical Area          5.0
# ..                                                 ...          ...
# 339  Sherman-Denison, TX Metropolitan Statistical Area          3.7
# 332         Longview, TX Metropolitan Statistical Area          5.7
# 327  Dallas-Fort Worth-Arlington, TX Metropolitan S...          3.8
# 320          Abilene, TX Metropolitan Statistical Area          3.8
# 225         Santa Fe, NM Metropolitan Statistical Area          5.0
# 338  San Antonio-New Braunfels, TX Metropolitan Sta...          3.6
# 173                  Pittsfield, MA Metropolitan NECTA          5.0
# 333          Lubbock, TX Metropolitan Statistical Area          3.2
# 330   Killeen-Temple, TX Metropolitan Statistical Area          4.3
# 148    Bowling Green, KY Metropolitan Statistical Area          4.0
# 343             Waco, TX Metropolitan Statistical Area          3.9
# 265           Toledo, OH Metropolitan Statistical Area          4.8
# 321         Amarillo, TX Metropolitan Statistical Area          3.0
# 328          El Paso, TX Metropolitan Statistical Area          4.8
# 152        Owensboro, KY Metropolitan Statistical Area          4.5
# 13         Fairbanks, AK Metropolitan Statistical Area          6.1
# 322  Austin-Round Rock, TX Metropolitan Statistical...          3.2
# 150  Lexington-Fayette, KY Metropolitan Statistical...          3.7
# 66             Dover, DE Metropolitan Statistical Area          4.9
# 12         Anchorage, AK Metropolitan Statistical Area          6.4
# 259  Cleveland-Elyria, OH Metropolitan Statistical ...          5.4
# 153       Alexandria, LA Metropolitan Statistical Area          6.1
# 329  Houston-The Woodlands-Sugar Land, TX Metropoli...          5.3
# 340     Texarkana, TX-AR Metropolitan Statistical Area          4.4
# 122         Rockford, IL Metropolitan Statistical Area          6.9
# 149  Elizabethtown-Fort Knox, KY Metropolitan Stati...          4.7
# 324  Brownsville-Harlingen, TX Metropolitan Statist...          7.5
# 326   Corpus Christi, TX Metropolitan Statistical Area          6.2
# 334  McAllen-Edinburg-Mission, TX Metropolitan Stat...          8.0
# 323  Beaumont-Port Arthur, TX Metropolitan Statisti...          7.4
#
#      One-year change
# 29              -4.2
# 219             -2.7
# 57              -2.7
# 133             -2.4
# 389             -2.3
# 371             -2.1
# 136             -2.1
# 124             -2.1
# 275             -2.1
# 221             -2.1
# 59              -2.0
# 134             -2.0
# 20              -2.0
# 131             -1.9
# 376             -1.8
# 128             -1.8
# 271             -1.7
# 276             -1.7
# 116             -1.7
# 58              -1.7
# 266             -1.7
# 369             -1.6
# 135             -1.6
# 132             -1.6
# 126             -1.6
# 336             -1.6
# 129             -1.6
# 130             -1.6
# 54              -1.5
# 212             -1.5
# ..               ...
# 339              0.1
# 332              0.1
# 327              0.2
# 320              0.2
# 225              0.2
# 338              0.2
# 173              0.2
# 333              0.2
# 330              0.2
# 148              0.2
# 343              0.3
# 265              0.3
# 321              0.3
# 328              0.3
# 152              0.3
# 13               0.3
# 322              0.3
# 150              0.3
# 66               0.3
# 12               0.4
# 259              0.4
# 153              0.5
# 329              0.5
# 340              0.5
# 122              0.6
# 149              0.6
# 324              0.7
# 326              0.7
# 334              0.7
# 323              1.2
#
# [391 rows x 3 columns]
