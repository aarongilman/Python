# %% [markdown]
# ### Mapping Changes to the Unemployment Rate using Plotly
#
# *Brian Dew, Domestic Program Intern, CEPR*<br>
# *June 17, 2017*
#
# Updated February 6, 2018

# %%
# Import libraries and sign in to plotly
import pandas as pd
import config   # File that contains api key
import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in('bdew', config.plotly_key)

# %%
# CSV file contains city names, their BLS codes (Metropolitan 
# MTAs/NECTAs only), and their latitude and longitude
MSA = pd.read_csv('MSA.csv')

# BLS flat file contains the unemployment rate by month since 2015
url = 'https://download.bls.gov/pub/time.series/la/la.data.0.CurrentU15-19'
df = pd.read_table(url, sep='\s+', na_values=['-'])

# %%
# Take only the unemployment data for MSAs and monthly series 
# (M13 is annual average)
df = pd.DataFrame(df[df['series_id'].isin(MSA['fullcode']) 
                 & ~df['period'].isin(['M13'])])

# Clean up the date to convert it to pandas datetime
df.loc[:,'month'] = df['period'].replace(regex=True, 
                                         to_replace=r'M', 
                                         value=r'')
df.loc[:,'day'] = 1
df.loc[:,'date'] = pd.to_datetime(df[['year', 'month', 'day']])
df.loc[:,'value'] = df['value'].astype('float')
df = df.set_index(['series_id','date'])

# %%
df.loc[:,'value_ch'] = df['value'].diff(periods=24)
df = df.reset_index().groupby(['series_id']).tail(1)
df['prevvalue'] = df['value'] - df['value_ch']
#df.sort_values('value_ch')

# %%
df['prevvalue'] = df['value'] - df['value_ch']

# %%
df.sort_values('value_ch')
# Out:
#                   series_id       date  year period  value footnote_codes  \
# 1169   LAUMT062094000000003 2018-03-01  2018    M03   15.3              p
# 12986  LAUMT483622000000003 2018-03-01  2018    M03    3.1              p
# 5069   LAUMT182902000000003 2018-03-01  2018    M03    3.2              p
# 1403   LAUMT063370000000003 2018-03-01  2018    M03    7.1              p
# 8657   LAUMT352214000000003 2018-03-01  2018    M03    5.5              p
# 15053  LAUMT561622000000003 2018-03-01  2018    M03    4.7              p
# 2066   LAUMT064970000000003 2018-03-01  2018    M03    8.7              p
# 1364   LAUMT063290000000003 2018-03-01  2018    M03   10.2              p
# 1247   LAUMT062526000000003 2018-03-01  2018    M03    9.2              p
# 1832   LAUMT064210000000003 2018-03-01  2018    M03    6.3              p
# 1091   LAUMT061254000000003 2018-03-01  2018    M03    9.6              p
# 1325   LAUMT063146000000003 2018-03-01  2018    M03    8.2              p
# 1520   LAUMT063982000000003 2018-03-01  2018    M03    5.7              p
# 1949   LAUMT064470000000003 2018-03-01  2018    M03    6.6              p
# 14546  LAUMT544854000000003 2018-03-01  2018    M03    6.1              p
# 5147   LAUMT183314000000003 2018-03-01  2018    M03    4.6              p
# 6083   LAUMT222918000000003 2018-03-01  2018    M03    4.6              p
# 10334  LAUMT394826000000003 2018-03-01  2018    M03    6.6              p
# 38     LAUMT011150000000003 2018-03-01  2018    M03    4.5              p
# 272    LAUMT012252000000003 2018-03-01  2018    M03    4.2              p
# 1208   LAUMT062342000000003 2018-03-01  2018    M03    8.7              p
# 194    LAUMT011946000000003 2018-03-01  2018    M03    3.7              p
# 2261   LAUMT082430000000003 2018-03-01  2018    M03    4.0              p
# 14546    03    1      -2.5        8.6
# 5147     03    1      -2.5        7.1
# 6083     03    1      -2.5        7.1
# 10334    03    1      -2.4        9.0
# 38       03    1      -2.4        6.9
# 272      03    1      -2.4        6.6
# 1208     03    1      -2.3       11.0
# 194      03    1      -2.3        6.0
# 2261     03    1      -2.3        6.3
# 4757     03    1      -2.2        7.3
# 6044     03    1      -2.2        6.6
# 1130     03    1      -2.1        7.4
# 4718     03    1      -2.1        7.2
# 4562     03    1      -2.1        7.9
# 311      03    1      -2.1        6.1
# 116      03    1      -2.1        5.6
# ...     ...  ...       ...        ...
# 9827     03    1      -0.1        3.6
# 12440    03    1      -0.1        3.2
# 7175     03    1      -0.1        5.3
# 7292     03    1      -0.1        5.3
# 12635    03    1      -0.1        3.8
# 6512     03    1      -0.1        5.1
# 1013     03    1       0.0        3.6
# 12401    03    1       0.0        3.0
# 8033     03    1       0.0        4.5
# 935      03    1       0.0        4.3
# 6395     03    1       0.0        4.6
# 7994     03    1       0.1        4.0
# 12479    03    1       0.2        6.4
# 8930     03    1       0.2        6.1
# 6434     03    1       0.2        4.3
# 12869    03    1       0.2        3.3
# 11894    03    1       0.2        3.5
# 11933    03    1       0.3        2.8
# 8969     03    1       0.3        3.9
# 8852     03    1       0.4        5.4
# 9125     03    1       0.4        5.2
# 8813     03    1       0.4        5.8
# 8774     03    1       0.4        4.3
# 13142    03    1       0.4        4.3
# 9008     03    1       0.4        4.5
# 9164     03    1       0.5        5.5
# 545      03    1       0.5        6.4
# 9086     03    1       0.5        4.9
# 9203     03    1       0.6        7.4
# 506      03    1       0.7        6.5
#
# [387 rows x 10 columns]

# %%
df.sort_values('value').reset_index()['prevvalue'].to_csv('MSANov2015_2.csv')

# %%
# Calculate one year change in unemployment rate for each MSA
df.loc[:,'value_ch'] = df['value'].diff(periods=12)
#df = df.dropna()

# Keep only the latest value for each MSA
df = df.reset_index().groupby(['series_id']).tail(1)
df.rename(columns={'series_id':'fullcode'}, inplace=True)

# Take the date for use in chart title
date = df['date'].iloc[0].strftime('%B %Y')

# Combine the two datasets and show 2 rows to verify 
unemp_list = df.merge(MSA, on='fullcode')

# Shorten MSA names for chart labels
unemp_list.loc[:,'MSA'] = unemp_list['area_code'].str.replace('Metropolitan Statistical Area', 'MSA')

# %%
# From the change in unemployment rate, mark increases red, decreases green,
#   no change is gray. The size of the circle to draw is the absolute value 
#   of the change times 8. 

for index, row in unemp_list.iterrows():
    if row['value_ch'] > 0:
        unemp_list.loc[index,'color'] = '#FF0000'
        unemp_list.loc[index,'size'] = abs(row['value_ch'])*10+2
        unemp_list.loc[index,'sym'] = '▲{}'.format(unemp_list.loc[index,'value_ch']) # Up Arrow
    if row['value_ch'] < 0:
        unemp_list.loc[index,'color'] = '#32CD32'
        unemp_list.loc[index,'size'] = abs(row['value_ch'])*10+2
        unemp_list.loc[index, 'sym'] = '▼{}'.format(unemp_list.loc[index,'value_ch']) # Down Arrow
    if row['value_ch'] == 0:
        unemp_list.loc[index,'color'] = '#696969'
        unemp_list.loc[index,'size'] = 3   # Just to mark location
        unemp_list.loc[index, 'sym'] = 'unchanged'
    # Create a text column for plotly hover labels
    unemp_list.loc[index,'text'] = '{}<br>{} Rate: {}% ({})'.format(
        unemp_list.loc[index,'MSA'], 
        date,
        unemp_list.loc[index,'value'],
        unemp_list.loc[index,'sym'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [sym] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-c33c1defcc29> in <module>()
#      21         date,
#      22         unemp_list.loc[index,'value'],
# ---> 23         unemp_list.loc[index,'sym'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     856     def _getitem_tuple(self, tup):
#     857         try:
# --> 858             return self._getitem_lowerdim(tup)
#     859         except IndexingError:
#     860             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#    1018                     return section
#    1019                 # This is an elided recursive call to iloc/loc/etc'
# -> 1020                 return getattr(section, self.name)[new_key]
#    1021
#    1022         raise IndexingError('not applicable')
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1624
#    1625         # fall thru to straight lookup
# -> 1626         self._has_valid_type(key, axis)
#    1627         return self._get_label(key, axis=axis)
#    1628
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1512                 raise
#    1513             except:
# -> 1514                 error()
#    1515
#    1516         return True
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1499                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#    1503             try:
#
# KeyError: 'the label [sym] is not in the [index]'

# %%
unemp_list
# Out:
#      index              fullcode       date  year period  value  \
# 0       38  LAUMT011150000000003 2018-03-01  2018    M03    4.5
# 1       77  LAUMT011222000000003 2018-03-01  2018    M03    3.6
# 2      116  LAUMT011382000000003 2018-03-01  2018    M03    3.5
# 3      155  LAUMT011930000000003 2018-03-01  2018    M03    3.5
# 4      194  LAUMT011946000000003 2018-03-01  2018    M03    3.7
# 5      233  LAUMT012002000000003 2018-03-01  2018    M03    4.0
# 6      272  LAUMT012252000000003 2018-03-01  2018    M03    4.2
# 7      311  LAUMT012346000000003 2018-03-01  2018    M03    4.0
# 8      350  LAUMT012662000000003 2018-03-01  2018    M03    3.4
# 9      389  LAUMT013366000000003 2018-03-01  2018    M03    4.6
# 10     428  LAUMT013386000000003 2018-03-01  2018    M03    3.8
# 11     467  LAUMT014622000000003 2018-03-01  2018    M03    3.7
# 12     506  LAUMT021126000000003 2018-03-01  2018    M03    7.2
# 13     545  LAUMT022182000000003 2018-03-01  2018    M03    6.9
# 14     584  LAUMT042238000000003 2018-03-01  2018    M03    5.5
# 15     623  LAUMT042942000000003 2018-03-01  2018    M03    5.7
# 16     662  LAUMT043806000000003 2018-03-01  2018    M03    4.1
# 17     701  LAUMT043914000000003 2018-03-01  2018    M03    4.3
# 18     740  LAUMT044342000000003 2018-03-01  2018    M03    5.6
# 19     779  LAUMT044606000000003 2018-03-01  2018    M03    4.3
# 20     818  LAUMT044974000000003 2018-03-01  2018    M03   13.6
# 21     857  LAUMT052222000000003 2018-03-01  2018    M03    2.8
# 22     896  LAUMT052290000000003 2018-03-01  2018    M03    4.2
# 23     935  LAUMT052630000000003 2018-03-01  2018    M03    4.3
# 24     974  LAUMT052786000000003 2018-03-01  2018    M03    3.3
# 25    1013  LAUMT053078000000003 2018-03-01  2018    M03    3.6
# 26    1052  LAUMT053822000000003 2018-03-01  2018    M03    5.3
# 27    1091  LAUMT061254000000003 2018-03-01  2018    M03    9.6
# 28    1130  LAUMT061702000000003 2018-03-01  2018    M03    5.3
# 29    1169  LAUMT062094000000003 2018-03-01  2018    M03   15.3
# ..     ...                   ...        ...   ...    ...    ...
# 361  13961  LAUMT531474000000003 2018-03-01  2018    M03    5.2
# 362  14000  LAUMT532842000000003 2018-03-01  2018    M03    6.5
# 363  14039  LAUMT533102000000003 2018-03-01  2018    M03    6.7
# 364  14078  LAUMT533458000000003 2018-03-01  2018    M03    5.8
# 365  14117  LAUMT533650000000003 2018-03-01  2018    M03    5.3
# 366  14156  LAUMT534266000000003 2018-03-01  2018    M03    3.9
# 367  14195  LAUMT534406000000003 2018-03-01  2018    M03    6.5
# 368  14234  LAUMT534746000000003 2018-03-01  2018    M03    5.4
# 369  14273  LAUMT534830000000003 2018-03-01  2018    M03    6.3
# 370  14312  LAUMT534942000000003 2018-03-01  2018    M03    7.6
# 371  14351  LAUMT541322000000003 2018-03-01  2018    M03    6.7
# 372  14390  LAUMT541662000000003 2018-03-01  2018    M03    5.8
# 373  14429  LAUMT542658000000003 2018-03-01  2018    M03    5.8
# 374  14468  LAUMT543406000000003 2018-03-01  2018    M03    4.6
# 375  14507  LAUMT543762000000003 2018-03-01  2018    M03    6.2
# 376  14546  LAUMT544854000000003 2018-03-01  2018    M03    6.1
# 377  14585  LAUMT551154000000003 2018-03-01  2018    M03    2.8
# 378  14624  LAUMT552074000000003 2018-03-01  2018    M03    3.2
# 379  14663  LAUMT552254000000003 2018-03-01  2018    M03    2.7
# 380  14702  LAUMT552458000000003 2018-03-01  2018    M03    3.0
# 381  14741  LAUMT552750000000003 2018-03-01  2018    M03    3.4
# 382  14780  LAUMT552910000000003 2018-03-01  2018    M03    2.9
# 383  14819  LAUMT553154000000003 2018-03-01  2018    M03    2.4
# 384  14858  LAUMT553334000000003 2018-03-01  2018    M03    3.1
# 385  14897  LAUMT553678000000003 2018-03-01  2018    M03    2.7
# 386  14936  LAUMT553954000000003 2018-03-01  2018    M03    3.7
# 387  14975  LAUMT554310000000003 2018-03-01  2018    M03    2.6
# 388  15014  LAUMT554814000000003 2018-03-01  2018    M03    2.9
# 389  15053  LAUMT561622000000003 2018-03-01  2018    M03    4.7
# 390  15092  LAUMT561694000000003 2018-03-01  2018    M03    3.8
#
#     footnote_codes month  day  value_ch  prevvalue              fullname  \
# 0                p    03    1       NaN        6.9          Anniston, AL
# 1                p    03    1       NaN        5.4            Auburn, AL
# 2                p    03    1       NaN        5.6        Birmingham, AL
# 3                p    03    1       NaN        5.5            Daphne, AL
# 4                p    03    1       NaN        6.0           Decatur, AL
# 5                p    03    1       NaN        6.0            Dothan, AL
# 6                p    03    1       NaN        6.6          Florence, AL
# 7                p    03    1       NaN        6.1           Gadsden, AL
# 8                p    03    1       NaN        5.3        Huntsville, AL
# 9                p    03    1       NaN        6.6            Mobile, AL
# 10               p    03    1       NaN        5.6        Montgomery, AL
# 11               p    03    1       NaN        5.8        Tuscaloosa, AL
# 12               p    03    1       2.7        6.5         Anchorage, AK
# 13               p    03    1       3.3        6.4         Fairbanks, AK
# 14               p    03    1       2.0        6.0         Flagstaff, AZ
# 15               p    03    1       2.2        7.2  Lake Havasu City, AZ
# 16               p    03    1       0.4        4.8           Phoenix, AZ
# 17               p    03    1       0.3        5.2          Prescott, AZ
# 18               p    03    1       1.4        6.6      Sierra Vista, AZ
# 19               p    03    1       0.3        5.0            Tucson, AZ
# 20               p    03    1      10.2       14.6              Yuma, AZ
# 21               p    03    1      -1.8        3.0      Fayetteville, AR
# 22               p    03    1       0.4        4.7        Fort Smith, AR
# 23               p    03    1       0.6        4.3       Hot Springs, AR
# 24               p    03    1      -3.9        3.5         Jonesboro, AR
# 25               p    03    1      -3.3        3.6       Little Rock, AR
# 26               p    03    1      -0.2        5.4        Pine Bluff, AR
# 27               p    03    1       3.9       12.3       Bakersfield, CA
# 28               p    03    1       1.2        7.4             Chico, CA
# 29               p    03    1      11.0       21.3         El Centro, CA
# ..             ...   ...  ...       ...        ...                   ...
# 361              p    03    1       1.9        5.6         Bremerton, WA
# 362              p    03    1       4.2        7.4         Kennewick, WA
# 363              p    03    1       3.3        7.5          Longview, WA
# 364              p    03    1       2.9        7.1      Mount Vernon, WA
# 365              p    03    1       2.0        6.0           Olympia, WA
# 366              p    03    1       0.1        4.7           Seattle, WA
# 367              p    03    1       3.0        6.9           Spokane, WA
# 368              p    03    1       2.0        6.0       Walla Walla, WA
# 369              p    03    1       3.2        7.5         Wenatchee, WA
# 370              p    03    1       4.0        8.9            Yakima, WA
# 371              p    03    1       3.5        8.6           Beckley, WV
# 372              p    03    1       0.6        6.5        Charleston, WV
# 373              p    03    1       0.6        6.8        Huntington, WV
# 374              p    03    1      -1.9        5.2        Morgantown, WV
# 375              p    03    1      -0.5        6.5       Parkersburg, WV
# 376              p    03    1       0.3        8.6          Wheeling, WV
# 377              p    03    1      -2.5        4.0          Appleton, WI
# 378              p    03    1      -0.7        4.5        Eau Claire, WI
# 379              p    03    1      -3.8        4.0       Fond du Lac, WI
# 380              p    03    1      -2.4        4.3         Green Bay, WI
# 381              p    03    1      -2.9        5.0        Janesville, WI
# 382              p    03    1      -4.7        4.3         La Crosse, WI
# 383              p    03    1      -4.3        3.4           Madison, WI
# 384              p    03    1      -2.7        4.6         Milwaukee, WI
# 385              p    03    1      -3.1        3.9           Oshkosh, WI
# 386              p    03    1      -0.9        5.5            Racine, WI
# 387              p    03    1      -3.6        3.8         Sheboygan, WI
# 388              p    03    1      -3.2        4.2            Wausau, WI
# 389              p    03    1       1.9        7.6            Casper, WY
# 390              p    03    1       0.6        4.6          Cheyenne, WY
#
#       latitude   longitude                                          area_code  \
# 0    33.695381  -85.839842  Anniston-Oxford-Jacksonville, AL Metropolitan ...
# 1    32.655091  -85.503643   Auburn-Opelika, AL Metropolitan Statistical Area
# 2    33.520682  -86.802432  Birmingham-Hoover, AL Metropolitan Statistical...
# 3    30.571851  -87.855586  Daphne-Fairhope-Foley, AL Metropolitan Statist...
# 4    34.624021  -87.057919          Decatur, AL Metropolitan Statistical Area
# 377  44.261134  -88.406760         Appleton, WI Metropolitan Statistical Area
# 378  44.811349  -91.498494       Eau Claire, WI Metropolitan Statistical Area
# 379  43.774876  -88.445803      Fond du Lac, WI Metropolitan Statistical Area
# 380  44.529941  -88.024832        Green Bay, WI Metropolitan Statistical Area
# 381  42.715185  -88.990774  Janesville-Beloit, WI Metropolitan Statistical...
# 382  43.801356  -91.239581  La Crosse-Onalaska, WI-MN Metropolitan Statist...
# 383  43.074761  -89.383761          Madison, WI Metropolitan Statistical Area
# 384  43.034993  -87.922497  Milwaukee-Waukesha-West Allis, WI Metropolitan...
# 385  44.020692  -88.540857   Oshkosh-Neenah, WI Metropolitan Statistical Area
# 386  42.726052  -87.782524           Racine, WI Metropolitan Statistical Area
# 387  43.750828  -87.714530        Sheboygan, WI Metropolitan Statistical Area
# 388  44.959602  -89.629824           Wausau, WI Metropolitan Statistical Area
# 389  42.866632 -106.313081           Casper, WY Metropolitan Statistical Area
# 390  41.139981 -104.820246         Cheyenne, WY Metropolitan Statistical Area
#
#                                               MSA
# 0            Anniston-Oxford-Jacksonville, AL MSA
# 1                          Auburn-Opelika, AL MSA
# 2                       Birmingham-Hoover, AL MSA
# 3                   Daphne-Fairhope-Foley, AL MSA
# 4                                 Decatur, AL MSA
# 5                                  Dothan, AL MSA
# 6                  Florence-Muscle Shoals, AL MSA
# 7                                 Gadsden, AL MSA
# 8                              Huntsville, AL MSA
# 9                                  Mobile, AL MSA
# 10                             Montgomery, AL MSA
# 11                             Tuscaloosa, AL MSA
# 12                              Anchorage, AK MSA
# 13                              Fairbanks, AK MSA
# 14                              Flagstaff, AZ MSA
# 15               Lake Havasu City-Kingman, AZ MSA
# 16                Phoenix-Mesa-Scottsdale, AZ MSA
# 17                               Prescott, AZ MSA
# 18                   Sierra Vista-Douglas, AZ MSA
# 19                                 Tucson, AZ MSA
# 20                                   Yuma, AZ MSA
# 21      Fayetteville-Springdale-Rogers, AR-MO MSA
# 22                          Fort Smith, AR-OK MSA
# 23                            Hot Springs, AR MSA
# 24                              Jonesboro, AR MSA
# 25   Little Rock-North Little Rock-Conway, AR MSA
# 26                             Pine Bluff, AR MSA
# 27                            Bakersfield, CA MSA
# 28                                  Chico, CA MSA
# 29                              El Centro, CA MSA
# ..                                            ...
# 361                  Bremerton-Silverdale, WA MSA
# 362                    Kennewick-Richland, WA MSA
# 363                              Longview, WA MSA
# 364                Mount Vernon-Anacortes, WA MSA
# 365                      Olympia-Tumwater, WA MSA
# 366               Seattle-Tacoma-Bellevue, WA MSA
# 367                Spokane-Spokane Valley, WA MSA
# 368                           Walla Walla, WA MSA
# 369                             Wenatchee, WA MSA
# 370                                Yakima, WA MSA
# 371                               Beckley, WV MSA
# 372                            Charleston, WV MSA
# 373              Huntington-Ashland, WV-KY-OH MSA
# 374                            Morgantown, WV MSA
# 375                    Parkersburg-Vienna, WV MSA
# 376                           Wheeling, WV-OH MSA
# 377                              Appleton, WI MSA
# 378                            Eau Claire, WI MSA
# 379                           Fond du Lac, WI MSA
# 380                             Green Bay, WI MSA
# 381                     Janesville-Beloit, WI MSA
# 382                 La Crosse-Onalaska, WI-MN MSA
# 383                               Madison, WI MSA
# 384         Milwaukee-Waukesha-West Allis, WI MSA
# 385                        Oshkosh-Neenah, WI MSA
# 386                                Racine, WI MSA
# 387                             Sheboygan, WI MSA
# 388                                Wausau, WI MSA
# 389                                Casper, WY MSA
# 390                              Cheyenne, WY MSA
#
# [391 rows x 16 columns]

# %% [markdown]
# #### Plotly code

# %%
trace1 = {
  "geo": "geo", 
  "hoverinfo": "text", 
  "lat": unemp_list['latitude'], 
  "lon": unemp_list['longitude'], 
  "marker": {
    "color": unemp_list['color'], 
    "line": {
      "color": "#202020", 
      "width": 0.8
    }, 
    "opacity": 0.5, 
    "size": unemp_list['size'], 
    "symbol": "circle"
  }, 
  "mode": "markers", 
  "name": "Unemployment Rate Change by Metro Area", 
  "opacity": 1, 
  "showlegend": True, 
  "text": unemp_list['text'], 
  "type": "scattergeo", 
  "visible": True
}
data = Data([trace1])
layout = {
  "annotations": [
    {
      "x": 0.05, 
      "y": 0.925, 
      "align": "left", 
      "font": {"size": 14}, 
      "showarrow": False, 
      "text": "<b>Change in Unemployment Rate by Metropolitan Statistical Area (MSA)</b><br><i>Change over level in same month of previous year, as of {}</i>".format(date), 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 0.05, 
      "y": 0.0725, 
      "align": "left", 
      "showarrow": False, 
      "text": "Hover to see details. Green is decrease in unemployment rate, red is increase. Circle size shows amount of change.  <br><b>Source:</b> U.S. Bureau of Labor Statistics, Local Area Unemployment Statistics", 
      "xref": "x", 
      "yref": "y"
    }
  ], 
  "autosize": True, 
  "dragmode": "zoom", 
  "geo": {
    "bgcolor": "#fff", 
    "countrycolor": "#808080", 
    "countrywidth": 0.7, 
    "domain": {
      "x": [0, 1.1], 
      "y": [0, 1.1]
    }, 
    "lataxis": {
      "dtick": 10, 
      "range": [20, 80], 
      "showgrid": False, 
      "tick0": 20
    }, 
    "lonaxis": {
      "dtick": 30, 
      "range": [-180, -50], 
      "showgrid": False, 
      "tick0": -180
    }, 
    "projection": {
      "scale": 1.03, 
      "type": "albers usa"
    }, 
    "resolution": 50, 
    "scope": "usa", 
    "showcountries": False, 
    "showlakes": False, 
    "showland": False, 
    "showrivers": False, 
    "showsubunits": True, 
    "subunitcolor": "#808080", 
    "subunitwidth": 0.7
  }, 
  "hidesources": False, 
  "hovermode": "closest", 
  "paper_bgcolor": "#fff", 
  "separators": ".,", 
  "showlegend": False, 
  "smith": False, 
  "margin": {
    "r": 0, 
    "t": 0, 
    "b": 0, 
    "l": 0
  },
}
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig, filename='MSA_Map')

# %% [markdown]
# #### Generate an html table of results

# %%
# generate html table with data
table = unemp_list[['MSA', 'value', 'value_ch']]
table.columns = ['Metropolitan Statistical Area (MSA) Name', 'Unemp. rate', 'One-year change']
table = table.sort_values('One-year change').drop_duplicates() 
# Sortable css class allows for js script to sort each column
# https://www.kryogenix.org/code/browser/sorttable/
table.to_html('C:/Working/bdecon.github.io/Dash/unemp_table.html', border=0, 
              index=False, classes='sortable')
