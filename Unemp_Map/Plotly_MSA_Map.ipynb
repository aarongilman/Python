# %% [markdown]
# ### Mapping Changes to the Unemployment Rate using Plotly
#
# *Brian Dew, Domestic Program Intern, CEPR*<br>
# *June 17, 2017*
#
# Updated February 6, 2018

# %%
# Import libraries and sign in to plotly
import pandas as pd
import config   # File that contains api key
import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in('bdew', config.plotly_key)

# %%
# CSV file contains city names, their BLS codes (Metropolitan 
# MTAs/NECTAs only), and their latitude and longitude
MSA = pd.read_csv('MSA.csv')

# BLS flat file contains the unemployment rate by month since 2015
url = 'https://download.bls.gov/pub/time.series/la/la.data.0.CurrentU15-19'
df = pd.read_table(url, sep='\s+', na_values=['-'])

# %%
df
# Out:
#                     series_id  year period      value footnote_codes
# 0        LAUBS060000000000003  2015    M01        7.0              d
# 1        LAUBS060000000000003  2015    M02        6.7              d
# 2        LAUBS060000000000003  2015    M03        6.6              d
# 3        LAUBS060000000000003  2015    M04        6.0              d
# 4        LAUBS060000000000003  2015    M05        5.9              d
# 5        LAUBS060000000000003  2015    M06        6.1              d
# 6        LAUBS060000000000003  2015    M07        6.3              d
# 7        LAUBS060000000000003  2015    M08        5.9              d
# 8        LAUBS060000000000003  2015    M09        5.4              d
# 9        LAUBS060000000000003  2015    M10        5.6              d
# 10       LAUBS060000000000003  2015    M11        5.6              d
# 11       LAUBS060000000000003  2015    M12        5.6              d
# 12       LAUBS060000000000003  2015    M13        6.0              d
# 13       LAUBS060000000000003  2016    M01        6.0              d
# 14       LAUBS060000000000003  2016    M02        5.9              d
# 15       LAUBS060000000000003  2016    M03        6.0              d
# 16       LAUBS060000000000003  2016    M04        5.5              d
# 17       LAUBS060000000000003  2016    M05        5.0              d
# 18       LAUBS060000000000003  2016    M06        5.6              d
# 19       LAUBS060000000000003  2016    M07        5.8              d
# 20       LAUBS060000000000003  2016    M08        5.6              d
# 21       LAUBS060000000000003  2016    M09        5.3              d
# 22       LAUBS060000000000003  2016    M10        5.3              d
# 23       LAUBS060000000000003  2016    M11        5.2              d
# 24       LAUBS060000000000003  2016    M12        5.3              d
# 25       LAUBS060000000000003  2016    M13        5.6              d
# 26       LAUBS060000000000003  2017    M01        5.8              d
# 27       LAUBS060000000000003  2017    M02        5.6              d
# 28       LAUBS060000000000003  2017    M03        5.4              d
# 29       LAUBS060000000000003  2017    M04        4.8              d
# ...                       ...   ...    ...        ...            ...
# 1222014  LAUST720000000000006  2015    M11  1125551.0              u
# 1222015  LAUST720000000000006  2015    M12  1138714.0              u
# 1222016  LAUST720000000000006  2015    M13  1121746.0              u
# 1222017  LAUST720000000000006  2016    M01  1120043.0              u
# 1222018  LAUST720000000000006  2016    M02  1131684.0              u
# 1222019  LAUST720000000000006  2016    M03  1124816.0              u
# 1222020  LAUST720000000000006  2016    M04  1125706.0              u
# 1222021  LAUST720000000000006  2016    M05  1127791.0              u
# 1222022  LAUST720000000000006  2016    M06  1104500.0              u
# 1222023  LAUST720000000000006  2016    M07  1122162.0              u
# 1222024  LAUST720000000000006  2016    M08  1102646.0              u
# 1222025  LAUST720000000000006  2016    M09  1115304.0              u
# 1222026  LAUST720000000000006  2016    M10  1098741.0              u
# 1222027  LAUST720000000000006  2016    M11  1106505.0              u
# 1222028  LAUST720000000000006  2016    M12  1135009.0              u
# 1222029  LAUST720000000000006  2016    M13  1117909.0              u
# 1222030  LAUST720000000000006  2017    M01  1119964.0              u
# 1222031  LAUST720000000000006  2017    M02  1143308.0              u
# 1222032  LAUST720000000000006  2017    M03  1122929.0              u
# 1222033  LAUST720000000000006  2017    M04  1115404.0              u
# 1222034  LAUST720000000000006  2017    M05  1099152.0              u
# 1222035  LAUST720000000000006  2017    M06  1083576.0              u
# 1222036  LAUST720000000000006  2017    M07  1091104.0              u
# 1222037  LAUST720000000000006  2017    M08  1092130.0              u
# 1222038  LAUST720000000000006  2017    M09  1091617.0              w
# 1222039  LAUST720000000000006  2017    M10  1055201.0              u
# 1222040  LAUST720000000000006  2017    M11  1106581.0              u
# 1222041  LAUST720000000000006  2017    M12  1110787.0              u
# 1222042  LAUST720000000000006  2017    M13  1102646.0              u
# 1222043  LAUST720000000000006  2018    M01  1098935.0            NaN
#
# [1222044 rows x 5 columns]

# %%
# Take only the unemployment data for MSAs and monthly series 
# (M13 is annual average)
df = pd.DataFrame(df[df['series_id'].isin(MSA['fullcode']) 
                 & ~df['period'].isin(['M13'])])

# Clean up the date to convert it to pandas datetime
df.loc[:,'month'] = df['period'].replace(regex=True, 
                                         to_replace=r'M', 
                                         value=r'')
df.loc[:,'day'] = 1
df.loc[:,'date'] = pd.to_datetime(df[['year', 'month', 'day']])
df.loc[:,'value'] = df['value'].astype('float')
df = df.set_index(['series_id','date'])

# %%
df.loc[:,'value_ch'] = df['value'].diff(periods=24)
df = df.reset_index().groupby(['series_id']).tail(1)
df['prevvalue'] = df['value'] - df['value_ch']
#df.sort_values('value_ch')

# %%
df['prevvalue'] = df['value'] - df['value_ch']

# %%
df.sort_values('value_ch')
# Out:
#                   series_id       date  year period  value footnote_codes  \
# 1109   LAUMT062094000000003 2018-01-01  2018    M01   17.0              p
# 1294   LAUMT063290000000003 2018-01-01  2018    M01    9.9              p
# 5771   LAUMT222918000000003 2018-01-01  2018    M01    4.6              p
# 1183   LAUMT062526000000003 2018-01-01  2018    M01    9.0              p
# 1442   LAUMT063982000000003 2018-01-01  2018    M01    5.6              p
# 258    LAUMT012252000000003 2018-01-01  2018    M01    4.7              p
# 1960   LAUMT064970000000003 2018-01-01  2018    M01    8.6              p
# 4513   LAUMT174042000000003 2018-01-01  2018    M01    5.3              p
# 5697   LAUMT222522000000003 2018-01-01  2018    M01    4.9              p
# 4402   LAUMT171950000000003 2018-01-01  2018    M01    5.3              p
# 4439   LAUMT172810000000003 2018-01-01  2018    M01    5.5              p
# 4476   LAUMT173790000000003 2018-01-01  2018    M01    5.3              p
# 1257   LAUMT063146000000003 2018-01-01  2018    M01    8.0              p
# 36     LAUMT011150000000003 2018-01-01  2018    M01    4.7              p
# 13615  LAUMT541322000000003 2018-01-01  2018    M01    6.3              p
# 12320  LAUMT483622000000003 2018-01-01  2018    M01    3.3              p
# 184    LAUMT011946000000003 2018-01-01  2018    M01    4.0              p
# 5919   LAUMT224334000000003 2018-01-01  2018    M01    4.6              p
# 369    LAUMT013366000000003 2018-01-01  2018    M01    5.0              p
# 443    LAUMT014622000000003 2018-01-01  2018    M01    3.9              p
# 1738   LAUMT064210000000003 2018-01-01  2018    M01    7.0              p
# 4328   LAUMT171918000000003 2018-01-01  2018    M01    6.0              p
# 1553   LAUMT064150000000003 2018-01-01  2018    M01    9.5              p
# 1331   LAUMT063370000000003 2018-01-01  2018    M01    7.4              p
# 5734   LAUMT222638000000003 2018-01-01  2018    M01    4.6              p
# 1849   LAUMT064470000000003 2018-01-01  2018    M01    7.0              p
# 4217   LAUMT171606000000003 2018-01-01  2018    M01    4.7              p
# 110    LAUMT011382000000003 2018-01-01  2018    M01    3.7              p
# 4365   LAUMT171934000000003 2018-01-01  2018    M01    4.7              p
# 1146   LAUMT062342000000003 2018-01-01  2018    M01    8.7              p
# ...                     ...        ...   ...    ...    ...            ...
# 8509   LAUMT362706000000003 2018-01-01  2018    M01    4.7              p
# 11950  LAUMT481858000000003 2018-01-01  2018    M01    5.9              p
# 11839  LAUMT481314000000003 2018-01-01  2018    M01    7.3              p
# 8694   LAUMT364654000000003 2018-01-01  2018    M01    6.3              p
# 9545   LAUMT391746000000003 2018-01-01  2018    M01    5.6              p
# 8620   LAUMT364038000000003 2018-01-01  2018    M01    5.6              p
# 8657   LAUMT364506000000003 2018-01-01  2018    M01    6.0              p
# 8324   LAUMT361058000000003 2018-01-01  2018    M01    5.0              p
# 8361   LAUMT361378000000003 2018-01-01  2018    M01    6.8              p
# 6696   LAUMT262710000000003 2018-01-01  2018    M01    5.4              p
# 11284  LAUMT463966000000003 2018-01-01  2018    M01    4.0              p
# 6474   LAUMT261146000000003 2018-01-01  2018    M01    3.6              p
# 6659   LAUMT262434000000003 2018-01-01  2018    M01    4.0              p
# 8546   LAUMT362874000000003 2018-01-01  2018    M01    5.4              p
# 8398   LAUMT361538000000003 2018-01-01  2018    M01    6.2              p
# 6622   LAUMT262242000000003 2018-01-01  2018    M01    6.6              p
# 11321  LAUMT464362000000003 2018-01-01  2018    M01    3.4              p
# 6511   LAUMT261298000000003 2018-01-01  2018    M01    5.4              p
# 6770   LAUMT262962000000003 2018-01-01  2018    M01    5.0              p
# 6733   LAUMT262802000000003 2018-01-01  2018    M01    5.0              p
# 6881   LAUMT263474000000003 2018-01-01  2018    M01    5.9              p
# 6918   LAUMT263566000000003 2018-01-01  2018    M01    5.8              p
# 8472   LAUMT362402000000003 2018-01-01  2018    M01    6.8              p
# 6807   LAUMT263322000000003 2018-01-01  2018    M01    5.7              p
# 6844   LAUMT263378000000003 2018-01-01  2018    M01    5.3              p
# 480    LAUMT021126000000003 2018-01-01  2018    M01    7.2              p
# 8731   LAUMT364806000000003 2018-01-01  2018    M01    8.4              p
# 6548   LAUMT261302000000003 2018-01-01  2018    M01    6.8              p
# 6955   LAUMT264098000000003 2018-01-01  2018    M01    6.6              p
# 517    LAUMT022182000000003 2018-01-01  2018    M01    7.5              p
#
#       month  day  value_ch  prevvalue
# 1109     01    1      -4.4       21.4
# 1294     01    1      -3.1       13.0
# 5771     01    1      -2.7        7.3
# 1183     01    1      -2.7       11.7
# 1442     01    1      -2.6        8.2
# 258      01    1      -2.6        7.3
# 1960     01    1      -2.5       11.1
# 4513     01    1      -2.5        7.8
# 5697     01    1      -2.5        7.4
# 4402     01    1      -2.4        7.7
# 4439     01    1      -2.4        7.9
# 4476     01    1      -2.4        7.7
# 1257     01    1      -2.4       10.4
# 36       01    1      -2.4        7.1
# 13615    01    1      -2.3        8.6
# 12320    01    1      -2.3        5.6
# 184      01    1      -2.3        6.3
# 5919     01    1      -2.2        6.8
# 369      01    1      -2.2        7.2
# 443      01    1      -2.2        6.1
# 1738     01    1      -2.2        9.2
# 4328     01    1      -2.2        8.2
# 1553     01    1      -2.2       11.7
# 1331     01    1      -2.2        9.6
# 5734     01    1      -2.1        6.7
# 1849     01    1      -2.1        9.1
# 4217     01    1      -2.1        6.8
# 110      01    1      -2.1        5.8
# 4365     01    1      -2.0        6.7
# 1146     01    1      -2.0       10.7
# ...     ...  ...       ...        ...
# 8509     01    1       0.1        4.6
# 11950    01    1       0.1        5.8
# 11839    01    1       0.4        6.9
# 8694     01    1       0.4        5.9
# 9545     01    1       0.4        5.2
# 8620     01    1       0.4        5.2
# 8657     01    1       0.4        5.6
# 8324     01    1       0.4        4.6
# 8361     01    1       0.5        6.3
# 6696     01    1       0.5        4.9
# 11284    01    1       0.5        3.5
# 6474     01    1       0.5        3.1
# 6659     01    1       0.6        3.4
# 8546     01    1       0.6        4.8
# 8398     01    1       0.6        5.6
# 6622     01    1       0.7        5.9
# 11321    01    1       0.7        2.7
# 6511     01    1       0.7        4.7
# 6770     01    1       0.7        4.3
# 6733     01    1       0.7        4.3
# 6881     01    1       0.7        5.2
# 6918     01    1       0.7        5.1
# 8472     01    1       0.7        6.1
# 6807     01    1       0.8        4.9
# 6844     01    1       0.9        4.4
# 480      01    1       1.0        6.2
# 8731     01    1       1.0        7.4
# 6548     01    1       1.1        5.7
# 6955     01    1       1.1        5.5
# 517      01    1       1.1        6.4
#
# [387 rows x 10 columns]

# %%
df.sort_values('value').reset_index()['prevvalue'].to_csv('MSANov2015_2.csv')

# %%
# Calculate one year change in unemployment rate for each MSA
df.loc[:,'value_ch'] = df['value'].diff(periods=12)
#df = df.dropna()

# Keep only the latest value for each MSA
df = df.reset_index().groupby(['series_id']).tail(1)
df.rename(columns={'series_id':'fullcode'}, inplace=True)

# Take the date for use in chart title
date = df['date'].iloc[0].strftime('%B %Y')

# Combine the two datasets and show 2 rows to verify 
unemp_list = df.merge(MSA, on='fullcode')

# Shorten MSA names for chart labels
unemp_list.loc[:,'MSA'] = unemp_list['area_code'].str.replace('Metropolitan Statistical Area', 'MSA')

# %%
# From the change in unemployment rate, mark increases red, decreases green,
#   no change is gray. The size of the circle to draw is the absolute value 
#   of the change times 8. 

for index, row in unemp_list.iterrows():
    if row['value_ch'] > 0:
        unemp_list.loc[index,'color'] = '#FF0000'
        unemp_list.loc[index,'size'] = abs(row['value_ch'])*10+2
        unemp_list.loc[index,'sym'] = '▲{}'.format(unemp_list.loc[index,'value_ch']) # Up Arrow
    if row['value_ch'] < 0:
        unemp_list.loc[index,'color'] = '#32CD32'
        unemp_list.loc[index,'size'] = abs(row['value_ch'])*10+2
        unemp_list.loc[index, 'sym'] = '▼{}'.format(unemp_list.loc[index,'value_ch']) # Down Arrow
    if row['value_ch'] == 0:
        unemp_list.loc[index,'color'] = '#696969'
        unemp_list.loc[index,'size'] = 3   # Just to mark location
        unemp_list.loc[index, 'sym'] = 'unchanged'
    # Create a text column for plotly hover labels
    unemp_list.loc[index,'text'] = '{}<br>{} Rate: {}% ({})'.format(
        unemp_list.loc[index,'MSA'], 
        date,
        unemp_list.loc[index,'value'],
        unemp_list.loc[index,'sym'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [sym] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-c33c1defcc29> in <module>()
#      21         date,
#      22         unemp_list.loc[index,'value'],
# ---> 23         unemp_list.loc[index,'sym'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     856     def _getitem_tuple(self, tup):
#     857         try:
# --> 858             return self._getitem_lowerdim(tup)
#     859         except IndexingError:
#     860             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#    1018                     return section
#    1019                 # This is an elided recursive call to iloc/loc/etc'
# -> 1020                 return getattr(section, self.name)[new_key]
#    1021
#    1022         raise IndexingError('not applicable')
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1624
#    1625         # fall thru to straight lookup
# -> 1626         self._has_valid_type(key, axis)
#    1627         return self._get_label(key, axis=axis)
#    1628
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1512                 raise
#    1513             except:
# -> 1514                 error()
#    1515
#    1516         return True
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1499                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#    1503             try:
#
# KeyError: 'the label [sym] is not in the [index]'

# %%
unemp_list
# Out:
#      index              fullcode       date  year period  value  \
# 0       36  LAUMT011150000000003 2018-01-01  2018    M01    4.7
# 1       73  LAUMT011222000000003 2018-01-01  2018    M01    3.7
# 2      110  LAUMT011382000000003 2018-01-01  2018    M01    3.7
# 3      147  LAUMT011930000000003 2018-01-01  2018    M01    4.0
# 4      184  LAUMT011946000000003 2018-01-01  2018    M01    4.0
# 5      221  LAUMT012002000000003 2018-01-01  2018    M01    4.3
# 6      258  LAUMT012252000000003 2018-01-01  2018    M01    4.7
# 7      295  LAUMT012346000000003 2018-01-01  2018    M01    4.3
# 8      332  LAUMT012662000000003 2018-01-01  2018    M01    3.6
# 9      369  LAUMT013366000000003 2018-01-01  2018    M01    5.0
# 10     406  LAUMT013386000000003 2018-01-01  2018    M01    4.0
# 11     443  LAUMT014622000000003 2018-01-01  2018    M01    3.9
# 12     480  LAUMT021126000000003 2018-01-01  2018    M01    7.2
# 13     517  LAUMT022182000000003 2018-01-01  2018    M01    7.5
# 14     554  LAUMT042238000000003 2018-01-01  2018    M01    6.3
# 15     591  LAUMT042942000000003 2018-01-01  2018    M01    6.4
# 16     628  LAUMT043806000000003 2018-01-01  2018    M01    4.5
# 17     665  LAUMT043914000000003 2018-01-01  2018    M01    4.9
# 18     702  LAUMT044342000000003 2018-01-01  2018    M01    6.2
# 19     739  LAUMT044606000000003 2018-01-01  2018    M01    4.7
# 20     776  LAUMT044974000000003 2018-01-01  2018    M01   14.6
# 21     813  LAUMT052222000000003 2018-01-01  2018    M01    3.2
# 22     850  LAUMT052290000000003 2018-01-01  2018    M01    4.7
# 23     887  LAUMT052630000000003 2018-01-01  2018    M01    4.7
# 24     924  LAUMT052786000000003 2018-01-01  2018    M01    3.8
# 25     961  LAUMT053078000000003 2018-01-01  2018    M01    3.8
# 26     998  LAUMT053822000000003 2018-01-01  2018    M01    5.7
# 27    1035  LAUMT061254000000003 2018-01-01  2018    M01    9.2
# 28    1072  LAUMT061702000000003 2018-01-01  2018    M01    5.6
# 29    1109  LAUMT062094000000003 2018-01-01  2018    M01   17.0
# ..     ...                   ...        ...   ...    ...    ...
# 361  13245  LAUMT531474000000003 2018-01-01  2018    M01    5.5
# 362  13282  LAUMT532842000000003 2018-01-01  2018    M01    7.4
# 363  13319  LAUMT533102000000003 2018-01-01  2018    M01    7.0
# 364  13356  LAUMT533458000000003 2018-01-01  2018    M01    6.3
# 365  13393  LAUMT533650000000003 2018-01-01  2018    M01    5.6
# 366  13430  LAUMT534266000000003 2018-01-01  2018    M01    4.7
# 367  13467  LAUMT534406000000003 2018-01-01  2018    M01    6.9
# 368  13504  LAUMT534746000000003 2018-01-01  2018    M01    6.3
# 369  13541  LAUMT534830000000003 2018-01-01  2018    M01    7.1
# 370  13578  LAUMT534942000000003 2018-01-01  2018    M01    9.4
# 371  13615  LAUMT541322000000003 2018-01-01  2018    M01    6.3
# 372  13652  LAUMT541662000000003 2018-01-01  2018    M01    5.7
# 373  13689  LAUMT542658000000003 2018-01-01  2018    M01    6.0
# 374  13726  LAUMT543406000000003 2018-01-01  2018    M01    4.4
# 375  13763  LAUMT543762000000003 2018-01-01  2018    M01    6.4
# 376  13800  LAUMT544854000000003 2018-01-01  2018    M01    6.7
# 377  13837  LAUMT551154000000003 2018-01-01  2018    M01    2.8
# 378  13874  LAUMT552074000000003 2018-01-01  2018    M01    3.2
# 379  13911  LAUMT552254000000003 2018-01-01  2018    M01    2.7
# 380  13948  LAUMT552458000000003 2018-01-01  2018    M01    3.0
# 381  13985  LAUMT552750000000003 2018-01-01  2018    M01    3.3
# 382  14022  LAUMT552910000000003 2018-01-01  2018    M01    3.0
# 383  14059  LAUMT553154000000003 2018-01-01  2018    M01    2.3
# 384  14096  LAUMT553334000000003 2018-01-01  2018    M01    3.0
# 385  14133  LAUMT553678000000003 2018-01-01  2018    M01    2.7
# 386  14170  LAUMT553954000000003 2018-01-01  2018    M01    3.7
# 387  14207  LAUMT554310000000003 2018-01-01  2018    M01    2.5
# 388  14244  LAUMT554814000000003 2018-01-01  2018    M01    2.7
# 389  14281  LAUMT561622000000003 2018-01-01  2018    M01    5.4
# 390  14318  LAUMT561694000000003 2018-01-01  2018    M01    4.3
#
#     footnote_codes month  day  value_ch  prevvalue              fullname  \
# 0                p    01    1       NaN        7.1          Anniston, AL
# 1                p    01    1       NaN        5.4            Auburn, AL
# 2                p    01    1       NaN        5.8        Birmingham, AL
# 3                p    01    1       NaN        6.0            Daphne, AL
# 4                p    01    1       NaN        6.3           Decatur, AL
# 5                p    01    1       NaN        6.2            Dothan, AL
# 6                p    01    1       NaN        7.3          Florence, AL
# 7                p    01    1       NaN        6.2           Gadsden, AL
# 8                p    01    1       NaN        5.4        Huntsville, AL
# 9                p    01    1       NaN        7.2            Mobile, AL
# 10               p    01    1       NaN        5.9        Montgomery, AL
# 11               p    01    1       NaN        6.1        Tuscaloosa, AL
# 12               p    01    1       2.5        6.2         Anchorage, AK
# 13               p    01    1       3.8        6.4         Fairbanks, AK
# 14               p    01    1       2.6        6.9         Flagstaff, AZ
# 15               p    01    1       2.4        7.6  Lake Havasu City, AZ
# 16               p    01    1       0.5        4.9           Phoenix, AZ
# 17               p    01    1       0.6        5.4          Prescott, AZ
# 18               p    01    1       1.5        6.8      Sierra Vista, AZ
# 19               p    01    1       0.4        5.1            Tucson, AZ
# 20               p    01    1      11.0       16.4              Yuma, AZ
# 21               p    01    1      -1.8        3.3      Fayetteville, AR
# 22               p    01    1       0.7        5.3        Fort Smith, AR
# 23               p    01    1       0.8        5.1       Hot Springs, AR
# 24               p    01    1      -3.4        4.2         Jonesboro, AR
# 25               p    01    1      -3.7        4.0       Little Rock, AR
# 26               p    01    1      -0.6        6.4        Pine Bluff, AR
# 27               p    01    1       2.8       11.1       Bakersfield, CA
# 28               p    01    1       1.1        7.5             Chico, CA
# 29               p    01    1      12.1       21.4         El Centro, CA
# ..             ...   ...  ...       ...        ...                   ...
# 361              p    01    1       2.5        5.9         Bremerton, WA
# 362              p    01    1       4.9        8.5         Kennewick, WA
# 363              p    01    1       3.0        8.1          Longview, WA
# 364              p    01    1       2.9        7.7      Mount Vernon, WA
# 365              p    01    1       2.1        6.3           Olympia, WA
# 366              p    01    1       0.3        5.0           Seattle, WA
# 367              p    01    1       3.1        7.7           Spokane, WA
# 368              p    01    1       2.6        7.2       Walla Walla, WA
# 369              p    01    1       3.4        8.5         Wenatchee, WA
# 370              p    01    1       5.4       11.1            Yakima, WA
# 371              p    01    1       2.9        8.6           Beckley, WV
# 372              p    01    1       0.0        6.8        Charleston, WV
# 373              p    01    1       0.5        7.3        Huntington, WV
# 374              p    01    1      -3.0        5.4        Morgantown, WV
# 375              p    01    1      -0.6        7.1       Parkersburg, WV
# 376              p    01    1       0.4        8.6          Wheeling, WV
# 377              p    01    1      -2.8        3.9          Appleton, WI
# 378              p    01    1      -1.5        4.7        Eau Claire, WI
# 379              p    01    1      -4.2        4.2       Fond du Lac, WI
# 380              p    01    1      -3.3        4.4         Green Bay, WI
# 381              p    01    1      -3.8        5.1        Janesville, WI
# 382              p    01    1      -6.4        4.5         La Crosse, WI
# 383              p    01    1      -4.0        3.4           Madison, WI
# 384              p    01    1      -2.7        4.7         Milwaukee, WI
# 385              p    01    1      -3.3        4.0           Oshkosh, WI
# 386              p    01    1      -0.7        5.5            Racine, WI
# 387              p    01    1      -3.9        3.8         Sheboygan, WI
# 388              p    01    1      -4.0        4.1            Wausau, WI
# 389              p    01    1       2.6        7.3            Casper, WY
# 390              p    01    1       1.1        5.1          Cheyenne, WY
#
#       latitude   longitude                                          area_code  \
# 0    33.695381  -85.839842  Anniston-Oxford-Jacksonville, AL Metropolitan ...
# 1    32.655091  -85.503643   Auburn-Opelika, AL Metropolitan Statistical Area
# 2    33.520682  -86.802432  Birmingham-Hoover, AL Metropolitan Statistical...
# 3    30.571851  -87.855586  Daphne-Fairhope-Foley, AL Metropolitan Statist...
# 4    34.624021  -87.057919          Decatur, AL Metropolitan Statistical Area
# 5    31.223231  -85.390489           Dothan, AL Metropolitan Statistical Area
# 6    34.799810  -87.677251  Florence-Muscle Shoals, AL Metropolitan Statis...
# 7    34.014380  -86.006668          Gadsden, AL Metropolitan Statistical Area
# 8    34.729847  -86.585901       Huntsville, AL Metropolitan Statistical Area
# 9    30.694357  -88.043054           Mobile, AL Metropolitan Statistical Area
# 10   32.366966  -86.300648       Montgomery, AL Metropolitan Statistical Area
# 11   33.266840  -87.486218       Tuscaloosa, AL Metropolitan Statistical Area
# 12   61.216313 -149.894852        Anchorage, AK Metropolitan Statistical Area
# 13   64.837845 -147.716675        Fairbanks, AK Metropolitan Statistical Area
# 14   35.199458 -111.651426        Flagstaff, AZ Metropolitan Statistical Area
# 15   34.474279 -114.344001  Lake Havasu City-Kingman, AZ Metropolitan Stat...
# 16   33.448587 -112.077346  Phoenix-Mesa-Scottsdale, AZ Metropolitan Stati...
# 17   34.540281 -112.469507         Prescott, AZ Metropolitan Statistical Area
# 18   31.554540 -110.303693  Sierra Vista-Douglas, AZ Metropolitan Statisti...
# 19   32.221742 -110.926476           Tucson, AZ Metropolitan Statistical Area
# 20   32.665135 -114.476031             Yuma, AZ Metropolitan Statistical Area
# 21   36.062584  -94.157433  Fayetteville-Springdale-Rogers, AR-MO Metropol...
# 22   35.387222  -94.424898    Fort Smith, AR-OK Metropolitan Statistical Area
# 23   34.448065  -93.046850      Hot Springs, AR Metropolitan Statistical Area
# 24   35.842865  -90.703452        Jonesboro, AR Metropolitan Statistical Area
# 25   34.746481  -92.289595  Little Rock-North Little Rock-Conway, AR Metro...
# 26   34.228431  -92.003195       Pine Bluff, AR Metropolitan Statistical Area
# 27   35.373871 -119.019464      Bakersfield, CA Metropolitan Statistical Area
# 28   39.728495 -121.837478            Chico, CA Metropolitan Statistical Area
# 29   32.792000 -115.563051        El Centro, CA Metropolitan Statistical Area
# ..         ...         ...                                                ...
# 361  47.532797 -122.754161  Bremerton-Silverdale, WA Metropolitan Statisti...
# 362  46.211246 -119.137234  Kennewick-Richland, WA Metropolitan Statistica...
# 363  46.142730 -122.955641         Longview, WA Metropolitan Statistical Area
# 364  48.420046 -122.326420  Mount Vernon-Anacortes, WA Metropolitan Statis...
# 365  47.045020 -122.894872  Olympia-Tumwater, WA Metropolitan Statistical ...
# 366  47.603832 -122.330062  Seattle-Tacoma-Bellevue, WA Metropolitan Stati...
# 367  47.658860 -117.424713  Spokane-Spokane Valley, WA Metropolitan Statis...
# 368  46.065000 -118.330278      Walla Walla, WA Metropolitan Statistical Area
# 369  47.423460 -120.310349        Wenatchee, WA Metropolitan Statistical Area
# 370  46.601557 -120.510842           Yakima, WA Metropolitan Statistical Area
# 371  37.778170  -81.188156          Beckley, WV Metropolitan Statistical Area
# 372  38.350599  -81.633281       Charleston, WV Metropolitan Statistical Area
# 373  38.419250  -82.445154  Huntington-Ashland, WV-KY-OH Metropolitan Stat...
# 374  39.629681  -79.955944       Morgantown, WV Metropolitan Statistical Area
# 375  39.269956  -81.550691  Parkersburg-Vienna, WV Metropolitan Statistica...
# 376  40.063962  -80.720915      Wheeling, WV-OH Metropolitan Statistical Area
# 377  44.261134  -88.406760         Appleton, WI Metropolitan Statistical Area
# 378  44.811349  -91.498494       Eau Claire, WI Metropolitan Statistical Area
# 379  43.774876  -88.445803      Fond du Lac, WI Metropolitan Statistical Area
# 380  44.529941  -88.024832        Green Bay, WI Metropolitan Statistical Area
# 381  42.715185  -88.990774  Janesville-Beloit, WI Metropolitan Statistical...
# 382  43.801356  -91.239581  La Crosse-Onalaska, WI-MN Metropolitan Statist...
# 383  43.074761  -89.383761          Madison, WI Metropolitan Statistical Area
# 384  43.034993  -87.922497  Milwaukee-Waukesha-West Allis, WI Metropolitan...
# 385  44.020692  -88.540857   Oshkosh-Neenah, WI Metropolitan Statistical Area
# 386  42.726052  -87.782524           Racine, WI Metropolitan Statistical Area
# 387  43.750828  -87.714530        Sheboygan, WI Metropolitan Statistical Area
# 388  44.959602  -89.629824           Wausau, WI Metropolitan Statistical Area
# 389  42.866632 -106.313081           Casper, WY Metropolitan Statistical Area
# 390  41.139981 -104.820246         Cheyenne, WY Metropolitan Statistical Area
#
#                                               MSA
# 0            Anniston-Oxford-Jacksonville, AL MSA
# 1                          Auburn-Opelika, AL MSA
# 2                       Birmingham-Hoover, AL MSA
# 3                   Daphne-Fairhope-Foley, AL MSA
# 4                                 Decatur, AL MSA
# 5                                  Dothan, AL MSA
# 6                  Florence-Muscle Shoals, AL MSA
# 7                                 Gadsden, AL MSA
# 8                              Huntsville, AL MSA
# 9                                  Mobile, AL MSA
# 10                             Montgomery, AL MSA
# 11                             Tuscaloosa, AL MSA
# 12                              Anchorage, AK MSA
# 13                              Fairbanks, AK MSA
# 14                              Flagstaff, AZ MSA
# 15               Lake Havasu City-Kingman, AZ MSA
# 16                Phoenix-Mesa-Scottsdale, AZ MSA
# 17                               Prescott, AZ MSA
# 18                   Sierra Vista-Douglas, AZ MSA
# 19                                 Tucson, AZ MSA
# 20                                   Yuma, AZ MSA
# 21      Fayetteville-Springdale-Rogers, AR-MO MSA
# 22                          Fort Smith, AR-OK MSA
# 23                            Hot Springs, AR MSA
# 24                              Jonesboro, AR MSA
# 25   Little Rock-North Little Rock-Conway, AR MSA
# 26                             Pine Bluff, AR MSA
# 27                            Bakersfield, CA MSA
# 28                                  Chico, CA MSA
# 29                              El Centro, CA MSA
# ..                                            ...
# 361                  Bremerton-Silverdale, WA MSA
# 362                    Kennewick-Richland, WA MSA
# 363                              Longview, WA MSA
# 364                Mount Vernon-Anacortes, WA MSA
# 365                      Olympia-Tumwater, WA MSA
# 366               Seattle-Tacoma-Bellevue, WA MSA
# 367                Spokane-Spokane Valley, WA MSA
# 368                           Walla Walla, WA MSA
# 369                             Wenatchee, WA MSA
# 370                                Yakima, WA MSA
# 371                               Beckley, WV MSA
# 372                            Charleston, WV MSA
# 373              Huntington-Ashland, WV-KY-OH MSA
# 374                            Morgantown, WV MSA
# 375                    Parkersburg-Vienna, WV MSA
# 376                           Wheeling, WV-OH MSA
# 377                              Appleton, WI MSA
# 378                            Eau Claire, WI MSA
# 379                           Fond du Lac, WI MSA
# 380                             Green Bay, WI MSA
# 381                     Janesville-Beloit, WI MSA
# 382                 La Crosse-Onalaska, WI-MN MSA
# 383                               Madison, WI MSA
# 384         Milwaukee-Waukesha-West Allis, WI MSA
# 385                        Oshkosh-Neenah, WI MSA
# 386                                Racine, WI MSA
# 387                             Sheboygan, WI MSA
# 388                                Wausau, WI MSA
# 389                                Casper, WY MSA
# 390                              Cheyenne, WY MSA
#
# [391 rows x 16 columns]

# %% [markdown]
# #### Plotly code

# %%
trace1 = {
  "geo": "geo", 
  "hoverinfo": "text", 
  "lat": unemp_list['latitude'], 
  "lon": unemp_list['longitude'], 
  "marker": {
    "color": unemp_list['color'], 
    "line": {
      "color": "#202020", 
      "width": 0.8
    }, 
    "opacity": 0.5, 
    "size": unemp_list['size'], 
    "symbol": "circle"
  }, 
  "mode": "markers", 
  "name": "Unemployment Rate Change by Metro Area", 
  "opacity": 1, 
  "showlegend": True, 
  "text": unemp_list['text'], 
  "type": "scattergeo", 
  "visible": True
}
data = Data([trace1])
layout = {
  "annotations": [
    {
      "x": 0.05, 
      "y": 0.925, 
      "align": "left", 
      "font": {"size": 14}, 
      "showarrow": False, 
      "text": "<b>Change in Unemployment Rate by Metropolitan Statistical Area (MSA)</b><br><i>Change over level in same month of previous year, as of {}</i>".format(date), 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 0.05, 
      "y": 0.0725, 
      "align": "left", 
      "showarrow": False, 
      "text": "Hover to see details. Green is decrease in unemployment rate, red is increase. Circle size shows amount of change.  <br><b>Source:</b> U.S. Bureau of Labor Statistics, Local Area Unemployment Statistics", 
      "xref": "x", 
      "yref": "y"
    }
  ], 
  "autosize": True, 
  "dragmode": "zoom", 
  "geo": {
    "bgcolor": "#fff", 
    "countrycolor": "#808080", 
    "countrywidth": 0.7, 
    "domain": {
      "x": [0, 1.1], 
      "y": [0, 1.1]
    }, 
    "lataxis": {
      "dtick": 10, 
      "range": [20, 80], 
      "showgrid": False, 
      "tick0": 20
    }, 
    "lonaxis": {
      "dtick": 30, 
      "range": [-180, -50], 
      "showgrid": False, 
      "tick0": -180
    }, 
    "projection": {
      "scale": 1.03, 
      "type": "albers usa"
    }, 
    "resolution": 50, 
    "scope": "usa", 
    "showcountries": False, 
    "showlakes": False, 
    "showland": False, 
    "showrivers": False, 
    "showsubunits": True, 
    "subunitcolor": "#808080", 
    "subunitwidth": 0.7
  }, 
  "hidesources": False, 
  "hovermode": "closest", 
  "paper_bgcolor": "#fff", 
  "separators": ".,", 
  "showlegend": False, 
  "smith": False, 
  "margin": {
    "r": 0, 
    "t": 0, 
    "b": 0, 
    "l": 0
  },
}
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig, filename='MSA_Map')

# %% [markdown]
# #### Generate an html table of results

# %%
# generate html table with data
table = unemp_list[['MSA', 'value', 'value_ch']]
table.columns = ['Metropolitan Statistical Area (MSA) Name', 'Unemp. rate', 'One-year change']
table = table.sort_values('One-year change').drop_duplicates() 
# Sortable css class allows for js script to sort each column
# https://www.kryogenix.org/code/browser/sorttable/
table.to_html('C:/Working/bdecon.github.io/Dash/unemp_table.html', border=0, 
              index=False, classes='sortable')
