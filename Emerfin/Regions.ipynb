# %%
import requests

url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/DataStructure/IFS'
code_list = requests.get(url).json()['Structure']['CodeLists']['CodeList']
#for code in code_list:
#	print '{}: {}'.format(code['Description']['#text'], code['@value'])

# %%
code_list[2]['Code']
# Out:
# [{u'@value': u'AF',
#   u'Annotations': {u'Annotation': [{u'@xmlns': u'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#      u'AnnotationText': {u'#text': u'Afghanistan, Islamic Republic of',
#       u'@xml:lang': u'en'},
#      u'AnnotationTitle': u'Name'},
#     {u'@xmlns': u'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#      u'AnnotationText': {u'#text': u'512', u'@xml:lang': u'en'},
#      u'AnnotationTitle': u'Code'},
#     {u'@xmlns': u'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#      u'AnnotationText': {u'#text': u'512', u'@xml:lang': u'en'},
#      u'AnnotationTitle': u'Source Code'},
#     {u'@xmlns': u'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#      u'AnnotationText': {u'#text': u'Afghanistan, I.R. of',
#       u'@xml:lang': u'en'},
#      u'AnnotationTitle': u'Short Name'},
#     {u'@xmlns': u'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
# ...

# %%
import pandas as pd

# %%
codes = pd.read_csv('https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv')

# %%
cty_reg_map = codes[['alpha-2', 'region']].set_index('alpha-2').dropna()
cty_reg_map.replace('Oceania', 'Asia')

# %%
cty_reg_map.replace('Oceania', 'Asia')
# Out:
#            region
# alpha-2
# AF           Asia
# AX         Europe
# AL         Europe
# DZ         Africa
# AS           Asia
# AD         Europe
# AO         Africa
# AI       Americas
# AG       Americas
# AR       Americas
# AM           Asia
# AW       Americas
# AU           Asia
# AT         Europe
# AZ           Asia
# BS       Americas
# BH           Asia
# BD           Asia
# BB       Americas
# BY         Europe
# BE         Europe
# BZ       Americas
# BJ         Africa
# BM       Americas
# BT           Asia
# BO       Americas
# BQ       Americas
# BA         Europe
# BW         Africa
# BR       Americas
# ...           ...
# TJ           Asia
# TZ         Africa
# TH           Asia
# TL           Asia
# TG         Africa
# TK           Asia
# TO           Asia
# TT       Americas
# TN         Africa
# TR           Asia
# TM           Asia
# TC       Americas
# TV           Asia
# UG         Africa
# UA         Europe
# AE           Asia
# GB         Europe
# ...

# %%
import requests # Python 2.7, requests version 2.12.4

url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/'
key = 'CompactData/IFS/Q.1C_903.NGDP_R_PT' # adjust codes here
data = requests.get('{}{}'.format(url,key)).json()
data['CompactData']['DataSet']['Series']['Obs'][-1]
# Out:
# {u'@OBS_VALUE': u'3.87079321473639', u'@TIME_PERIOD': u'2016-Q1'}
