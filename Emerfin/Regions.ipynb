# %%
import requests

url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/CodeList/CL_AREA_IFS'
code_list = requests.get(url).json()['Structure']['CodeLists']['CodeList']['Code']
for code in code_list:
	print '{}: {}'.format(code['Description']['#text'], code['@value'])
# Out:
# Afghanistan: AF
# Albania: AL
# Algeria: DZ
# American Samoa: AS
# Angola: AO
# Anguilla: AI
# Antigua and Barbuda: AG
# AMF (Arab Monetary Fund): 5M
# Argentina: AR
# Armenia: AM
# Aruba: AW
# Australia: AU
# Austria: AT
# Azerbaijan: AZ
# Bahamas: BS
# Bahrain: BH
# Bangladesh: BD
# BEAC (Banque des Etats de l`Afrique Centrale): 5W
# BIS (Bank for International Settlements): 5B
# Barbados: BB
# Belarus: BY
# Belgium: BE
# Belgo-Luxembourg Economic Union: R1
# Belize: BZ
# Benin: BJ
# Bermuda: BM
# Bhutan: BT
# Bolivia: BO
# Bosnia and Herzegovina: BA
# Botswana: BW
# Brazil: BR
# Brunei Darussalam: BN
# Bulgaria: BG
# Burkina Faso: BF
# Burundi: BI
# Cape Verde: CV
# Cambodia: KH
# Cameroon: CM
# Canada: CA
# Cayman Islands: KY
# Central African Republic: CF
# Central Bank West Africa: 1C_752
# Chad: TD
# Chile: CL
# Hong Kong, China: HK
# Macao: MO
# China: CN
# Colombia: CO
# Comoros: KM
# Congo, the Democratic Republic of the: CD
# Congo: CG
# Cook Islands: CK
# Costa Rica: CR
# ...

# %%
import requests # Python 2.7, requests version 2.12.4

url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/'
key = 'CompactData/IFS/Q.1C_903.NGDP_R_PT' # adjust codes here
data = requests.get('{}{}'.format(url,key)).json()
data['CompactData']['DataSet']['Series']['Obs'][-1]
# Out:
# {u'@OBS_VALUE': u'3.87079321473639', u'@TIME_PERIOD': u'2016-Q1'}
