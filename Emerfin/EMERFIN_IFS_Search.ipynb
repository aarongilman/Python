# %% [markdown]
# # EMERFIN_IFS_Search.ipynb
#
# Find the best IFS indicators to cover a list of countries and search terms.
#
# Resources:
# * [JSON RESTful Web Service](http://datahelp.imf.org/knowledgebase/articles/667681-using-json-restful-web-service)
# * [Data Services News](http://data.imf.org/?sk=A329021F-1ED6-4D6E-B719-5BF5413923B6)
#
# -----------------------------------------------------------------------------------------------------------------
#
# Import packages and obtain metadata dict

# %%
import requests     # requests.get('source') method retrieves data from source
import time         # used to pace API requests and avoid disconnection

source = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/DataStructure/IFS'
metafull = (requests.get(source).json()['Structure']['CodeLists']['CodeList'])
items_to_collect = {'areas': 'CL_AREA_IFS', 'units': 'CL_UNIT_MULT'}
name_vars = ('Short Name', 'Full Name', 'Concept', 'Unit', 'Topic')

metadata = {}
for item, code in items_to_collect.items():
    # use item code to filter data_structure result
    item_to_collect = [sub['Code'] for sub in metafull
                       if sub['@id'] == code][0]
    metadata[item] = {
    # Obtain metadata {code: description} from DataStructure method        
        subitem['@value']: subitem['Description']['#text']
        for subitem in item_to_collect
    }

# Collect metadata for indicators separately
meta_indicators = [sub['Code'] for sub in metafull
                   if sub['@id'] == 'CL_INDICATOR_IFS'][0]
metadata['indicators'] = {
    indic['@value']: {
        'Description': indic['Description']['#text']
        } for indic in meta_indicators
}
name_vars = {'Short':2,'Full':3,'Concept':5,'Unit_Name':7,'Topic':8}
for indic in meta_indicators:
    for var, loc in name_vars.items():
        try: 
            metadata['indicators'][indic['@value']][var] = (
            indic['Annotations']['Annotation'][loc]['AnnotationText']['#text'])
        except KeyError:
            continue

# %% [markdown]
# Define variables to use in data API request

# %%
# Terms to use to filter the descriptions of IFS indicators.
filter_terms = ['Equities', 'Industrial Production', 'Interest Rate', 'Price Ind',
                'Gross Domestic Product', 'Employ', 'Services, Net', 'Rice', 'Soy',
                'Iron', 'Energy', 'Nickel']
filtered_inds = [code for code, descr in metadata['indicators'].items()
                 if any([f_term in descr['Description'] for f_term in filter_terms])]

# ISO2 codes--IFS also contains regional aggregates with IMF specific codes
country_list = ['BR', 'RU', 'ZA', 'MX', 'TR']
cty_list = '+'.join(country_list)  # formatted for API requests

date_lim = '?startPeriod=2014'

# Location of actual IFS data (rather than metadata)
data_src = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/IFS/'

# %%
filtered_inds
# Out:
# [u'FID_PA',
#  u'LCM_IX',
#  u'FIGB_PA',
#  u'PZPINRG_IX',
#  u'AIP_PC_CP_A_PT',
#  u'FIMM_FX_PA',
#  u'FPEMF_IX',
#  u'LEMI_SA_IX',
#  u'NGDP_R_SA_IX',
#  u'AIPMI_IX',
#  u'PZPINGAS_USD_MBTU_RATE',
#  u'FILIBOR_6M_PA',
#  u'FPOLM_PA',
#  u'PZPINGAS_TYPE3_USD_MBTU_RATE',
#  u'PZPIOIL_Type3_USD_BBL_RATE',
#  u'GBECE_G01_CA_USD',
#  u'NGDP_R_SA_AR_XDC',
#  u'PZPINICK_USD_TN_RATE',
#  u'NGDP_D_SA_IX',
#  u'FILIBOR_ON_PA',
#  u'FIMM_PA',
#  u'PZPICL_USD_TN_RATE',
#  u'PPPIHIG_IX',
#  u'LOCNSH_EOP_IX',
#  u'NGDP_D_IX',
#  u'PZPIOIL_TYPE1_USD_BBL_RATE',
#  u'NGDP_R_AR_XDC',
#  u'GCECE_G01_CA_XDC',
#  u'NGDP_R_XDC',
#  u'AIMIGOLD_SA_IX',
#  u'FITB_PA',
#  u'AIPMA_IX',
#  u'PZPIRIN_IX',
#  u'FPEI_IX',
#  u'FILR_FX_PA',
#  u'PZPISOIL_IX',
#  u'FPESP_IX',
#  u'GGECE_G01_AC_XDC',
#  u'PZPISMEA_IX',
#  u'FPE_IX',
#  u'PPPI_IX',
#  u'FPEPFTSE100_IX',
#  u'PZPIFE_USD_TN_RATE',
#  u'FPEPNASC_IX',
#  u'NGDP_SA_AR_XDC',
#  u'NGDP_R_SA_XDC',
#  u'TXGSOYB_R_FOB_IX',
#  u'NGDP_R_IX',
#  u'AIPMA_SA_IX',
#  u'NGDP_AR_XDC',
#  u'GCECE_G01_AC_EUR',
#  u'GBECE_G01_AC_EUR',
#  u'PZPISMEA_USD_TN_RATE',
#  u'FIDR_FX_PA',
#  u'PZPICL_TYPE2_IX',
#  u'PZPIOIL_USD_BBL_RATE',
#  u'TXGRIN_D_USD_TN_FOB_RATE',
#  u'FILIBOR_1M_PA',
#  u'PCPI_PC_CP_A_PT',
#  u'FPEPSP_IX',
#  u'NGDP_EUR',
#  u'PPPI_PC_PP_PT',
#  u'NGDP_D_PC_CP_A_PT',
#  u'FIR_PA',
#  u'GBECE_G01_AC_XDC',
#  u'PXP_IX',
#  u'NGDP_F_XDC',
#  u'GCECE_G01_CA_USD',
#  u'NGDP_SA_XDC',
#  u'GCECE_G01_AC_XDC',
#  u'FISR_FX_PA',
#  u'PPPICE_IX',
#  u'AIPMI_SA_IX',
#  u'FIGB_MLT_PA',
#  u'GBECE_G01_AC_USD',
#  u'PZPIOIL_TYPE2_IX',
#  u'FIDR_PA',
#  u'PZPIOIL_IX',
#  u'PZPINGAS_USD_1000MC_RATE',
#  u'PZPIOIL_TYPE2_USD_BBL_RATE',
#  u'FPEI_EOP_IX',
#  u'GCECE_G01_CA_EUR',
#  u'FILIBOR_3M_PA',
#  u'FID_FX_PA',
#  u'PPPII_IX',
#  u'LE_PE_NUM',
#  u'NGDP_R_SA_EUR',
#  u'PZPISOIL_USD_TN_RATE',
#  u'PZPISOYB_IX',
#  u'NGDP_R_F_XDC',
#  u'PCPI_IX',
#  u'AIMIGOLD_IX',
#  u'FITB_IX',
#  u'TXGSOYB_D_FOB_IX',
#  u'PZPINICK_IX',
#  u'FIRA_PA',
#  u'FIEURIBOR_6M_PA',
#  u'FISR_PA',
#  u'PZPIFE_USC_DMT_RATE',
#  u'FPEPWIG20_EOP_IX',
#  u'PZPIFE_IX',
#  u'PZPIRIN_USD_TN_RATE',
#  u'FPEFR_EOP_IX',
#  u'PZPIGASO_USC_GAL_RATE',
#  u'BGS_BP6_USD',
#  u'NGDP_R_CH_SA_AR_XDC',
#  u'FILIBOR_1Y_PA',
#  u'PZPICL_TYPE2_USD_TN_RATE',
#  u'FIEURIBOR_3M_PA',
#  u'CPRPTT01_IX',
#  u'PMP_IX',
#  u'AIP_SA_IX',
#  u'ENEER_IX',
#  u'AIMICU_IX',
#  u'FILR_PA',
#  u'GGECE_G01_AC_USD',
#  u'PZPINGAS_TYPE2_USD_MBTU_RATE',
#  u'TXGSOYB_USD',
#  u'GCECE_G01_AC_USD',
#  u'FPEPWIG20_IX',
#  u'AIPME_IX',
#  u'FPEPAMEX_IX',
#  u'TXGRIN_FOB_XDC',
#  u'PZPINGAS_TYPE2_USD_TMC_RATE',
#  u'FITB_3M_PA',
#  u'GGECE_G01_CA_XDC',
#  u'PPPIFG_IX',
#  u'FPEPRTS_IX',
#  u'PPPIAM_IX',
#  u'GGECE_G01_AC_EUR',
#  u'LEMA_IX',
#  u'FISDR_PA',
#  u'PZPICL_TYPE1_IX',
#  u'AIPMMOR_IX',
#  u'GBECE_G01_CA_XDC',
#  u'PPPI_PC_CP_A_PT',
#  u'FIGB_S_PA',
#  u'AIP_IX',
#  u'NGDP_R_PT',
#  u'NGDP_XDC',
#  u'TXGRIN_R_FOB_IX',
#  u'EREER_WPI_IX',
#  u'PZPIOIL_TYPE1_IX',
#  u'PCPI_PC_PP_PT',
#  u'PZPINGAS_TYPE3_IX',
#  u'PPPIIRM_IX',
#  u'LEMA_SA_IX',
#  u'AIPMMOC_IX',
#  u'PZPIOIL_Type3_IX',
#  u'GBECE_G01_CA_EUR',
#  u'GGECE_G01_CA_EUR',
#  u'NGDP_R_EUR',
#  u'PZPIGASO_IX',
#  u'PZPINGAS_TYPE2_IX',
#  u'BGS_USD',
#  u'GGECE_G01_CA_USD',
#  u'FITB_FX_PA',
#  u'PWPI_IX',
#  u'NGDP_USD',
#  u'NGDP_SA_EUR',
#  u'PZPINGAS_TYPE3_USD_1000MC_RATE',
#  u'TXGRIN_D_FOB_IX',
#  u'FPEMN_IX',
#  u'EREER_IX',
#  u'PCPIHA_IX',
#  u'FPEF_EOP_IX',
#  u'PZPISOYB_USD_TN_RATE']

# %% [markdown]
# Make request to data API and save nonblank series to list

# %%
# One indicator at a time, full list with valid results from throwing all
# combinations of countries and filtered indicators at the API
valid_series = []
for filt_ind in filtered_inds:
    data_url = '{}.{}.{}.{}'.format(data_src, cty_list, filt_ind, date_lim)
    data = requests.get(data_url).json()['CompactData']['DataSet']
    if 'Series' in data.keys():         # Check if data contain series
        for series in data['Series']:
            if 'Obs' in series.keys():  # Check if series contain observations
                valid_series.append(series)
    time.sleep(0.5)   # Delay requests slightly so server does not block them

# %% [markdown]
# Use pandas to build table of best indicators

# %%
import pandas as pd  # Pandas to organize results and export to csv

df = pd.DataFrame(valid_series).iloc[:,0:5]
valid_series = None  # clear the extra data from memory
# We prefer more frequent data, and give it a higher score in the sort
df['Freq'] = df['@FREQ'].replace({'M':2, 'Q':1, 'A':0})
df = df.sort_values(['@INDICATOR', '@REF_AREA', 'Freq']).drop_duplicates(
    ['@INDICATOR', '@REF_AREA'], keep='last').reset_index(drop=True)
df['Country'] = df['@REF_AREA'].map(metadata['areas'])
df['Units'] = df[df['@UNIT_MULT']!='0']['@UNIT_MULT'].map(metadata['units'])
# Merge in metadata from indicator level 
meta_df = pd.DataFrame(metadata['indicators']).T
df = pd.concat([df.set_index('@INDICATOR'), meta_df], axis=1, join='inner')
# Generate more clear/specific measures for each series
df['Category'] = df['Full'].str.split(',', expand=True, n=1)[0]
df['Y_Label'] = df['Unit_Name'].str.cat(df['Units'], sep=', ').fillna(df['Unit_Name'])
df['Combined'] = df['@FREQ'].str.cat([df['@REF_AREA'], df.index], sep='.')
df['Chart_Title'] = df['Description'].str.rsplit(',', expand=True, n=1)[0]

# %%
Group_dict = {
    'National Accounts':'1-National Accounts',
    'Labor Markets':'2-Labor Markets',
    'Social Indicators':'2-Labor Markets',
    'Economic Activity':'3-Economic Activity',
    'Producer Price Index':'4-Prices',
    'Consumer Prices':'4-Prices',
    'Prices':'4-Prices',
    'Balance of Payments':'5-Balance of Payments',
    'Exchange Rates':'6-Exchange Rates',
    'Financial':'7-Interest Rates',
    'Financial Market Prices': '8-Equities'
}
df['Group'] = df['Category'].map(Group_dict)
df.index.name = '@INDICATOR'
df = df.reset_index().set_index('Combined')

# %%
df
# Out:
#                  @FREQ @REF_AREA @TIME_FORMAT @UNIT_MULT  Freq  \
# AIMIGOLD_SA_IX       M        ZA          P1M          0     2
# AIPMA_IX             M        MX          P1M          0     2
# AIPMA_SA_IX          M        ZA          P1M          0     2
# AIPMI_IX             M        MX          P1M          0     2
# AIPMI_SA_IX          M        ZA          P1M          0     2
# AIPMMOC_IX           M        MX          P1M          0     2
# AIP_IX               M        MX          P1M          0     2
# AIP_IX               M        RU          P1M          0     2
# AIP_IX               M        TR          P1M          0     2
# AIP_SA_IX            M        BR          P1M          0     2
# AIP_SA_IX            M        MX          P1M          0     2
# AIP_SA_IX            M        TR          P1M          0     2
# BGS_BP6_USD          Q        BR          P3M          6     1
# BGS_BP6_USD          Q        MX          P3M          6     1
# BGS_BP6_USD          Q        RU          P3M          6     1
# BGS_BP6_USD          Q        TR          P3M          6     1
# BGS_BP6_USD          Q        ZA          P3M          6     1
# ENEER_IX             M        BR          P1M          0     2
# ENEER_IX             M        MX          P1M          0     2
# ENEER_IX             M        RU          P1M          0     2
# ENEER_IX             M        ZA          P1M          0     2
# EREER_IX             M        BR          P1M          0     2
# EREER_IX             M        MX          P1M          0     2
# EREER_IX             M        RU          P1M          0     2
# EREER_IX             M        ZA          P1M          0     2
# FIDR_PA              M        BR          P1M          0     2
# FIDR_PA              M        MX          P1M          0     2
# FIDR_PA              M        RU          P1M          0     2
# FIDR_PA              M        TR          P1M          0     2
# FIDR_PA              M        ZA          P1M          0     2
# ...                ...       ...          ...        ...   ...
# NGDP_R_PT            Q        ZA          P3M          0     1
# NGDP_R_SA_AR_XDC     Q        MX          P3M          9     1
# NGDP_R_SA_AR_XDC     Q        ZA          P3M          6     1
# NGDP_R_SA_IX         Q        MX          P3M          0     1
# NGDP_R_SA_IX         Q        ZA          P3M          0     1
# NGDP_R_XDC           Q        BR          P3M          6     1
# NGDP_R_XDC           Q        RU          P3M          9     1
# NGDP_R_XDC           Q        TR          P3M          6     1
# NGDP_SA_AR_XDC       Q        MX          P3M          9     1
# NGDP_SA_AR_XDC       Q        ZA          P3M          6     1
# NGDP_XDC             Q        BR          P3M          6     1
# NGDP_XDC             Q        RU          P3M          9     1
# NGDP_XDC             Q        TR          P3M          6     1
# PCPI_IX              M        BR          P1M          0     2
# PCPI_IX              M        MX          P1M          0     2
# PCPI_IX              M        RU          P1M          0     2
# PCPI_IX              M        TR          P1M          0     2
# PCPI_IX              M        ZA          P1M          0     2
# PCPI_PC_CP_A_PT      M        BR          P1M          0     2
# PCPI_PC_CP_A_PT      M        MX          P1M          0     2
# PCPI_PC_CP_A_PT      M        RU          P1M          0     2
# PCPI_PC_CP_A_PT      M        TR          P1M          0     2
# PCPI_PC_CP_A_PT      M        ZA          P1M          0     2
# PMP_IX               M        MX          P1M          0     2
# PPPI_IX              M        BR          P1M          0     2
# PPPI_IX              M        MX          P1M          0     2
# PPPI_IX              M        TR          P1M          0     2
# PPPI_IX              M        ZA          P1M          0     2
# PPPI_PC_PP_PT        M        RU          P1M          0     2
# PXP_IX               M        MX          P1M          0     2
#
#                              Country     Units  \
# AIMIGOLD_SA_IX          South Africa       NaN
# AIPMA_IX                      Mexico       NaN
# AIPMA_SA_IX             South Africa       NaN
# AIPMI_IX                      Mexico       NaN
# AIPMI_SA_IX             South Africa       NaN
# AIPMMOC_IX                    Mexico       NaN
# AIP_IX                        Mexico       NaN
# AIP_IX            Russian Federation       NaN
# AIP_IX                        Turkey       NaN
# AIP_SA_IX                     Brazil       NaN
# AIP_SA_IX                     Mexico       NaN
# AIP_SA_IX                     Turkey       NaN
# BGS_BP6_USD                   Brazil  Millions
# BGS_BP6_USD                   Mexico  Millions
# BGS_BP6_USD       Russian Federation  Millions
# BGS_BP6_USD                   Turkey  Millions
# BGS_BP6_USD             South Africa  Millions
# ENEER_IX                      Brazil       NaN
# ENEER_IX                      Mexico       NaN
# ENEER_IX          Russian Federation       NaN
# ENEER_IX                South Africa       NaN
# EREER_IX                      Brazil       NaN
# EREER_IX                      Mexico       NaN
# EREER_IX          Russian Federation       NaN
# EREER_IX                South Africa       NaN
# FIDR_PA                       Brazil       NaN
# FIDR_PA                       Mexico       NaN
# FIDR_PA           Russian Federation       NaN
# FIDR_PA                       Turkey       NaN
# FIDR_PA                 South Africa       NaN
# ...                              ...       ...
# NGDP_R_PT               South Africa       NaN
# NGDP_R_SA_AR_XDC              Mexico  Billions
# NGDP_R_SA_AR_XDC        South Africa  Millions
# NGDP_R_SA_IX                  Mexico       NaN
# NGDP_R_SA_IX            South Africa       NaN
# NGDP_R_XDC                    Brazil  Millions
# NGDP_R_XDC        Russian Federation  Billions
# NGDP_R_XDC                    Turkey  Millions
# NGDP_SA_AR_XDC                Mexico  Billions
# NGDP_SA_AR_XDC          South Africa  Millions
# NGDP_XDC                      Brazil  Millions
# NGDP_XDC          Russian Federation  Billions
# NGDP_XDC                      Turkey  Millions
# PCPI_IX                       Brazil       NaN
# PCPI_IX                       Mexico       NaN
# PCPI_IX           Russian Federation       NaN
# PCPI_IX                       Turkey       NaN
# PCPI_IX                 South Africa       NaN
# PCPI_PC_CP_A_PT               Brazil       NaN
# PCPI_PC_CP_A_PT               Mexico       NaN
# PCPI_PC_CP_A_PT   Russian Federation       NaN
# PCPI_PC_CP_A_PT               Turkey       NaN
# PCPI_PC_CP_A_PT         South Africa       NaN
# PMP_IX                        Mexico       NaN
# PPPI_IX                       Brazil       NaN
# PPPI_IX                       Mexico       NaN
# PPPI_IX                       Turkey       NaN
# PPPI_IX                 South Africa       NaN
# PPPI_PC_PP_PT     Russian Federation       NaN
# PXP_IX                        Mexico       NaN
#
#                                                             Concept  \
# AIMIGOLD_SA_IX                 Gold Production, Seasonally adjusted
# AIPMA_IX                                              Manufacturing
# AIPMA_SA_IX       Industrial Production, Manufacturing, Seasonal...
# AIPMI_IX                              Industrial Production, Mining
# AIPMI_SA_IX                             Mining, Seasonally adjusted
# AIPMMOC_IX        Industrial Production, Manufacturing, Non-dura...
# AIP_IX                                        Industrial Production
# AIP_IX                                        Industrial Production
# AIP_IX                                        Industrial Production
# AIP_SA_IX                Industrial Production, Seasonally adjusted
# AIP_SA_IX                Industrial Production, Seasonally adjusted
# AIP_SA_IX                Industrial Production, Seasonally adjusted
# BGS_BP6_USD                  Current Acct., Goods and Services, Net
# BGS_BP6_USD                  Current Acct., Goods and Services, Net
# BGS_BP6_USD                  Current Acct., Goods and Services, Net
# BGS_BP6_USD                  Current Acct., Goods and Services, Net
# BGS_BP6_USD                  Current Acct., Goods and Services, Net
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# FIDR_PA                                                Deposit Rate
# FIDR_PA                                                Deposit Rate
# FIDR_PA                                                Deposit Rate
# FIDR_PA                                                Deposit Rate
# FIDR_PA                                                Deposit Rate
# ...                                                             ...
# NGDP_R_PT                              Gross Domestic Product, Real
# NGDP_R_SA_AR_XDC  Gross Domestic Product, Real, Seasonally Adjus...
# NGDP_R_SA_AR_XDC  Gross Domestic Product, Real, Seasonally Adjus...
# NGDP_R_SA_IX      Gross Domestic Product, Real, Seasonally Adjusted
# NGDP_R_SA_IX      Gross Domestic Product, Real, Seasonally Adjusted
# NGDP_R_XDC                             Gross Domestic Product, Real
# NGDP_R_XDC                             Gross Domestic Product, Real
# NGDP_R_XDC                             Gross Domestic Product, Real
# NGDP_SA_AR_XDC    Gross Domestic Product, Seasonally Adjusted, A...
# NGDP_SA_AR_XDC    Gross Domestic Product, Seasonally Adjusted, A...
# NGDP_XDC                                     Gross Domestic Product
# NGDP_XDC                                     Gross Domestic Product
# NGDP_XDC                                     Gross Domestic Product
# PCPI_IX                             Consumer Price Index, All items
# PCPI_IX                             Consumer Price Index, All items
# PCPI_IX                             Consumer Price Index, All items
# PCPI_IX                             Consumer Price Index, All items
# PCPI_IX                             Consumer Price Index, All items
# PCPI_PC_CP_A_PT                     Consumer Price Index, All items
# PCPI_PC_CP_A_PT                     Consumer Price Index, All items
# PCPI_PC_CP_A_PT                     Consumer Price Index, All items
# PCPI_PC_CP_A_PT                     Consumer Price Index, All items
# PCPI_PC_CP_A_PT                     Consumer Price Index, All items
# PMP_IX                          Import Price Index, All Commodities
# PPPI_IX                       Producer Price Index, All Commodities
# PPPI_IX                       Producer Price Index, All Commodities
# PPPI_IX                       Producer Price Index, All Commodities
# PPPI_IX                       Producer Price Index, All Commodities
# PPPI_PC_PP_PT     All Commodities, Percentage change, previous p...
# PXP_IX                                              All Commodities
#
#                                                         Description  \
# AIMIGOLD_SA_IX    Industrial Production, Mining, Gold Production...
# AIPMA_IX                Industrial Production, Manufacturing, Index
# AIPMA_SA_IX       Industrial Production, Manufacturing, Seasonal...
# AIPMI_IX                       Industrial Production, Mining, Index
# AIPMI_SA_IX       Industrial Production, Mining, Seasonally adju...
# AIPMMOC_IX        Industrial Production, Manufacturing, Non-dura...
# AIP_IX                                 Industrial Production, Index
# AIP_IX                                 Industrial Production, Index
# AIP_IX                                 Industrial Production, Index
# AIP_SA_IX         Industrial Production, Seasonally adjusted, Index
# AIP_SA_IX         Industrial Production, Seasonally adjusted, Index
# AIP_SA_IX         Industrial Production, Seasonally adjusted, Index
# BGS_BP6_USD       Current Account, Goods and Services, Net, US D...
# BGS_BP6_USD       Current Account, Goods and Services, Net, US D...
# BGS_BP6_USD       Current Account, Goods and Services, Net, US D...
# BGS_BP6_USD       Current Account, Goods and Services, Net, US D...
# BGS_BP6_USD       Current Account, Goods and Services, Net, US D...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# FIDR_PA                  Interest Rates, Deposit, Percent per annum
# FIDR_PA                  Interest Rates, Deposit, Percent per annum
# FIDR_PA                  Interest Rates, Deposit, Percent per annum
# FIDR_PA                  Interest Rates, Deposit, Percent per annum
# FIDR_PA                  Interest Rates, Deposit, Percent per annum
# ...                                                             ...
# NGDP_R_PT                     Gross Domestic Product, Real, Percent
# NGDP_R_SA_AR_XDC  Gross Domestic Product, Real, Seasonally adjus...
# NGDP_R_SA_AR_XDC  Gross Domestic Product, Real, Seasonally adjus...
# NGDP_R_SA_IX      Gross Domestic Product, Real, Seasonally adjus...
# NGDP_R_SA_IX      Gross Domestic Product, Real, Seasonally adjus...
# NGDP_R_XDC          Gross Domestic Product, Real, National Currency
# NGDP_R_XDC          Gross Domestic Product, Real, National Currency
# NGDP_R_XDC          Gross Domestic Product, Real, National Currency
# NGDP_SA_AR_XDC    Gross Domestic Product, Nominal, Seasonally ad...
# NGDP_SA_AR_XDC    Gross Domestic Product, Nominal, Seasonally ad...
# NGDP_XDC          Gross Domestic Product, Nominal, National Curr...
# NGDP_XDC          Gross Domestic Product, Nominal, National Curr...
# NGDP_XDC          Gross Domestic Product, Nominal, National Curr...
# PCPI_IX                      Consumer Price Index, All items, Index
# PCPI_IX                      Consumer Price Index, All items, Index
# PCPI_IX                      Consumer Price Index, All items, Index
# PCPI_IX                      Consumer Price Index, All items, Index
# PCPI_IX                      Consumer Price Index, All items, Index
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PMP_IX                   Import Price Index, All Commodities, Index
# PPPI_IX                Producer Price Index, All Commodities, Index
# PPPI_IX                Producer Price Index, All Commodities, Index
# PPPI_IX                Producer Price Index, All Commodities, Index
# PPPI_IX                Producer Price Index, All Commodities, Index
# PPPI_PC_PP_PT     Producer Price Index, All Commodities, Percent...
# PXP_IX                   Export Price Index, All Commodities, Index
#
#                                                                Full  \
# AIMIGOLD_SA_IX    Economic Activity, Industrial Production, Mini...
# AIPMA_IX          Economic Activity, Industrial Production, Manu...
# AIPMA_SA_IX       Economic Activity, Industrial Production, Manu...
# AIPMI_IX          Economic Activity, Industrial Production, Mini...
# AIPMI_SA_IX       Economic Activity, Industrial Production, Mini...
# AIPMMOC_IX        Economic Activity, Industrial Production, Manu...
# AIP_IX              Economic Activity, Industrial Production, Index
# AIP_IX              Economic Activity, Industrial Production, Index
# AIP_IX              Economic Activity, Industrial Production, Index
# AIP_SA_IX         Economic Activity, Industrial Production, Seas...
# AIP_SA_IX         Economic Activity, Industrial Production, Seas...
# AIP_SA_IX         Economic Activity, Industrial Production, Seas...
# BGS_BP6_USD       Balance of Payments, Current Account, Goods an...
# BGS_BP6_USD       Balance of Payments, Current Account, Goods an...
# BGS_BP6_USD       Balance of Payments, Current Account, Goods an...
# BGS_BP6_USD       Balance of Payments, Current Account, Goods an...
# BGS_BP6_USD       Balance of Payments, Current Account, Goods an...
# ENEER_IX          Exchange Rates, Nominal Effective Exchange Rat...
# ENEER_IX          Exchange Rates, Nominal Effective Exchange Rat...
# ENEER_IX          Exchange Rates, Nominal Effective Exchange Rat...
# ENEER_IX          Exchange Rates, Nominal Effective Exchange Rat...
# EREER_IX          Exchange Rates, Real Effective Exchange Rate, ...
# EREER_IX          Exchange Rates, Real Effective Exchange Rate, ...
# EREER_IX          Exchange Rates, Real Effective Exchange Rate, ...
# EREER_IX          Exchange Rates, Real Effective Exchange Rate, ...
# FIDR_PA           Financial, Interest Rates, Deposit, Percent pe...
# FIDR_PA           Financial, Interest Rates, Deposit, Percent pe...
# FIDR_PA           Financial, Interest Rates, Deposit, Percent pe...
# FIDR_PA           Financial, Interest Rates, Deposit, Percent pe...
# FIDR_PA           Financial, Interest Rates, Deposit, Percent pe...
# ...                                                             ...
# NGDP_R_PT         National Accounts, Gross Domestic Product, Rea...
# NGDP_R_SA_AR_XDC  National Accounts, Gross Domestic Product, Rea...
# NGDP_R_SA_AR_XDC  National Accounts, Gross Domestic Product, Rea...
# NGDP_R_SA_IX      National Accounts, Gross Domestic Product, Rea...
# NGDP_R_SA_IX      National Accounts, Gross Domestic Product, Rea...
# NGDP_R_XDC        National Accounts, Gross Domestic Product, Rea...
# NGDP_R_XDC        National Accounts, Gross Domestic Product, Rea...
# NGDP_R_XDC        National Accounts, Gross Domestic Product, Rea...
# NGDP_SA_AR_XDC    National Accounts, Gross Domestic Product, Nom...
# NGDP_SA_AR_XDC    National Accounts, Gross Domestic Product, Nom...
# NGDP_XDC          National Accounts, Gross Domestic Product, Nom...
# NGDP_XDC          National Accounts, Gross Domestic Product, Nom...
# NGDP_XDC          National Accounts, Gross Domestic Product, Nom...
# PCPI_IX              Prices, Consumer Price Index, All items, Index
# PCPI_IX              Prices, Consumer Price Index, All items, Index
# PCPI_IX              Prices, Consumer Price Index, All items, Index
# PCPI_IX              Prices, Consumer Price Index, All items, Index
# PCPI_IX              Prices, Consumer Price Index, All items, Index
# PCPI_PC_CP_A_PT   Prices, Consumer Price Index, All items, Perce...
# PCPI_PC_CP_A_PT   Prices, Consumer Price Index, All items, Perce...
# PCPI_PC_CP_A_PT   Prices, Consumer Price Index, All items, Perce...
# PCPI_PC_CP_A_PT   Prices, Consumer Price Index, All items, Perce...
# PCPI_PC_CP_A_PT   Prices, Consumer Price Index, All items, Perce...
# PMP_IX            Prices, Import Price Index, All Commodities, I...
# PPPI_IX           Prices, Producer Price Index, All Commodities,...
# PPPI_IX           Prices, Producer Price Index, All Commodities,...
# PPPI_IX           Prices, Producer Price Index, All Commodities,...
# PPPI_IX           Prices, Producer Price Index, All Commodities,...
# PPPI_PC_PP_PT     Prices, Producer Price Index, All Commodities,...
# PXP_IX            Prices, Export Price Index, All Commodities, I...
#
#                                                               Short  \
# AIMIGOLD_SA_IX          Gold Production, Seasonally adjusted, Index
# AIPMA_IX                                       Manufacturing, Index
# AIPMA_SA_IX       Industrial Production, Manufacturing, Seasonal...
# AIPMI_IX                       Industrial Production, Mining, Index
# AIPMI_SA_IX                      Mining, Seasonally adjusted, Index
# AIPMMOC_IX        Industrial Production, Manufacturing, Non-dura...
# AIP_IX                                 Industrial Production, Index
# AIP_IX                                 Industrial Production, Index
# AIP_IX                                 Industrial Production, Index
# AIP_SA_IX         Industrial Production, Seasonally adjusted, Index
# AIP_SA_IX         Industrial Production, Seasonally adjusted, Index
# AIP_SA_IX         Industrial Production, Seasonally adjusted, Index
# BGS_BP6_USD       Current Acct., Goods and Services, Net, US Dol...
# BGS_BP6_USD       Current Acct., Goods and Services, Net, US Dol...
# BGS_BP6_USD       Current Acct., Goods and Services, Net, US Dol...
# BGS_BP6_USD       Current Acct., Goods and Services, Net, US Dol...
# BGS_BP6_USD       Current Acct., Goods and Services, Net, US Dol...
# ENEER_IX                         NEER, Trade Partners by CPI, Index
# ENEER_IX                         NEER, Trade Partners by CPI, Index
# ENEER_IX                         NEER, Trade Partners by CPI, Index
# ENEER_IX                         NEER, Trade Partners by CPI, Index
# EREER_IX                                  REER, Based on CPI, Index
# EREER_IX                                  REER, Based on CPI, Index
# EREER_IX                                  REER, Based on CPI, Index
# EREER_IX                                  REER, Based on CPI, Index
# FIDR_PA                             Deposit Rate, Percent per annum
# FIDR_PA                             Deposit Rate, Percent per annum
# FIDR_PA                             Deposit Rate, Percent per annum
# FIDR_PA                             Deposit Rate, Percent per annum
# FIDR_PA                             Deposit Rate, Percent per annum
# ...                                                             ...
# NGDP_R_PT                     Gross Domestic Product, Real, Percent
# NGDP_R_SA_AR_XDC  Gross Domestic Product, Real, Seasonally Adjus...
# NGDP_R_SA_AR_XDC  Gross Domestic Product, Real, Seasonally Adjus...
# NGDP_R_SA_IX      Gross Domestic Product, Real, Seasonally Adjus...
# NGDP_R_SA_IX      Gross Domestic Product, Real, Seasonally Adjus...
# NGDP_R_XDC          Gross Domestic Product, Real, National Currency
# NGDP_R_XDC          Gross Domestic Product, Real, National Currency
# NGDP_R_XDC          Gross Domestic Product, Real, National Currency
# NGDP_SA_AR_XDC    Gross Domestic Product, Seasonally Adjusted, A...
# NGDP_SA_AR_XDC    Gross Domestic Product, Seasonally Adjusted, A...
# NGDP_XDC                  Gross Domestic Product, National Currency
# NGDP_XDC                  Gross Domestic Product, National Currency
# NGDP_XDC                  Gross Domestic Product, National Currency
# PCPI_IX                                       CPI, All items, Index
# PCPI_IX                                       CPI, All items, Index
# PCPI_IX                                       CPI, All items, Index
# PCPI_IX                                       CPI, All items, Index
# PCPI_IX                                       CPI, All items, Index
# PCPI_PC_CP_A_PT                  CPI, All items, Y/Y Percent Change
# PCPI_PC_CP_A_PT                  CPI, All items, Y/Y Percent Change
# PCPI_PC_CP_A_PT                  CPI, All items, Y/Y Percent Change
# PCPI_PC_CP_A_PT                  CPI, All items, Y/Y Percent Change
# PCPI_PC_CP_A_PT                  CPI, All items, Y/Y Percent Change
# PMP_IX                   Import Price Index, All Commodities, Index
# PPPI_IX                Producer Price Index, All Commodities, Index
# PPPI_IX                Producer Price Index, All Commodities, Index
# PPPI_IX                Producer Price Index, All Commodities, Index
# PPPI_IX                Producer Price Index, All Commodities, Index
# PPPI_PC_PP_PT     All Commodities, Percentage change, previous p...
# PXP_IX                                       All Commodities, Index
#
#                              Topic          Unit_Name             Category  \
# AIMIGOLD_SA_IX         Real Sector              Index    Economic Activity
# AIPMA_IX               Real Sector              Index    Economic Activity
# AIPMA_SA_IX            Real Sector              Index    Economic Activity
# AIPMI_IX               Real Sector              Index    Economic Activity
# AIPMI_SA_IX            Real Sector              Index    Economic Activity
# AIPMMOC_IX             Real Sector              Index    Economic Activity
# AIP_IX                 Real Sector              Index    Economic Activity
# AIP_IX                 Real Sector              Index    Economic Activity
# AIP_IX                 Real Sector              Index    Economic Activity
# AIP_SA_IX              Real Sector              Index    Economic Activity
# AIP_SA_IX              Real Sector              Index    Economic Activity
# AIP_SA_IX              Real Sector              Index    Economic Activity
# BGS_BP6_USD        External Sector         US Dollars  Balance of Payments
# BGS_BP6_USD        External Sector         US Dollars  Balance of Payments
# BGS_BP6_USD        External Sector         US Dollars  Balance of Payments
# BGS_BP6_USD        External Sector         US Dollars  Balance of Payments
# BGS_BP6_USD        External Sector         US Dollars  Balance of Payments
# ENEER_IX          Financial Sector              Index       Exchange Rates
# ENEER_IX          Financial Sector              Index       Exchange Rates
# ENEER_IX          Financial Sector              Index       Exchange Rates
# ENEER_IX          Financial Sector              Index       Exchange Rates
# EREER_IX          Financial Sector              Index       Exchange Rates
# EREER_IX          Financial Sector              Index       Exchange Rates
# EREER_IX          Financial Sector              Index       Exchange Rates
# EREER_IX          Financial Sector              Index       Exchange Rates
# FIDR_PA           Financial Sector  Percent per Annum            Financial
# FIDR_PA           Financial Sector  Percent per Annum            Financial
# FIDR_PA           Financial Sector  Percent per Annum            Financial
# FIDR_PA           Financial Sector  Percent per Annum            Financial
# FIDR_PA           Financial Sector  Percent per Annum            Financial
# ...                            ...                ...                  ...
# NGDP_R_PT              Real Sector            Percent    National Accounts
# NGDP_R_SA_AR_XDC       Real Sector  Domestic Currency    National Accounts
# NGDP_R_SA_AR_XDC       Real Sector  Domestic Currency    National Accounts
# NGDP_R_SA_IX           Real Sector              Index    National Accounts
# NGDP_R_SA_IX           Real Sector              Index    National Accounts
# NGDP_R_XDC             Real Sector  Domestic Currency    National Accounts
# NGDP_R_XDC             Real Sector  Domestic Currency    National Accounts
# NGDP_R_XDC             Real Sector  Domestic Currency    National Accounts
# NGDP_SA_AR_XDC         Real Sector  Domestic Currency    National Accounts
# NGDP_SA_AR_XDC         Real Sector  Domestic Currency    National Accounts
# NGDP_XDC               Real Sector  Domestic Currency    National Accounts
# NGDP_XDC               Real Sector  Domestic Currency    National Accounts
# NGDP_XDC               Real Sector  Domestic Currency    National Accounts
# PCPI_IX                Real Sector              Index               Prices
# PCPI_IX                Real Sector              Index               Prices
# PCPI_IX                Real Sector              Index               Prices
# PCPI_IX                Real Sector              Index               Prices
# PCPI_IX                Real Sector              Index               Prices
# PCPI_PC_CP_A_PT        Real Sector            Percent               Prices
# PCPI_PC_CP_A_PT        Real Sector            Percent               Prices
# PCPI_PC_CP_A_PT        Real Sector            Percent               Prices
# PCPI_PC_CP_A_PT        Real Sector            Percent               Prices
# PCPI_PC_CP_A_PT        Real Sector            Percent               Prices
# PMP_IX                 Real Sector              Index               Prices
# PPPI_IX                Real Sector              Index               Prices
# PPPI_IX                Real Sector              Index               Prices
# PPPI_IX                Real Sector              Index               Prices
# PPPI_IX                Real Sector              Index               Prices
# PPPI_PC_PP_PT          Real Sector            Percent               Prices
# PXP_IX                 Real Sector              Index               Prices
#
#                                       Y_Label               Combined  \
# AIMIGOLD_SA_IX                          Index    M.ZA.AIMIGOLD_SA_IX
# AIPMA_IX                                Index          M.MX.AIPMA_IX
# AIPMA_SA_IX                             Index       M.ZA.AIPMA_SA_IX
# AIPMI_IX                                Index          M.MX.AIPMI_IX
# AIPMI_SA_IX                             Index       M.ZA.AIPMI_SA_IX
# AIPMMOC_IX                              Index        M.MX.AIPMMOC_IX
# AIP_IX                                  Index            M.MX.AIP_IX
# AIP_IX                                  Index            M.RU.AIP_IX
# AIP_IX                                  Index            M.TR.AIP_IX
# AIP_SA_IX                               Index         M.BR.AIP_SA_IX
# AIP_SA_IX                               Index         M.MX.AIP_SA_IX
# AIP_SA_IX                               Index         M.TR.AIP_SA_IX
# BGS_BP6_USD              US Dollars, Millions       Q.BR.BGS_BP6_USD
# BGS_BP6_USD              US Dollars, Millions       Q.MX.BGS_BP6_USD
# BGS_BP6_USD              US Dollars, Millions       Q.RU.BGS_BP6_USD
# BGS_BP6_USD              US Dollars, Millions       Q.TR.BGS_BP6_USD
# BGS_BP6_USD              US Dollars, Millions       Q.ZA.BGS_BP6_USD
# ENEER_IX                                Index          M.BR.ENEER_IX
# ENEER_IX                                Index          M.MX.ENEER_IX
# ENEER_IX                                Index          M.RU.ENEER_IX
# ENEER_IX                                Index          M.ZA.ENEER_IX
# EREER_IX                                Index          M.BR.EREER_IX
# EREER_IX                                Index          M.MX.EREER_IX
# EREER_IX                                Index          M.RU.EREER_IX
# EREER_IX                                Index          M.ZA.EREER_IX
# FIDR_PA                     Percent per Annum           M.BR.FIDR_PA
# FIDR_PA                     Percent per Annum           M.MX.FIDR_PA
# FIDR_PA                     Percent per Annum           M.RU.FIDR_PA
# FIDR_PA                     Percent per Annum           M.TR.FIDR_PA
# FIDR_PA                     Percent per Annum           M.ZA.FIDR_PA
# ...                                       ...                    ...
# NGDP_R_PT                             Percent         Q.ZA.NGDP_R_PT
# NGDP_R_SA_AR_XDC  Domestic Currency, Billions  Q.MX.NGDP_R_SA_AR_XDC
# NGDP_R_SA_AR_XDC  Domestic Currency, Millions  Q.ZA.NGDP_R_SA_AR_XDC
# NGDP_R_SA_IX                            Index      Q.MX.NGDP_R_SA_IX
# NGDP_R_SA_IX                            Index      Q.ZA.NGDP_R_SA_IX
# NGDP_R_XDC        Domestic Currency, Millions        Q.BR.NGDP_R_XDC
# NGDP_R_XDC        Domestic Currency, Billions        Q.RU.NGDP_R_XDC
# NGDP_R_XDC        Domestic Currency, Millions        Q.TR.NGDP_R_XDC
# NGDP_SA_AR_XDC    Domestic Currency, Billions    Q.MX.NGDP_SA_AR_XDC
# NGDP_SA_AR_XDC    Domestic Currency, Millions    Q.ZA.NGDP_SA_AR_XDC
# NGDP_XDC          Domestic Currency, Millions          Q.BR.NGDP_XDC
# NGDP_XDC          Domestic Currency, Billions          Q.RU.NGDP_XDC
# NGDP_XDC          Domestic Currency, Millions          Q.TR.NGDP_XDC
# PCPI_IX                                 Index           M.BR.PCPI_IX
# PCPI_IX                                 Index           M.MX.PCPI_IX
# PCPI_IX                                 Index           M.RU.PCPI_IX
# PCPI_IX                                 Index           M.TR.PCPI_IX
# PCPI_IX                                 Index           M.ZA.PCPI_IX
# PCPI_PC_CP_A_PT                       Percent   M.BR.PCPI_PC_CP_A_PT
# PCPI_PC_CP_A_PT                       Percent   M.MX.PCPI_PC_CP_A_PT
# PCPI_PC_CP_A_PT                       Percent   M.RU.PCPI_PC_CP_A_PT
# PCPI_PC_CP_A_PT                       Percent   M.TR.PCPI_PC_CP_A_PT
# PCPI_PC_CP_A_PT                       Percent   M.ZA.PCPI_PC_CP_A_PT
# PMP_IX                                  Index            M.MX.PMP_IX
# PPPI_IX                                 Index           M.BR.PPPI_IX
# PPPI_IX                                 Index           M.MX.PPPI_IX
# PPPI_IX                                 Index           M.TR.PPPI_IX
# PPPI_IX                                 Index           M.ZA.PPPI_IX
# PPPI_PC_PP_PT                         Percent     M.RU.PPPI_PC_PP_PT
# PXP_IX                                  Index            M.MX.PXP_IX
#
#                                                         Chart_Title  \
# AIMIGOLD_SA_IX    Industrial Production, Mining, Gold Production...
# AIPMA_IX                       Industrial Production, Manufacturing
# AIPMA_SA_IX       Industrial Production, Manufacturing, Seasonal...
# AIPMI_IX                              Industrial Production, Mining
# AIPMI_SA_IX       Industrial Production, Mining, Seasonally adju...
# AIPMMOC_IX        Industrial Production, Manufacturing, Non-dura...
# AIP_IX                                        Industrial Production
# AIP_IX                                        Industrial Production
# AIP_IX                                        Industrial Production
# AIP_SA_IX                Industrial Production, Seasonally adjusted
# AIP_SA_IX                Industrial Production, Seasonally adjusted
# AIP_SA_IX                Industrial Production, Seasonally adjusted
# BGS_BP6_USD                Current Account, Goods and Services, Net
# BGS_BP6_USD                Current Account, Goods and Services, Net
# BGS_BP6_USD                Current Account, Goods and Services, Net
# BGS_BP6_USD                Current Account, Goods and Services, Net
# BGS_BP6_USD                Current Account, Goods and Services, Net
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# ENEER_IX          Nominal Effective Exchange Rate, Trade Partner...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# EREER_IX          Real Effective Exchange Rate, based on Consume...
# FIDR_PA                                     Interest Rates, Deposit
# FIDR_PA                                     Interest Rates, Deposit
# FIDR_PA                                     Interest Rates, Deposit
# FIDR_PA                                     Interest Rates, Deposit
# FIDR_PA                                     Interest Rates, Deposit
# ...                                                             ...
# NGDP_R_PT                              Gross Domestic Product, Real
# NGDP_R_SA_AR_XDC  Gross Domestic Product, Real, Seasonally adjus...
# NGDP_R_SA_AR_XDC  Gross Domestic Product, Real, Seasonally adjus...
# NGDP_R_SA_IX      Gross Domestic Product, Real, Seasonally adjusted
# NGDP_R_SA_IX      Gross Domestic Product, Real, Seasonally adjusted
# NGDP_R_XDC                             Gross Domestic Product, Real
# NGDP_R_XDC                             Gross Domestic Product, Real
# NGDP_R_XDC                             Gross Domestic Product, Real
# NGDP_SA_AR_XDC    Gross Domestic Product, Nominal, Seasonally ad...
# NGDP_SA_AR_XDC    Gross Domestic Product, Nominal, Seasonally ad...
# NGDP_XDC                            Gross Domestic Product, Nominal
# NGDP_XDC                            Gross Domestic Product, Nominal
# NGDP_XDC                            Gross Domestic Product, Nominal
# PCPI_IX                             Consumer Price Index, All items
# PCPI_IX                             Consumer Price Index, All items
# PCPI_IX                             Consumer Price Index, All items
# PCPI_IX                             Consumer Price Index, All items
# PCPI_IX                             Consumer Price Index, All items
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PCPI_PC_CP_A_PT   Consumer Price Index, All items, Percent Chang...
# PMP_IX                          Import Price Index, All Commodities
# PPPI_IX                       Producer Price Index, All Commodities
# PPPI_IX                       Producer Price Index, All Commodities
# PPPI_IX                       Producer Price Index, All Commodities
# PPPI_IX                       Producer Price Index, All Commodities
# PPPI_PC_PP_PT     Producer Price Index, All Commodities, Percent...
# PXP_IX                          Export Price Index, All Commodities
#
#                                   Group
# AIMIGOLD_SA_IX      3-Economic Activity
# AIPMA_IX            3-Economic Activity
# AIPMA_SA_IX         3-Economic Activity
# AIPMI_IX            3-Economic Activity
# AIPMI_SA_IX         3-Economic Activity
# AIPMMOC_IX          3-Economic Activity
# AIP_IX              3-Economic Activity
# AIP_IX              3-Economic Activity
# AIP_IX              3-Economic Activity
# AIP_SA_IX           3-Economic Activity
# AIP_SA_IX           3-Economic Activity
# AIP_SA_IX           3-Economic Activity
# BGS_BP6_USD       5-Balance of Payments
# BGS_BP6_USD       5-Balance of Payments
# BGS_BP6_USD       5-Balance of Payments
# BGS_BP6_USD       5-Balance of Payments
# BGS_BP6_USD       5-Balance of Payments
# ENEER_IX               6-Exchange Rates
# ENEER_IX               6-Exchange Rates
# ENEER_IX               6-Exchange Rates
# ENEER_IX               6-Exchange Rates
# EREER_IX               6-Exchange Rates
# EREER_IX               6-Exchange Rates
# EREER_IX               6-Exchange Rates
# EREER_IX               6-Exchange Rates
# FIDR_PA                7-Interest Rates
# FIDR_PA                7-Interest Rates
# FIDR_PA                7-Interest Rates
# FIDR_PA                7-Interest Rates
# FIDR_PA                7-Interest Rates
# ...                                 ...
# NGDP_R_PT           1-National Accounts
# NGDP_R_SA_AR_XDC    1-National Accounts
# NGDP_R_SA_AR_XDC    1-National Accounts
# NGDP_R_SA_IX        1-National Accounts
# NGDP_R_SA_IX        1-National Accounts
# NGDP_R_XDC          1-National Accounts
# NGDP_R_XDC          1-National Accounts
# NGDP_R_XDC          1-National Accounts
# NGDP_SA_AR_XDC      1-National Accounts
# NGDP_SA_AR_XDC      1-National Accounts
# NGDP_XDC            1-National Accounts
# NGDP_XDC            1-National Accounts
# NGDP_XDC            1-National Accounts
# PCPI_IX                        4-Prices
# PCPI_IX                        4-Prices
# PCPI_IX                        4-Prices
# PCPI_IX                        4-Prices
# PCPI_IX                        4-Prices
# PCPI_PC_CP_A_PT                4-Prices
# PCPI_PC_CP_A_PT                4-Prices
# PCPI_PC_CP_A_PT                4-Prices
# PCPI_PC_CP_A_PT                4-Prices
# PCPI_PC_CP_A_PT                4-Prices
# PMP_IX                         4-Prices
# PPPI_IX                        4-Prices
# PPPI_IX                        4-Prices
# PPPI_IX                        4-Prices
# PPPI_IX                        4-Prices
# PPPI_PC_PP_PT                  4-Prices
# PXP_IX                         4-Prices
#
# [125 rows x 18 columns]
