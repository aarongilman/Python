# %% [markdown]
# # EMERFIN DASHBOARD
# Python 2.7 script to generate charts and latex code

# %%
# Import preliminaries
import requests
import pandas as pd
import time
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import fnmatch
import numpy as np

# %%
url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/'
series_url = '{}CodeList/CL_INDICATOR_IFS'.format(url)
area_url = '{}CodeList/CL_AREA_IFS'.format(url)
data_url= '{}CompactData/IFS/'.format(url)
ds_url = '{}DataStructure/IFS'.format(url)
SearchTerms = ['ic Product, Real','mploym','Industrial Pro','ices, Net','Interest Rate','Price In']
CountryList = ['BR','RU','IN','CN','ZA','VN','MX','ID','NG','TR','RO','AR','CO','EG','TH','PL',
               'PH','BG','FR','DE','US','JP','SN','MU','KE','UA','IT','GR','MY','CL','JM','MA',
               'PE','AU','AT','CA','CR','HU','DZ','IE','PT','ES','NL','KR','UY','BH','SA','PY',
               'HN','MN','OM','QA','SV','SK','LK','FJ','RS','NO','DK','LT','MZ','NZ','KW','KH',
               'GH','EC','PA','NP','BO','CH','PK','SG','FI','SI','SE','LV','BD','GB'
              ]# ['BH','OM']#
dfcols = ['@FREQ','@INDICATOR','@REF_AREA','@UNIT_MULT', 'Obs','@TIME_FORMAT']
name_vars = {'Short':2,'Full':3,'Concept':5,'Unit_Name':7,'Topic':8}

# %%
# Request r_list of IFS series that meet SearchTerms
s_list = requests.get(series_url).json()['Structure']['CodeLists']['CodeList']['Code']
s_dict = {s_list[i]['@value']: s_list[i]['Description']['#text'] for i in range(0,len(s_list))}
r_list = [k for k, v in s_dict.items() if any([x in v for x in SearchTerms])]

# %%
# Final results must have data available for r_list and CountryList 
ResultsList = []
for r in r_list:
    url_r = '{}.{}.{}.?startPeriod=2013'.format(data_url, '+'.join(CountryList), r)
#    print url_r    
    data = requests.get(url_r).json()['CompactData']['DataSet']
    if 'Series' in data.keys():
        for n in range(0,len(data['Series'])):
            if 'Obs' in data['Series'][n].keys(): 
                ResultsList.append(data['Series'][n])
    time.sleep(0.5)   ## Delay requests slightly so that IMF does not block them

# %%
# Generate .csv of best series
df = pd.DataFrame(ResultsList, columns=(dfcols)).iloc[:,0:4]
df['Freq'] = df['@FREQ'].replace({'M':2, 'Q':1, 'A':0})  ## Monthly data pref
df['Combined'] = df['@REF_AREA'].str.cat(df['@INDICATOR'], sep='.')
df = df.sort_values(['Combined', 'Freq']).drop_duplicates('Combined', keep='last')
df['Title'] = df['@INDICATOR'].map(s_dict)
df['Source'] = 'IFS'
## Country Full Names
s_area = requests.get(area_url).json()['Structure']['CodeLists']['CodeList']['Code']
d_area = {s_area[i]['@value']: s_area[i]['Description']['#text'] for i in range(0,len(s_area))}
df['Country'] = df['@REF_AREA'].map(d_area)
## Unit Multiplier Text
ds = requests.get(ds_url).json()['Structure']['CodeLists']['CodeList'][0]['Code']
d_unit = {ds[i]['@value']: ds[i]['Description']['#text'] for i in range(0,len(ds))}
df['Units'] = df[df['@UNIT_MULT']!='0']['@UNIT_MULT'].map(d_unit)
## Additional Text
df2 = pd.DataFrame(requests.get(ds_url).json()['Structure']['CodeLists']['CodeList'][3]['Code'])
df2 = df2[df2['@value'].isin(pd.unique(df['@INDICATOR']))]
for k, v in name_vars.items():
    d = {}
    for i in range(0,len(df2)):
        d[df2.iloc[i]['@value']] = df2.iloc[i]['Annotations']['Annotation'][v]['AnnotationText']['#text']
    df[k] = df['@INDICATOR'].map(d)   
df['Y_Label'] = df['Unit_Name'].str.cat(df['Units'], sep=', ').fillna(df['Unit_Name'])
df['Combined'] = df['@FREQ'].str.cat(df['Combined'], sep='.')
df = df.set_index('Combined')
df['Category'] = df['Full'].str.split(',', expand=True, n=1)[0]
df['Chart_Title'] = df['Title'].str.rsplit(',', expand=True, n=1)[0]
f1 = 'Percentage change, corresponding period previous year'
f2 = 'Percent Change, Corresponding Period Previous Year'
r1 = 'Annual percentage change'
df['Chart_Title'] = df['Chart_Title'].str.replace(f1, r1)
df['Chart_Title'] = df['Chart_Title'].str.replace(f2, r1)
df = df.sort_values(['Country', 'Category', 'Chart_Title'])

# %%
# Categorize each chart into one of 8 groups
Group_dict = {
    'National Accounts':'1-National Accounts',
    'Labor Markets':'2-Labor Markets',
    'Social Indicators':'2-Labor Markets',
    'Economic Activity':'3-Economic Activity',
    'Producer Price Index':'4-Prices',
    'Consumer Prices':'4-Prices',
    'Prices':'4-Prices',
    'Balance of Payments':'5-Balance of Payments',
    'Exchange Rates':'6-Exchange Rates',
    #:'7-Financial Policy Rate',  # Find from Chart_Title later
    'Financial':'8-Financial Market Rate'
}
Policy_kw = ['Policy', 'Lending', 'Discount']
df['Group'] = df['Category'].map(Group_dict)
df.loc[df['Chart_Title'].str.contains('Pol|Disc').tolist(), 'Group'] = '7-Financial Policy Rate'

# %%
# Source
df['Source'] = 'IFS'
# Regions Mapping from CSV file
Regions = pd.read_csv('regions.csv', index_col='country').to_dict()['region']
df['Region'] = df['Country'].map(Regions)
# Chart Type
df['Type'] = 'plot'
df.loc[df['Group'].str.contains('1|5').tolist(), 'Type'] = 'bar'

# %%
# Main or Alt
df['Main_Alt'] = 'Alternate'
df.loc[df['Title'].str.contains('Real, P|eal Eff|Cons.*cent|ment Rate, P|ices, Net|Indus.*erc').tolist(), 'Main_Alt'] = 'Main'
for c in pd.unique(df['Country'].values):
    if len(df[df['Country']==c][(df['Group'].str.contains('3').tolist()) & (df['Main_Alt'] == 'Main')]) == 0:
        df.loc[(df['Country']==c) & (df['@INDICATOR'].str.contains('AIP_IX').tolist()), 'Main_Alt'] = 'Main'
        if len(df[df['Country']==c][(df['Group'].str.contains('3').tolist()) & (df['Main_Alt'] == 'Main')]) == 0:
            df.loc[(df['Country']==c) & (df['@INDICATOR'].str.contains('AIP_SA_IX').tolist()), 'Main_Alt'] = 'Main'
            if len(df[df['Country']==c][(df['Group'].str.contains('3').tolist()) & (df['Main_Alt'] == 'Main')]) == 0:
                df.loc[(df['Country']==c) & (df['@INDICATOR'].str.contains('AIPMA_IX').tolist()), 'Main_Alt'] = 'Main' 
                if len(df[df['Country']==c][(df['Group'].str.contains('3').tolist()) & (df['Main_Alt'] == 'Main')]) == 0:
                    df.loc[(df['Country']==c) & (df['@INDICATOR'].str.contains('AIPMA_SA_IX').tolist()), 'Main_Alt'] = 'Main'
    if len(df[df['Country']==c][(df['Group'].str.contains('7').tolist()) & (df['Main_Alt'] == 'Main')]) == 0:
        df.loc[(df['Country']==c) & (df['Title'].str.contains('Policy').tolist()), 'Main_Alt'] = 'Main'
        if len(df[df['Country']==c][(df['Group'].str.contains('7').tolist()) & (df['Main_Alt'] == 'Main')]) == 0:
            df.loc[(df['Country']==c) & (df['Title'].str.contains('Discount').tolist()), 'Main_Alt'] = 'Main'
    if len(df[df['Country']==c][(df['Group'].str.contains('8').tolist()) & (df['Main_Alt'] == 'Main')]) == 0:
        df.loc[(df['Country']==c) & (df['Title'].str.contains('ment Bonds, Per').tolist()), 'Main_Alt'] = 'Main'
        if len(df[df['Country']==c][(df['Group'].str.contains('8').tolist()) & (df['Main_Alt'] == 'Main')]) == 0:
            df.loc[(df['Country']==c) & (df['Title'].str.contains('Treas').tolist()), 'Main_Alt'] = 'Main'
            if len(df[df['Country']==c][(df['Group'].str.contains('8').tolist()) & (df['Main_Alt'] == 'Main')]) == 0:
                df.loc[(df['Country']==c) & (df['Title'].str.contains('Lending Rate, P').tolist()), 'Main_Alt'] = 'Main'
# Out:
# C:\Users\BDew\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\BDew\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\BDew\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\BDew\Anaconda2\lib\site-packages\ipykernel\__main__.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\BDew\Anaconda2\lib\site-packages\ipykernel\__main__.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\BDew\Anaconda2\lib\site-packages\ipykernel\__main__.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\BDew\Anaconda2\lib\site-packages\ipykernel\__main__.py:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\BDew\Anaconda2\lib\site-packages\ipykernel\__main__.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\BDew\Anaconda2\lib\site-packages\ipykernel\__main__.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df.to_csv('IFS_Series_List.csv')

# %%
url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/IFS/'
series_df = pd.read_csv('IFS_Series_List.csv', index_col='Combined') #df.sort_values(['Country', 'Group']) #
s_list = series_df.index[series_df['Main_Alt'] == 'Main']
color_list = {
    1: u'red',
    2: u'blue', 
    3: u'#2ecc71', 
    4: u'#e67e22', 
    5: u'#5dade2',
    6: u'#a569bd',
    7: u'#1c7c45',
    8: u'#ffc300',
}
yearsFmt = mdates.DateFormatter('%Y')

# %%
for v in s_list: #[s_list[0]]
    data = requests.get('{}{}.?startPeriod=2006'.format(url, v)).json()['CompactData']['DataSet']['Series']['Obs']
    time.sleep(0.5)   ## Delay requests slightly so that IMF does not block them
    # Load data into a pandas dataframe and set index
    df = pd.DataFrame(data)
    df = df.set_index(pd.to_datetime(df['@TIME_PERIOD']))
    plttype = series_df.loc[v]['Type']
    # Basic plot 
    ax = plt.gca()
    ax.yaxis.grid(True)
    ax.set_axisbelow(True)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.yaxis.set_ticks_position('left') 
    ax.xaxis.set_ticks_position('bottom')
    ax.xaxis.set_major_formatter(yearsFmt)
    ax.xaxis.set_label_coords(0.35, -0.1)
    ax.margins(0.05)
    color_id = color_list[int(series_df.loc[v]['Group'][0])]
    if 'plot' in series_df.loc[v]['Type']:
        plt.plot(df['@OBS_VALUE'].astype(float), linewidth=2, color=color_id)
    else:
        if v in fnmatch.filter(s_list, 'A*GDP*'):
            plt.bar(df.index, df['@OBS_VALUE'].astype(float), width=180, color=color_id, linewidth=0)
        if v in fnmatch.filter(s_list, 'A*BGS*'):
            plt.bar(df.index, df['@OBS_VALUE'].astype(float), width=180, color=color_id, linewidth=0)
        else: 
            plt.bar(df.index, df['@OBS_VALUE'].astype(float), width=60, color=color_id, linewidth=0)
    plt.tick_params(axis='both', which='major', labelsize=7)
    plt.tick_params(axis='both', which='minor', labelsize=7)
    plt.title(series_df.loc[v]['Chart_Title'], fontsize=10)
    if len(series_df.loc[v]['Chart_Title']) <= 50:
        plt.title(series_df.loc[v]['Chart_Title'], fontsize=12)
    plt.rcParams['figure.figsize'] = (5, 3)
    plt.ylabel(series_df.loc[v]['Y_Label'], fontsize=8)
    if 'Index' in series_df.loc[v]['Y_Label']:
        if '@BASE_YEAR' in data[0].keys():
#            print v
            plt.ylabel('{}, ({}=100)'.format(series_df.loc[v]['Y_Label'], data[0]['@BASE_YEAR']), fontsize=8)
    lvv = np.round(float(df['@OBS_VALUE'][-1]), decimals=2)
    lvd = df.index[-1].strftime('%Y-%m-%d')    
    plt.xlabel('Source: IFS      Latest Value: {}: {}'.format(lvd, lvv), fontsize=9)
    plt.savefig('plots/{}_{}_v1.pdf'.format(v[2:4],v[5:]), bbox_inches='tight')
    plt.close()

# %%
series_df = pd.read_csv('IFS_Series_List.csv', index_col='Combined').sort_values(['Region','Country', 'Group'])
s_list = series_df.index[series_df['Main_Alt'] == 'Main']
ltx1 = '\includegraphics[max width=0.5\\textwidth]{'
ltx2 ='\\thispagestyle{main} \\noindent '
for r in pd.unique(series_df['Region']):
    print '\section*{{{}}}'.format(r)
    print '\markboth{{{}}}{{}}'.format(r)
    for c in pd.unique(series_df.loc[series_df['Region']==r, 'Country']):
        print '\subsection*{{{}}}{}'.format(c, ltx2)
        idx = series_df[(series_df['Main_Alt'] == 'Main') & (series_df['Country'] == str(c))].index
        for v in range(0,len(idx)):
            print '{}{}_{}_v1.pdf}}'.format(ltx1, idx[v][2:4],idx[v][5:])
        print '\\newpage'
# Out:
# \section*{Africa}
# \markboth{Africa}{}
# \subsection*{Ghana}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{GH_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GH_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GH_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GH_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GH_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Kenya}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{KE_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KE_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KE_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KE_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KE_FITB_PA_v1.pdf}
# \newpage
# \subsection*{Mauritius}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{MU_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MU_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MU_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MU_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MU_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MU_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Mozambique}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{MZ_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MZ_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MZ_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MZ_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MZ_FITB_PA_v1.pdf}
# \newpage
# \subsection*{Nigeria}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{NG_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NG_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NG_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NG_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NG_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NG_FITB_PA_v1.pdf}
# \newpage
# \subsection*{Senegal}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{SN_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SN_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SN_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SN_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SN_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SN_FIRA_PA_v1.pdf}
# \newpage
# \subsection*{South Africa}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{ZA_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ZA_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ZA_AIPMA_SA_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ZA_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ZA_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ZA_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ZA_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ZA_FIGB_PA_v1.pdf}
# \newpage
# \section*{Americas}
# \markboth{Americas}{}
# \subsection*{Argentina}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{AR_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AR_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AR_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AR_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AR_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Brazil}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{BR_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BR_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BR_AIP_SA_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BR_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BR_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BR_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BR_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BR_FITB_PA_v1.pdf}
# \newpage
# \subsection*{Canada}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{CA_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CA_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CA_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CA_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CA_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CA_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CA_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CA_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Chile}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{CL_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CL_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CL_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CL_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CL_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CL_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CL_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CL_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Colombia}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{CO_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CO_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CO_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CO_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CO_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CO_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Costa Rica}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{CR_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CR_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CR_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CR_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CR_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CR_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CR_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Ecuador}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{EC_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EC_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EC_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EC_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EC_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EC_FID_PA_v1.pdf}
# \newpage
# \subsection*{Honduras}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{HN_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HN_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HN_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HN_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HN_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Jamaica}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{JM_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JM_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JM_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JM_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JM_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JM_FITB_PA_v1.pdf}
# \newpage
# \subsection*{Mexico}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{MX_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MX_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MX_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MX_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MX_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MX_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MX_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MX_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Panama}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{PA_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PA_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PA_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PA_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PA_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Peru}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{PE_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PE_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PE_AIPMA_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PE_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PE_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PE_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PE_FILR_PA_v1.pdf}
# \newpage
# \subsection*{United States}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{US_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{US_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{US_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{US_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{US_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{US_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{US_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{US_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Uruguay}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{UY_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UY_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UY_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UY_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UY_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UY_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UY_FITB_PA_v1.pdf}
# \newpage
# \section*{Asia}
# \markboth{Asia}{}
# \subsection*{Australia}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{AU_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AU_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AU_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AU_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AU_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AU_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AU_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AU_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{China}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{CN_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CN_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CN_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CN_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CN_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CN_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CN_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{CN_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Fiji}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{FJ_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FJ_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FJ_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FJ_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FJ_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FJ_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{India}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{IN_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IN_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IN_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IN_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IN_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IN_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Indonesia}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{ID_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ID_AIPMA_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ID_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ID_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ID_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ID_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Japan}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{JP_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JP_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JP_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JP_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JP_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JP_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JP_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{JP_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Korea, Republic of}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{KR_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KR_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KR_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KR_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KR_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KR_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KR_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Malaysia}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{MY_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MY_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MY_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MY_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MY_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MY_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MY_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MY_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Mongolia}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{MN_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MN_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MN_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MN_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{MN_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Nepal}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{NP_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NP_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NP_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NP_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NP_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{New Zealand}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{NZ_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NZ_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NZ_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NZ_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NZ_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NZ_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NZ_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NZ_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Philippines}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{PH_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PH_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PH_AIPMA_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PH_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PH_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PH_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PH_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PH_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Sri Lanka}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{LK_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LK_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LK_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LK_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LK_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LK_FIRA_PA_v1.pdf}
# \newpage
# \subsection*{Thailand}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{TH_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TH_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TH_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TH_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TH_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TH_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Viet Nam}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{VN_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{VN_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{VN_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{VN_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{VN_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{VN_FITB_PA_v1.pdf}
# \newpage
# \section*{Europe}
# \markboth{Europe}{}
# \subsection*{Austria}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{AT_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AT_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AT_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AT_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AT_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AT_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{AT_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Bulgaria}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{BG_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BG_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BG_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BG_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BG_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BG_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BG_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BG_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Denmark}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{DK_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DK_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DK_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DK_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DK_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DK_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DK_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DK_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{France}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{FR_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FR_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FR_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FR_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FR_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FR_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{FR_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Germany}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{DE_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DE_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DE_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DE_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DE_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DE_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DE_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Greece}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{GR_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GR_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GR_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GR_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GR_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GR_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GR_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Hungary}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{HU_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HU_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HU_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HU_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HU_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HU_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HU_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{HU_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Ireland}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{IE_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IE_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IE_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IE_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IE_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IE_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IE_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Italy}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{IT_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IT_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IT_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IT_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IT_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IT_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{IT_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Lithuania}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{LT_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LT_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LT_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LT_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LT_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{LT_FIRA_PA_v1.pdf}
# \newpage
# \subsection*{Netherlands}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{NL_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NL_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NL_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NL_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NL_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NL_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NL_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Norway}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{NO_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NO_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NO_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NO_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NO_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NO_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NO_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{NO_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Poland}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{PL_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PL_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PL_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PL_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PL_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PL_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PL_FIRA_PA_v1.pdf}
# \newpage
# \subsection*{Portugal}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{PT_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PT_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PT_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PT_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PT_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PT_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{PT_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Romania}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{RO_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RO_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RO_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RO_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RO_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RO_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RO_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RO_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Russian Federation}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{RU_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RU_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RU_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RU_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RU_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RU_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RU_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RU_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Serbia}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{RS_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RS_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RS_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{RS_FIRA_PA_v1.pdf}
# \newpage
# \subsection*{Slovenia}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{SI_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SI_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SI_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SI_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SI_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SI_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Spain}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{ES_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ES_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ES_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ES_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ES_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ES_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{ES_FIGB_PA_v1.pdf}
# \newpage
# \subsection*{Ukraine}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{UA_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UA_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UA_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UA_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UA_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UA_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{UA_FILR_PA_v1.pdf}
# \newpage
# \subsection*{United Kingdom}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{GB_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GB_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GB_AIP_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GB_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GB_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GB_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GB_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{GB_FIGB_PA_v1.pdf}
# \newpage
# \section*{Middle East}
# \markboth{Middle East}{}
# \subsection*{Algeria}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{DZ_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DZ_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DZ_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DZ_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DZ_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DZ_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{DZ_FITB_PA_v1.pdf}
# \newpage
# \subsection*{Bahrain}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{BH_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BH_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BH_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BH_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BH_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{BH_FIRA_PA_v1.pdf}
# \newpage
# \subsection*{Egypt}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{EG_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EG_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EG_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EG_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EG_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{EG_FITB_PA_v1.pdf}
# \newpage
# \subsection*{Kuwait}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{KW_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KW_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KW_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KW_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{KW_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Oman}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{OM_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{OM_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{OM_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{OM_FID_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{OM_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Qatar}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{QA_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{QA_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{QA_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{QA_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{QA_FILR_PA_v1.pdf}
# \newpage
# \subsection*{Saudi Arabia}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{SA_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SA_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SA_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SA_EREER_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SA_FPOLM_PA_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{SA_FIRA_PA_v1.pdf}
# \newpage
# \subsection*{Turkey}\thispagestyle{main} \noindent
# \includegraphics[max width=0.5\textwidth]{TR_NGDP_R_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TR_LUR_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TR_AIP_IX_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TR_PCPI_PC_CP_A_PT_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TR_BGS_BP6_USD_v1.pdf}
# \includegraphics[max width=0.5\textwidth]{TR_FPOLM_PA_v1.pdf}
# \newpage
# \section*{nan}
# \markboth{nan}{}
