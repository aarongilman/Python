# %%
import config
import plotly.plotly as py
from plotly.graph_objs import *

# %%
# Get this figure: fig = py.get_figure("https://plot.ly/~bdew/106/")
# Get this figure's data: data = py.get_figure("https://plot.ly/~bdew/106/").get_data()
# Add data to this figure: py.plot(Data([Scatter(x=[1, 2], y=[2, 3])]), filename ="Plot 106", fileopt="extend")
# Get y data of first trace: y1 = py.get_figure("https://plot.ly/~bdew/106/").get_data()[0]["y"]

# Get figure documentation: https://plot.ly/python/get-requests/
# Add data documentation: https://plot.ly/python/file-options/

# If you're using unicode in your file, you may need to specify the encoding.
# You can reproduce this figure in Python with the following code!

# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api
import config
import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in('bdew', config.plotly_key)
trace1 = {
  "x": ["2017", "2027"], 
  "y": ["136", "2440"], 
  "marker": {
    "color": "rgb(31, 73, 125)", 
    "line": {"color": "rgb(255, 255, 255)"}
  }, 
  "name": "B", 
  "type": "bar", 
  "uid": "459a26", 
  "xsrc": "bdew:105:64718e", 
  "ysrc": "bdew:105:40f229"
}
data = Data([trace1])
layout = {
  "annotations": [
    {
      "x": 2017, 
      "y": 274.555353902, 
      "font": {
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "$136 Billion", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 2026.92857143, 
      "y": 2559.56442831, 
      "font": {
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "$2.44 Trillion", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 0.05, 
      "y": 1.37, 
      "font": {
        "color": "rgb(139, 139, 131)", 
        "family": "Balto", 
        "size": 14
      }, 
      "showarrow": False, 
      "text": "<b>Figure 1</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.05, 
      "y": 1.3, 
      "font": {
        "color": "rgb(31, 73, 125)", 
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "<b>Amazon Sales</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.07, 
      "y": 1.18974358974, 
      "align": "left", 
      "font": {
        "color": "rgb(139, 139, 131)", 
        "family": "Balto", 
        "size": 14
      }, 
      "showarrow": False, 
      "text": "Current sales and 2027 projected sales required for P/E ratio of 20 with current profit margin", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.05, 
      "y": -0.30, 
      "align": "left", 
      "font": {
        "color": "rgb(127, 127, 127)", 
        "family": "Balto"
      }, 
      "showarrow": False, 
      "text": "cepr.net<br>Source: company financial statements, CEPR calculations", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "height": 400, 
  "hovermode": "closest", 
  "margin": {
    "r": 20, 
    "t": 90, 
    "b": 80, 
    "l": 20
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "shapes": [
    {
      "line": {
        "color": "rgba(139, 139, 131, 100)", 
        "width": 3
      }, 
      "type": "line", 
      "x0": -0.1, 
      "x1": 1.1, 
      "xref": "paper", 
      "y0": 1.39, 
      "y1": 1.39, 
      "yref": "paper"
    }, 
    {
      "line": {
        "color": "rgba(139, 139, 131, 100)", 
        "width": 2
      }, 
      "type": "line", 
      "x0": -0.1, 
      "x1": 1.1, 
      "xref": "paper", 
      "y0": -0.35, 
      "y1": -0.35, 
      "yref": "paper"
    }
  ], 
  "width": 520, 
  "xaxis": {
    "autorange": True, 
    "dtick": 10, 
    "nticks": 2, 
    "range": [2012, 2032], 
    "tick0": -3, 
    "tickfont": {
      "color": "rgb(127, 127, 127)", 
      "family": "Balto", 
      "size": 18
    }, 
    "tickmode": "linear", 
    "title": "", 
    "type": "linear"
  }, 
  "yaxis": {
    "autorange": True, 
    "range": [0, 2706.14741319], 
    "showgrid": False, 
    "showticklabels": False, 
    "title": "", 
    "type": "linear", 
    "zerolinecolor": "rgb(127, 127, 127)"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename="Amazon_fig1")
#py.image.save_as(fig,'Amazon_fig1.png')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-8-c01de0b9c8a6> in <module>()
#     176 }
#     177 fig = Figure(data=data, layout=layout)
# --> 178 py.iplot(fig, filename="Amazon_fig1")
#     179 #py.image.save_as(fig,'Amazon_fig1.png')
#
# C:\Anaconda2\lib\site-packages\plotly\plotly\plotly.pyc in iplot(figure_or_data, **plot_options)
#     132     if 'auto_open' not in plot_options:
#     133         plot_options['auto_open'] = False
# --> 134     url = plot(figure_or_data, **plot_options)
#     135
#     136     if isinstance(figure_or_data, dict):
#
# C:\Anaconda2\lib\site-packages\plotly\plotly\plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     225     data = fig.get('data', [])
#     226     plot_options['layout'] = fig.get('layout', {})
# --> 227     response = v1.clientresp(data, **plot_options)
#     228
# ...

# %%
py.sign_in('bdew', config.plotly_key)
trace1 = {
  "x": ["2017", "2027"], 
  "y": ["2", "29.5"], 
  "marker": {
    "color": "rgb(31, 73, 125)", 
    "line": {"color": "rgb(255, 255, 255)"}
  }, 
  "name": "B", 
  "type": "bar", 
  "uid": "459a26", 
  "xsrc": "bdew:105:64718e", 
  "ysrc": "bdew:105:40f229"
}
data = Data([trace1])
layout = {
  "annotations": [
    {
      "x": 2017, 
      "y": 4, 
      "font": {
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "2%", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 2026.92857143, 
      "y": 31.5, 
      "font": {
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "29.5%", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": -0.0553571428571, 
      "y": 1.37, 
      "font": {
        "color": "rgb(139, 139, 131)", 
        "family": "Balto", 
        "size": 14
      }, 
      "showarrow": False, 
      "text": "<b>Figure 2</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.0625, 
      "y": 1.3, 
      "font": {
        "color": "rgb(31, 73, 125)", 
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "<b>Amazon Profit</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.0232142857143, 
      "y": 1.18974358974, 
      "align": "left", 
      "font": {
        "color": "rgb(139, 139, 131)", 
        "family": "Balto", 
        "size": 13
      }, 
      "showarrow": False, 
      "text": "Current profit as a percent of sales and 2027 <br>projected for P/E ratio of 20 with 2% sales growth", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.05, 
      "y": -0.30, 
      "align": "left", 
      "font": {
        "color": "rgb(127, 127, 127)", 
        "family": "Balto"
      }, 
      "showarrow": False, 
      "text": "cepr.net<br>Source: company financial statements, CEPR calculations", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "height": 400, 
  "hovermode": "closest", 
  "margin": {
    "r": 20, 
    "t": 90, 
    "b": 80, 
    "l": 20
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "shapes": [
    {
      "line": {
        "color": "rgba(139, 139, 131, 100)", 
        "width": 3
      }, 
      "type": "line", 
      "x0": -0.1, 
      "x1": 1.1, 
      "xref": "paper", 
      "y0": 1.39, 
      "y1": 1.39, 
      "yref": "paper"
    }, 
    {
      "line": {
        "color": "rgba(139, 139, 131, 100)", 
        "width": 2
      }, 
      "type": "line", 
      "x0": -0.1, 
      "x1": 1.1, 
      "xref": "paper", 
      "y0": -0.35, 
      "y1": -0.35, 
      "yref": "paper"
    }
  ], 
  "width": 320, 
  "xaxis": {
    "autorange": True, 
    "dtick": 10, 
    "nticks": 2, 
    "range": [2012, 2032], 
    "tick0": -3, 
    "tickfont": {
      "color": "rgb(127, 127, 127)", 
      "family": "Balto", 
      "size": 18
    }, 
    "tickmode": "linear", 
    "title": "", 
    "type": "linear"
  }, 
  "yaxis": {
    "autorange": True, 
    "range": [0, 34], 
    "showgrid": False, 
    "showticklabels": False, 
    "title": "", 
    "type": "linear", 
    "zerolinecolor": "rgb(127, 127, 127)"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename="Amazon_fig2")
#py.image.save_as(fig,'Amazon_fig1.png')
#plot_url =
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bdew/109.embed" height="400px" width="320px"></iframe>

# %%
py.sign_in('bdew', config.plotly_key)
trace1 = {
  "x": ["2017", "2027"], 
  "y": ["0.6", "30.4"], 
  "marker": {
    "color": "rgb(31, 73, 125)", 
    "line": {"color": "rgb(255, 255, 255)"}
  }, 
  "name": "B", 
  "type": "bar", 
  "uid": "459a26", 
  "xsrc": "bdew:105:64718e", 
  "ysrc": "bdew:105:40f229"
}
data = Data([trace1])
layout = {
  "annotations": [
    {
      "x": 2017, 
      "y": 2.6, 
      "font": {
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "0.6%", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 2026.92857143, 
      "y": 32.4, 
      "font": {
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "30.4%", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": -0.0553571428571, 
      "y": 1.37, 
      "font": {
        "color": "rgb(139, 139, 131)", 
        "family": "Balto", 
        "size": 14
      }, 
      "showarrow": False, 
      "text": "<b>Figure 4</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.0625, 
      "y": 1.3, 
      "font": {
        "color": "rgb(31, 73, 125)", 
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "<b>Amazon Non-AWS Profit</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.0232142857143, 
      "y": 1.18974358974, 
      "align": "left", 
      "font": {
        "color": "rgb(139, 139, 131)", 
        "family": "Balto", 
        "size": 13
      }, 
      "showarrow": False, 
      "text": "Current non-AWS profit as percent of sales and 2027<br>projected for P/E ratio of 20 with AWS constant", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.05, 
      "y": -0.30, 
      "align": "left", 
      "font": {
        "color": "rgb(127, 127, 127)", 
        "family": "Balto"
      }, 
      "showarrow": False, 
      "text": "cepr.net<br>Source: company financial statements, CEPR calculations", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "height": 400, 
  "hovermode": "closest", 
  "margin": {
    "r": 20, 
    "t": 90, 
    "b": 80, 
    "l": 20
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "shapes": [
    {
      "line": {
        "color": "rgba(139, 139, 131, 100)", 
        "width": 3
      }, 
      "type": "line", 
      "x0": -0.1, 
      "x1": 1.1, 
      "xref": "paper", 
      "y0": 1.39, 
      "y1": 1.39, 
      "yref": "paper"
    }, 
    {
      "line": {
        "color": "rgba(139, 139, 131, 100)", 
        "width": 2
      }, 
      "type": "line", 
      "x0": -0.1, 
      "x1": 1.1, 
      "xref": "paper", 
      "y0": -0.35, 
      "y1": -0.35, 
      "yref": "paper"
    }
  ], 
  "width": 320, 
  "xaxis": {
    "autorange": True, 
    "dtick": 10, 
    "nticks": 2, 
    "range": [2012, 2032], 
    "tick0": -3, 
    "tickfont": {
      "color": "rgb(127, 127, 127)", 
      "family": "Balto", 
      "size": 18
    }, 
    "tickmode": "linear", 
    "title": "", 
    "type": "linear"
  }, 
  "yaxis": {
    "autorange": True, 
    "range": [0, 35], 
    "showgrid": False, 
    "showticklabels": False, 
    "title": "", 
    "type": "linear", 
    "zerolinecolor": "rgb(127, 127, 127)"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename="Amazon_fig3")
#py.image.save_as(fig,'Amazon_fig1.png')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bdew/111.embed" height="400px" width="320px"></iframe>

# %%
py.sign_in('bdew', config.plotly_key)
trace1 = {
  "x": ["2017", "2027"], 
  "y": ["136", "7700"], 
  "marker": {
    "color": "rgb(31, 73, 125)", 
    "line": {"color": "rgb(255, 255, 255)"}
  }, 
  "name": "B", 
  "type": "bar", 
  "uid": "459a26", 
  "xsrc": "bdew:105:64718e", 
  "ysrc": "bdew:105:40f229"
}
data = Data([trace1])
layout = {
  "annotations": [
    {
      "x": 2017, 
      "y": 536, 
      "font": {
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "$136 Billion", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 2026.92857143, 
      "y": 8100, 
      "font": {
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "$7.7 Trillion", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": -0.0553571428571, 
      "y": 1.37, 
      "font": {
        "color": "rgb(139, 139, 131)", 
        "family": "Balto", 
        "size": 14
      }, 
      "showarrow": False, 
      "text": "<b>Figure 3</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.0625, 
      "y": 1.3, 
      "font": {
        "color": "rgb(31, 73, 125)", 
        "family": "Balto", 
        "size": 20
      }, 
      "showarrow": False, 
      "text": "<b>Amazon Sales, AWS Constant</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.0232142857143, 
      "y": 1.18974358974, 
      "align": "left", 
      "font": {
        "color": "rgb(139, 139, 131)", 
        "family": "Balto", 
        "size": 14
      }, 
      "showarrow": False, 
      "text": "Current sales and projected 2027 sales for<br>P/E ratio of 20 with AWS constant", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.05, 
      "y": -0.30, 
      "align": "left", 
      "font": {
        "color": "rgb(127, 127, 127)", 
        "family": "Balto"
      }, 
      "showarrow": False, 
      "text": "cepr.net<br>Source: company financial statements, CEPR calculations", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "height": 400, 
  "hovermode": "closest", 
  "margin": {
    "r": 20, 
    "t": 90, 
    "b": 80, 
    "l": 20
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "shapes": [
    {
      "line": {
        "color": "rgba(139, 139, 131, 100)", 
        "width": 3
      }, 
      "type": "line", 
      "x0": -0.1, 
      "x1": 1.1, 
      "xref": "paper", 
      "y0": 1.39, 
      "y1": 1.39, 
      "yref": "paper"
    }, 
    {
      "line": {
        "color": "rgba(139, 139, 131, 100)", 
        "width": 2
      }, 
      "type": "line", 
      "x0": -0.1, 
      "x1": 1.1, 
      "xref": "paper", 
      "y0": -0.35, 
      "y1": -0.35, 
      "yref": "paper"
    }
  ], 
  "width": 320, 
  "xaxis": {
    "autorange": True, 
    "dtick": 10, 
    "nticks": 2, 
    "range": [2012, 2032], 
    "tick0": -3, 
    "tickfont": {
      "color": "rgb(127, 127, 127)", 
      "family": "Balto", 
      "size": 18
    }, 
    "tickmode": "linear", 
    "title": "", 
    "type": "linear"
  }, 
  "yaxis": {
    "autorange": True, 
    "range": [0, 8300], 
    "showgrid": False, 
    "showticklabels": False, 
    "title": "", 
    "type": "linear", 
    "zerolinecolor": "rgb(127, 127, 127)"
  }
}
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig, filename="Amazon_fig4")
#py.image.save_as(fig,'Amazon_fig1.png')
