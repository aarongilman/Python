# %% [markdown]
# ### Wins

# %%
import pandas as pd

# %%
df = pd.read_csv('wins.csv')#.set_index(['Type', 'Law_Year'])

# %%
df[df['Type'] == 'State']
# Out:
#     Law_Year       Location sID   Type     Imp  2006  2007  2008  2009  \
# 31      2011    Connecticut  CT  State     NaN   NaN   NaN   NaN   NaN
# 32      2014     California  CA  State     NaN   NaN   NaN   NaN   NaN
# 33      2014  Massachusetts  MA  State     NaN   NaN   NaN   NaN   NaN
# 34      2015         Oregon  OR  State     NaN   NaN   NaN   NaN   NaN
# 35      2016        Vermont  VT  State  2018.0   NaN   NaN   NaN   NaN
# 36      2016     Washington  WA  State  2018.0   NaN   NaN   NaN   NaN
# 37      2016        Arizona  AZ  State     NaN   NaN   NaN   NaN   NaN
#
#         2010      2011      2012      2013      2014      2015      2016
# 31   3579899   3589893   3593795   3596003   3591873   3584730   3576452
# 32  37332685  37676861  38011074  38335203  38680810  38993940  39250017
# 33   6565524   6611923   6658008   6706786   6749911   6784240   6811779
# 34   3838048   3868031   3899116   3925751   3968371   4024634   4093465
# ...
