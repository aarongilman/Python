# %% [markdown]
# ### Census API - ACS Example

# %%
import requests
import pandas as pd

import config
api_key = config.census_key

# %%
base = 'http://api.census.gov/data/'
years = ['2009', '2015']
variables = 'NAME,B01001I_001E,B01001_001E'
state = '10'

# %%
d = {}
for y in years:
    url = '{}{}/acs5?get={}&for=county:*&in=state:{}&key={}'.format(base, y, variables, state, api_key)
    r = requests.get(url).json()
    df = pd.DataFrame(r[1:], columns=r[0]).set_index('NAME')
    df['share'] = df['B01001I_001E'].astype(int) / df['B01001_001E'].astype(int)
    d[y] = df['share']

# %%
base = 'http://api.census.gov/data/'
years = ['2009', '2012', '2015']
variables = 'NAME,B01002_001E'
state = '10'

# %%
d = {}
for y in years:
    url = '{}{}/acs5?get={}&for=county:*&in=state:{}&key={}'.format(base, y, variables, state, api_key)
    r = requests.get(url).json()
    df = pd.DataFrame(r[1:], columns=r[0]).set_index('NAME')
    d[y] = df['B01002_001E']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-1c9b4ad1b5ef> in <module>()
#       2 for y in years:
#       3     url = '{}{}/acs1?get={}&for=county:*&in=state:{}&key={}'.format(base, y, variables, state, api_key)
# ----> 4     r = requests.get(url).json()
#       5     df = pd.DataFrame(r[1:], columns=r[0]).set_index('NAME')
#       6     d[y] = df['B01002_001E']
#
# /home/domestic_ra/anaconda2/lib/python2.7/site-packages/requests/models.pyc in json(self, **kwargs)
#     883                     # used.
#     884                     pass
# --> 885         return complexjson.loads(self.text, **kwargs)
#     886
#     887     @property
#
# /home/domestic_ra/anaconda2/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /home/domestic_ra/anaconda2/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# /home/domestic_ra/anaconda2/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
# --> 382             raise ValueError("No JSON object could be decoded")
#     383         return obj, end
#
# ValueError: No JSON object could be decoded

# %%
base = 'http://api.census.gov/data/'
years = ['2009', '2012', '2015']
variables = 'NAME,B19013_001E'
state = '10'

# %%
d = {}
for y in years:
    url = '{}{}/acs5?get={}&for=state:{}&key={}'.format(base, y, variables, state, api_key)
    r = requests.get(url).json()
    df = pd.DataFrame(r[1:], columns=r[0]).set_index('NAME')
    d[y] = df['B19013_001E']
    
d
# Out:
# {'2009': NAME
#  Delaware    57618
#  Name: B19013_001E, dtype: object, '2012': NAME
#  Delaware    60119
#  Name: B19013_001E, dtype: object, '2015': NAME
#  Delaware    60509
#  Name: B19013_001E, dtype: object}

# %%
df['B19013_001E']
# Out:
# NAME
# Delaware    60509
# Name: B19013_001E, dtype: object

# %%
y = '2015'
url = '{}{}/acs5?get={}&for=state:*&key={}'.format(base, y, variables, api_key)
r = requests.get(url).json()
df = pd.DataFrame(r[1:], columns=r[0]).set_index('NAME')

# %%
df.sort_values('B19013_001E')
# Out:
#                      B19013_001E state
# NAME
# Puerto Rico                19350    72
# Mississippi                39665    28
# Arkansas                   41371    05
# West Virginia              41751    54
# Alabama                    43623    01
# Kentucky                   43740    21
# New Mexico                 44963    35
# Louisiana                  45047    22
# Tennessee                  45219    47
# South Carolina             45483    45
# North Carolina             46868    37
# Oklahoma                   46879    40
# Montana                    47169    30
# Florida                    47507    12
# Idaho                      47583    16
# Missouri                   48173    29
# Indiana                    49255    18
# Maine                      49331    23
# Ohio                       49429    39
# Michigan                   49576    26
# Georgia                    49620    13
# Arizona                    50255    04
# South Dakota               50957    46
# Oregon                     51243    41
# Nevada                     51847    32
# Kansas                     52205    20
# Nebraska                   52997    31
# Iowa                       53183    19
# Texas                      53207    48
# Wisconsin                  53357    55
# Pennsylvania               53599    42
# Vermont                    55176    50
# Rhode Island               56852    44
# North Dakota               57181    38
# Illinois                   57574    17
# Wyoming                    58840    56
# New York                   59269    36
# Delaware                   60509    10
# Colorado                   60629    08
# Utah                       60727    49
# Washington                 61062    53
# Minnesota                  61492    27
# California                 61818    06
# Virginia                   65015    51
# New Hampshire              66779    33
# Massachusetts              68563    25
# Hawaii                     69515    15
# Connecticut                70331    09
# District of Columbia       70848    11
# New Jersey                 72093    34
# Alaska                     72515    02
# Maryland                   74551    24

# %% [markdown]
# ### Working Example - Percent of Working Age Population Earning Less than X

# %%
base = 'http://api.census.gov/data/'
variables = 'NAME,B20004_002E'

# %%
y = '2015'
url = '{}{}/acs5?get={}&for=state:*&key={}'.format(base, y, variables, api_key)
r = requests.get(url).json()
df = pd.DataFrame(r[1:], columns=r[0]).set_index('NAME')

# %%
df
# Out:
#                      B20004_002E state
# NAME
# Alaska                     24957    02
# Alabama                    19422    01
# Arkansas                   20585    05
# Arizona                    19456    04
# California                 19700    06
# Colorado                   22602    08
# Connecticut                22458    09
# District of Columbia       22792    11
# Delaware                   22578    10
# Florida                    18753    12
# Georgia                    19611    13
# Hawaii                     23523    15
# Iowa                       23305    19
# Idaho                      20872    16
# Illinois                   21477    17
# Indiana                    20724    18
# Kansas                     22551    20
# Kentucky                   19565    21
# Louisiana                  20234    22
# Massachusetts              23412    25
# Maryland                   24457    24
# Maine                      20502    23
# Michigan                   18714    26
# Minnesota                  21743    27
# Missouri                   19585    29
# Mississippi                19488    28
# Montana                    18300    30
# North Carolina             18455    37
# North Dakota               25976    38
# Nebraska                   22311    31
# New Hampshire              26001    33
# New Jersey                 21932    34
# New Mexico                 17585    35
# Nevada                     23658    32
# New York                   20205    36
# Ohio                       19702    39
# Oklahoma                   20652    40
# Oregon                     20273    41
# Pennsylvania               21437    42
# Puerto Rico                10661    72
# Rhode Island               23247    44
# South Carolina             18563    45
# South Dakota               21434    46
# Tennessee                  19237    47
# Texas                      20044    48
# Utah                       22009    49
# Virginia                   21914    51
# Vermont                    22305    50
# Washington                 22104    53
# Wisconsin                  21628    55
# West Virginia              19874    54
# Wyoming                    23279    56
