# %% [markdown]
# ### International Monetary Fund API

# %%
import requests

# %%
url = 'http://dataservices.imf.org/REST/SDMX_JSON.svc/'
key = 'CompactData/IFS/M.GB.PCPI_IX' # adjust as needed
data = requests.get('{}{}'.format(url,key)).json()
data['CompactData']['DataSet']['Series']['Obs'][-1]
# Out:
# {u'@BASE_YEAR': u'2010',
#  u'@OBS_VALUE': u'115.075421339659',
#  u'@TIME_PERIOD': u'2017-04'}

# %%
import pandas as pd
pd.DataFrame(data['CompactData']['DataSet']['Series']['Obs'])
# Out:
#     @BASE_YEAR        @OBS_VALUE @TIME_PERIOD
# 0         2010  54.0729416903254      1988-01
# 1         2010  54.2476523258353      1988-02
# 2         2010  54.4223629613453      1988-03
# 3         2010   55.121205503385      1988-04
# 4         2010  55.3832714566499      1988-05
# 5         2010  55.5579820921599      1988-06
# 6         2010  55.5579820921599      1988-07
# 7         2010  55.7326927276698      1988-08
# 8         2010  55.9947586809347      1988-09
# 9         2010  56.2568246341996      1988-10
# 10        2010  56.5188905874645      1988-11
# 11        2010  56.6062459052195      1988-12
# 12        2010  56.7809565407294      1989-01
# 13        2010  56.9556671762394      1989-02
# 14        2010  57.2177331295043      1989-03
# 15        2010   58.003930989299      1989-04
# 16        2010  58.2659969425639      1989-05
# 17        2010  58.5280628958288      1989-06
# 18        2010  58.4407075780738      1989-07
# 19        2010  58.5280628958288      1989-08
# 20        2010  58.9648394846036      1989-09
# 21        2010  59.4016160733785      1989-10
# 22        2010  59.5763267088884      1989-11
# 23        2010  59.6636820266434      1989-12
# 24        2010  59.9257479799083      1990-01
# 25        2010  60.2751692509282      1990-02
# 26        2010   60.624590521948      1990-03
# 27        2010  61.6728543350076      1990-04
# 28        2010  62.2843415592924      1990-05
# 29        2010  62.5464075125573      1990-06
# ..         ...               ...          ...
# 322       2010  111.944117357628      2014-11
# 323       2010  111.944117357628      2014-12
# 324       2010  111.049459077047      2015-01
# 325       2010  111.273123647192      2015-02
# 326       2010  111.496788217337      2015-03
# 327       2010  111.720452787482      2015-04
# 328       2010  111.944117357628      2015-05
# 329       2010    112.0559496427      2015-06
# 330       2010  111.832285072555      2015-07
# 331       2010  112.167781927773      2015-08
# 332       2010    112.0559496427      2015-09
# 333       2010  112.167781927773      2015-10
# 334       2010  112.167781927773      2015-11
# 335       2010  112.167781927773      2015-12
# 336       2010  111.273123647192      2016-01
# 337       2010   111.60862050241      2016-02
# 338       2010    112.0559496427      2016-03
# 339       2010    112.0559496427      2016-04
# 340       2010  112.279614212845      2016-05
# 341       2010   112.50327878299      2016-06
# 342       2010   112.50327878299      2016-07
# 343       2010  112.838775638208      2016-08
# 344       2010  113.062440208353      2016-09
# 345       2010  113.174272493426      2016-10
# 346       2010  113.397937063571      2016-11
# 347       2010  113.957098488934      2016-12
# 348       2010  113.397937063571      2017-01
# 349       2010  114.180763059079      2017-02
# 350       2010  114.628092199369      2017-03
# 351       2010  115.075421339659      2017-04
#
# [352 rows x 3 columns]
