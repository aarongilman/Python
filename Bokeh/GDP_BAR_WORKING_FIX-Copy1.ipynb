# %%
# Import libraries
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime as dt
import time

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, Span, Label, HoverTool, Range1d
from bokeh.embed import components
from bokeh.io import output_notebook
from bokeh.charts import Bar, show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="48c31761-1b15-4606-b469-ae12552f2861">Loading BokehJS ...</span>
#     </div>

# %%
# Retrieve data as pandas dataframe named df
df = web.DataReader('GDPC1', 'fred', dt(2010,1,1))

# Calculate growth rate
df['Y'] = ((1 + (df['GDPC1'] - df['GDPC1'].shift(1))/df['GDPC1'].shift(1))**4 - 1) * 100
df['Y'] = df['Y'].round(1)
# String Date column
df['quarter'] = df.index.quarter
df['year'] = df.index.strftime('%Y')
df['strdate'] = df.year.map(str) + " Q" + df.quarter.map(str)

# Declare variables for chart label
Y = (df['GDPC1'][-1] / 1000).round(decimals=1)
q = df.quarter[-1]
y = df.year[-1]
ch = df['Y'][-1].round(decimals=1)

df = df.dropna()

latest = '{} Q{}: Real GDP: {}T; Growth: {}%'.format(y, q, Y, ch)
xlabel = time.mktime(dt(2010, 7, 3, 2, 0, 0).timetuple())*1000
source = ColumnDataSource({'x': df.index, 'y': df['Y'], 'Date': df.strdate})

def get_width():
    mindate = min(source.data['x'])
    maxdate = max(source.data['x'])
    return 0.8 * (maxdate-mindate).total_seconds()*1000 / len(source.data['x'])

tooltips = """
            <div>
                <span style="font-size: 12px;">@Date:</span>
                <span style="font-size: 12px; font-weight: bold;">@y{1.1}</span>
            </div>
"""
# horizontal line at zero
hline = Span(location=0, dimension='width', line_color='gray', line_width=1)
p = figure(width=700,height=300,x_axis_type='datetime',
           tools=['pan,wheel_zoom,box_zoom,reset'], logo=None,
           toolbar_location="below", toolbar_sticky=False, y_range=Range1d(-3, 6.5))
p.add_layout(hline)
p.sizing_mode = 'scale_width'
p.vbar('x', width=get_width(), bottom=0, top='y', source = source, color='Red', alpha=0, level='overlay')
p.xgrid.grid_line_color = None
p.outline_line_color = 'white'
p.axis.axis_line_color = 'white'
citation = Label(x=xlabel, y=5, render_mode='css', x_units='data', text_font_size='9pt',
                 text_color='#686868', text=latest, background_fill_color='white', background_fill_alpha=1.0)
p.add_layout(citation)
p.add_tools(HoverTool(tooltips=tooltips, show_arrow=False))
p.toolbar.active_drag = None

script, div = components(p)
show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-41c0e1107d40> in <module>()
#      50         toolbar_location='below', toolbar_sticky=False,
#      51         color='Red', xlabel='', ylabel='Annualized percent change')
# ---> 52 p.add_layout(bar)
#      53 p.add_layout(citation)
#      54 p.add_tools(HoverTool(tooltips=tooltips, show_arrow=False))
#
# C:\Users\BDew\Anaconda2\lib\site-packages\bokeh\models\plots.pyc in add_layout(self, obj, place)
#     221             obj.plot = self
#     222
# --> 223         self.renderers.append(obj)
#     224
#     225         if place is not 'center':
#
# C:\Users\BDew\Anaconda2\lib\site-packages\bokeh\core\property\containers.pyc in wrapper(self, *args, **kwargs)
#      75         old = self._saved_copy()
#      76         result = func(self, *args, **kwargs)
# ---> 77         self._notify_owners(old)
#      78         return result
#      79     wrapper.__doc__ = "Container method ``%s`` instrumented to notify property owners" % func.__name__
#
# C:\Users\BDew\Anaconda2\lib\site-packages\bokeh\core\property\containers.pyc in _notify_owners(self, old, hint)
#     102     def _notify_owners(self, old, hint=None):
#     103         for (owner, prop) in self._owners:
# --> 104             prop._notify_mutated(owner, old, hint)
#     105
#     106     def _saved_copy(self):
#
# C:\Users\BDew\Anaconda2\lib\site-packages\bokeh\core\property\descriptors.pyc in _notify_mutated(self, obj, old, hint)
#     808         # re-validate because the contents of 'old' have changed,
#     809         # in some cases this could give us a new object for the value
# --> 810         value = self.property.prepare_value(obj, self.name, value)
#     811
#     812         self._real_set(obj, old, value, hint)
#
# C:\Users\BDew\Anaconda2\lib\site-packages\bokeh\core\property\bases.pyc in prepare_value(self, obj_or_cls, name, value)
#     263                     break
#     264             else:
# --> 265                 raise e
#     266         else:
#     267             value = self.transform(value)
#
# ValueError: expected an element of List(Instance(Renderer)), got seq with invalid items [Chart(id='dc894971-7225-4241-8890-ee5390476bef', ...)]
