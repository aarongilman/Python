# %% [markdown]
# #### Plotly graphs for Taxes and Growth piece

# %%
import pandas as pd
import plotly
import plotly.plotly as py
from plotly.graph_objs import *
from plotly.grid_objs import Column, Grid

import config   ## File with API keys (just to prevent my API keys from being public)
plotly.tools.set_credentials_file(username='bdew', api_key=config.plotly_key)

# %%
df = pd.read_csv('clean.csv').set_index('date')

# %%
df.keys()
# Out:
# Index([u'Shading', u'Prime_Men', u'Prime_Women', u'20-24_Men', u'16-19_Men',
#        u'55-64_Men', u'65-over_Men', u'55-64_Women', u'20-24_Women',
#        u'16-19_Women', u'65-over_Women', u'Prime_Men_White',
#        u'Prime_Men_Black', u'Prime_Men_Hispanic', u'Prime_Women_Black',
#        u'Prime_Women_White', u'Prime_Women_Hispanic', u'16-24_Men',
#        u'16-24_Women', u'25-34_Men', u'35-44_Men', u'45-54_Men',
#        u'25-34_Women', u'45-54_Women', u'35-44_Women'],
#       dtype='object')

# %%
for index, row in df.iterrows():
    df.loc[index,'Prime_Men_text'] = 'Men: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'Prime_Men'].round(1))
    df.loc[index,'Prime_Women_text'] = 'Women: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'Prime_Women'].round(1))
    df.loc[index,'16-24_Men_text'] = '16-24 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'16-24_Men'].round(1))
    df.loc[index,'25-34_Men_text'] = '25-34 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'25-34_Men'].round(1))    
    df.loc[index,'35-44_Men_text'] = '35-44 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'35-44_Men'].round(1))
    df.loc[index,'45-54_Men_text'] = '45-54 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'45-54_Men'].round(1))  
    df.loc[index,'55-64_Men_text'] = '55-64 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'55-64_Men'].round(1))
    df.loc[index,'65-over_Men_text'] = '65+: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'65-over_Men'].round(1))  
    df.loc[index,'16-24_Women_text'] = '16-24 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'16-24_Women'].round(1))
    df.loc[index,'25-34_Women_text'] = '25-34 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'25-34_Women'].round(1))    
    df.loc[index,'35-44_Women_text'] = '35-44 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'35-44_Women'].round(1))
    df.loc[index,'45-54_Women_text'] = '45-54 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'45-54_Women'].round(1))  
    df.loc[index,'55-64_Women_text'] = '55-64 yrs.: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'55-64_Women'].round(1))
    df.loc[index,'65-over_Women_text'] = '65+: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'65-over_Women'].round(1))      
for index, row in df.dropna().iterrows():
    df.loc[index,'Prime_Men_Black_text'] = 'Black: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'Prime_Men_Black'].round(1))
    df.loc[index,'Prime_Men_White_text'] = 'White: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'Prime_Men_White'].round(1))  
    df.loc[index,'Prime_Men_Hispanic_text'] = 'Hispanic: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'Prime_Men_Hispanic'].round(1))    
    df.loc[index,'Prime_Women_Black_text'] = 'Black: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'Prime_Women_Black'].round(1))
    df.loc[index,'Prime_Women_White_text'] = 'White: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'Prime_Women_White'].round(1))  
    df.loc[index,'Prime_Women_Hispanic_text'] = 'Hispanic: {}: {}%'.format(
        pd.to_datetime(index).year,
        df.loc[index,'Prime_Women_Hispanic'].round(1))

# %%
trace1 = {
  "x": df.index,
  "y": df.Shading,
  "fill": "tonexty", 
  "fillcolor": "rgba(135, 143, 135, 0.2)", 
  "hoverinfo": "none", 
  "line": {
    "shape": "hv", 
    "width": 0
  }, 
  "mode": "lines", 
  "name": "Shaded region", 
  "showlegend": False, 
  "type": "scatter"
}
trace2 = {
  "x": df.index,  
  "y": df.Prime_Men,
  "connectgaps": False, 
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 0, 153)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "Men", 
  "opacity": 1, 
  "showlegend": False, 
  "text": df.Prime_Men_text,
  "type": "scatter", 
  "visible": True, 
}
trace3 = {
  "x": df.index,  
  "y": df.Prime_Women,
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 128, 255)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "Women", 
  "showlegend": False, 
  "text": df.Prime_Women_text,
  "type": "scatter"
}
data = Data([trace1, trace2, trace3])
layout = {
  "annotations": [
    {
      "x": -0.036527039269, 
      "y": -0.181328320802, 
      "align": "left", 
      "font": {
        "family": "Open Sans, sans-serif", 
        "size": 10
      }, 
      "showarrow": False, 
      "text": "http://cepr.net<br>Source: Bureau of Labor Statistics, labor force statistics from the current population survey.  ", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.03, 
      "y": 1.15214285714, 
      "align": "left", 
      "font": {
        "family": "Balto", 
        "size": 15
      }, 
      "showarrow": False, 
      "text": "<b>Figure 1. Prime-age employment to population ratio (EPOP)<br> &nbsp;</b><i>Age 25-54, share of population that is employed</i>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.09, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "High-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.84, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "Low-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.751111111111, 
      "y": 0.839285714286, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>Men</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.792777777778, 
      "y": 0.247368421053, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "&lt;b&gt;Women&lt;/b&gt;", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "font": {"family": "Balto"}, 
  "height": 400, 
  "hovermode": "x", 
  "legend": {
    "x": 0.681502859035, 
    "y": 1.09189189189, 
    "font": {"size": 12}, 
    "orientation": "v", 
    "traceorder": "normal"
  }, 
  "margin": {
    "r": 10, 
    "t": 50, 
    "b": 70, 
    "l": 40
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "showlegend": True, 
  "title": "", 
  "titlefont": {
    "family": "Balto", 
    "size": 16
  }, 
  "width": 500, 
  "xaxis": {
    "autorange": False, 
    "fixedrange": True, 
    "nticks": 11, 
    "range": ["1992-06-01", "2012-06-01"], 
    "showgrid": False, 
    "tickfont": {"family": "Balto"}, 
    "ticks": "inside", 
    "ticksuffix": "", 
    "title": "", 
    "type": "date"
  }, 
  "yaxis": {
    "autorange": False, 
    "dtick": 5, 
    "fixedrange": True, 
    "range": [65, 96], 
    "showgrid": True, 
    "showticklabels": True, 
    "tick0": 0, 
    "tickfont": {"family": "Balto"}, 
    "tickmode": "linear", 
    "ticks": "", 
    "ticksuffix": "%", 
    "title": "", 
    "type": "linear"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='EPOPs and taxes_fig1')

# %%
trace1 = {
  "x": df.index,
  "y": df.Shading,
  "fill": "tonexty", 
  "fillcolor": "rgba(135, 143, 135, 0.2)", 
  "hoverinfo": "none", 
  "line": {
    "shape": "hv", 
    "width": 0
  }, 
  "mode": "lines", 
  "name": "Shaded region", 
  "showlegend": False, 
  "type": "scatter"
}
trace2 = {
  "x": df.index,  
  "y": df.Prime_Men_Black,
  "connectgaps": False, 
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 128, 255)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "Black", 
  "opacity": 1, 
  "showlegend": False, 
  "text": df.Prime_Men_Black_text,
  "type": "scatter", 
  "visible": True, 
}
trace3 = {
  "x": df.index,  
  "y": df.Prime_Men_White,
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 0, 153)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "White", 
  "showlegend": False, 
  "text": df.Prime_Men_White_text,
  "type": "scatter"
}
trace4 = {
  "x": df.index,  
  "y": df.Prime_Men_Hispanic,
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(140, 176, 242)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "Hispanic", 
  "showlegend": False, 
  "text": df.Prime_Men_Hispanic_text,
  "type": "scatter"
}
data = Data([trace1, trace2, trace3, trace4])
layout = {
  "annotations": [
    {
      "x": -0.04, 
      "y": -0.181328320802, 
      "align": "left", 
      "font": {
        "family": "Open Sans, sans-serif", 
        "size": 10
      }, 
      "showarrow": False, 
      "text": "http://cepr.net<br>Source: Bureau of Labor Statistics, labor force statistics from the current population survey.  ", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.04, 
      "y": 1.15214285714, 
      "align": "left", 
      "font": {
        "family": "Balto", 
        "size": 15
      }, 
      "showarrow": False, 
      "text": "<b>Figure 2. Prime-age employment to population ratio (EPOP), men<br> &nbsp;</b><i>Age 25-54, share of population that is employed, by race or origin</i>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.09, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "High-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.84, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "Low-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0377777777777, 
      "y": 0.892857142857, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>White</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0550000000002, 
      "y": 0.275939849624, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>Black</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0422222222222, 
      "y": 0.592857142857, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>Hispanic</b>", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "font": {"family": "Balto"}, 
  "height": 400, 
  "hovermode": "x", 
  "legend": {
    "x": 0.681502859035, 
    "y": 1.09189189189, 
    "font": {"size": 12}, 
    "orientation": "v", 
    "traceorder": "normal"
  }, 
  "margin": {
    "r": 10, 
    "t": 50, 
    "b": 70, 
    "l": 40
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "showlegend": True, 
  "title": "", 
  "titlefont": {
    "family": "Balto", 
    "size": 16
  }, 
  "width": 500, 
  "xaxis": {
    "autorange": False, 
    "fixedrange": True, 
    "nticks": 11, 
    "range": ["1992-06-01", "2012-06-01"], 
    "showgrid": False, 
    "tickfont": {"family": "Balto"}, 
    "ticks": "inside", 
    "ticksuffix": "", 
    "title": "", 
    "type": "date"
  }, 
  "yaxis": {
    "autorange": False, 
    "dtick": 5, 
    "fixedrange": True, 
    "range": [65, 96], 
    "showgrid": True, 
    "showticklabels": True, 
    "tick0": 0, 
    "tickfont": {"family": "Balto"}, 
    "tickmode": "linear", 
    "ticks": "", 
    "ticksuffix": "%", 
    "title": "", 
    "type": "linear"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='EPOPs and taxes_fig2')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bdew/123.embed" height="400px" width="500px"></iframe>

# %%
trace1 = {
  "x": df.index,
  "y": df.Shading,
  "fill": "tonexty", 
  "fillcolor": "rgba(135, 143, 135, 0.2)", 
  "hoverinfo": "none", 
  "line": {
    "shape": "hv", 
    "width": 0
  }, 
  "mode": "lines", 
  "name": "Shaded region", 
  "showlegend": False, 
  "type": "scatter"
}
trace2 = {
  "x": df.index,  
  "y": df.Prime_Women_Black,
  "connectgaps": False, 
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 128, 255)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "Black", 
  "opacity": 1, 
  "showlegend": False, 
  "text": df.Prime_Women_Black_text,
  "type": "scatter", 
  "visible": True, 
}
trace3 = {
  "x": df.index,  
  "y": df.Prime_Women_White,
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 0, 153)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "White", 
  "showlegend": False, 
  "text": df.Prime_Women_White_text,
  "type": "scatter"
}
trace4 = {
  "x": df.index,  
  "y": df.Prime_Women_Hispanic,
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(140, 176, 242)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "Hispanic", 
  "showlegend": False, 
  "text": df.Prime_Women_Hispanic_text,
  "type": "scatter"
}
data = Data([trace1, trace2, trace3, trace4])
layout = {
  "annotations": [
    {
      "x": -0.04, 
      "y": -0.181328320802, 
      "align": "left", 
      "font": {
        "family": "Open Sans, sans-serif", 
        "size": 10
      }, 
      "showarrow": False, 
      "text": "http://cepr.net<br>Source: Bureau of Labor Statistics, labor force statistics from the current population survey.  ", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.04, 
      "y": 1.15214285714, 
      "align": "left", 
      "font": {
        "family": "Balto", 
        "size": 15
      }, 
      "showarrow": False, 
      "text": "<b>Figure 3. Prime-age employment to population ratio (EPOP), women<br> &nbsp;</b><i>Age 25-54, share of population that is employed, by race or origin</i>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.09, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "High-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.84, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "Low-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0377777777777, 
      "y": 0.892857142857, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>White</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0305555555558, 
      "y": 0.475939849624, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>Black</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0422222222222, 
      "y": 0.0249999999999, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>Hispanic</b>", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "font": {"family": "Balto"}, 
  "height": 400, 
  "hovermode": "x", 
  "legend": {
    "x": 0.681502859035, 
    "y": 1.09189189189, 
    "font": {"size": 12}, 
    "orientation": "v", 
    "traceorder": "normal"
  }, 
  "margin": {
    "r": 10, 
    "t": 50, 
    "b": 70, 
    "l": 40
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "showlegend": True, 
  "title": "", 
  "titlefont": {
    "family": "Balto", 
    "size": 16
  }, 
  "width": 500, 
  "xaxis": {
    "autorange": False, 
    "fixedrange": True, 
    "nticks": 11, 
    "range": ["1992-06-01", "2012-06-01"], 
    "showgrid": False, 
    "tickfont": {"family": "Balto"}, 
    "ticks": "inside", 
    "ticksuffix": "", 
    "title": "", 
    "type": "date"
  }, 
  "yaxis": {
    "autorange": False, 
    "dtick": 5, 
    "fixedrange": True, 
    "range": [55, 78], 
    "showgrid": True, 
    "showticklabels": True, 
    "tick0": 0, 
    "tickfont": {"family": "Balto"}, 
    "tickmode": "linear", 
    "ticks": "", 
    "ticksuffix": "%", 
    "title": "", 
    "type": "linear"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='EPOPs and taxes_fig3')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bdew/125.embed" height="400px" width="500px"></iframe>

# %%
trace1 = {
  "x": df.index,
  "y": df['Shading'],
  "fill": "tonexty", 
  "fillcolor": "rgba(135, 143, 135, 0.2)", 
  "hoverinfo": "none", 
  "line": {
    "shape": "hv", 
    "width": 0
  }, 
  "mode": "lines", 
  "name": "Shaded region", 
  "showlegend": False, 
  "type": "scatter"
}
trace2 = {
  "x": df.index,  
  "y": df['25-34_Men'],
  "connectgaps": False, 
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 128, 255)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "25-34_Men", 
  "opacity": 1, 
  "showlegend": False, 
  "text": df['25-34_Men_text'],
  "type": "scatter", 
  "visible": True, 
}
trace3 = {
  "x": df.index,  
  "y": df['35-44_Men'],
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 0, 153)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "35-44_Men", 
  "showlegend": False, 
  "text": df['35-44_Men_text'],
  "type": "scatter"
}
trace4 = {
  "x": df.index,  
  "y": df['45-54_Men'],
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(140, 176, 242)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "45-54 Men", 
  "showlegend": False, 
  "text": df['45-54_Men_text'],
  "type": "scatter"
}
data = Data([trace1, trace2, trace3, trace4])
layout = {
  "annotations": [
    {
      "x": -0.04, 
      "y": -0.181328320802, 
      "align": "left", 
      "font": {
        "family": "Open Sans, sans-serif", 
        "size": 10
      }, 
      "showarrow": False, 
      "text": "http://cepr.net<br>Source: Bureau of Labor Statistics, labor force statistics from the current population survey.  ", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.04, 
      "y": 1.15214285714, 
      "align": "left", 
      "font": {
        "family": "Balto", 
        "size": 15
      }, 
      "showarrow": False, 
      "text": "<b>Figure 4a. Employment to population ratio (EPOP), men<br> &nbsp;</b><i>Share of prime-age population that is employed, by age group</i>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.09, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "High-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.84, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "Low-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.533333333333, 
      "y": 0.360714285715, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>45-54</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.897222222223, 
      "y": 0.840225563909, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>35-44</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.742222222223, 
      "y": 0.621428571428, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>25-34</b>", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "font": {"family": "Balto"}, 
  "height": 400, 
  "hovermode": "x", 
  "legend": {
    "x": 0.681502859035, 
    "y": 1.09189189189, 
    "font": {"size": 12}, 
    "orientation": "v", 
    "traceorder": "normal"
  }, 
  "margin": {
    "r": 10, 
    "t": 50, 
    "b": 70, 
    "l": 40
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "showlegend": True, 
  "title": "", 
  "titlefont": {
    "family": "Balto", 
    "size": 16
  }, 
  "width": 500, 
  "xaxis": {
    "autorange": False, 
    "fixedrange": True, 
    "nticks": 11, 
    "range": ["1992-06-01", "2012-06-01"], 
    "showgrid": False, 
    "tickfont": {"family": "Balto"}, 
    "ticks": "inside", 
    "ticksuffix": "", 
    "title": "", 
    "type": "date"
  }, 
  "yaxis": {
    "autorange": False, 
    "dtick": 5, 
    "fixedrange": True, 
    "range": [78, 92], 
    "showgrid": True, 
    "showticklabels": True, 
    "tick0": 0, 
    "tickfont": {"family": "Balto"}, 
    "tickmode": "linear", 
    "ticks": "", 
    "ticksuffix": "%", 
    "title": "", 
    "type": "linear"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='EPOPs and taxes_fig4a')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bdew/127.embed" height="400px" width="500px"></iframe>

# %%
trace1 = {
  "x": df.index,
  "y": df['Shading'],
  "fill": "tonexty", 
  "fillcolor": "rgba(135, 143, 135, 0.2)", 
  "hoverinfo": "none", 
  "line": {
    "shape": "hv", 
    "width": 0
  }, 
  "mode": "lines", 
  "name": "Shaded region", 
  "showlegend": False, 
  "type": "scatter"
}
trace2 = {
  "x": df.index,  
  "y": df['55-64_Men'],
  "connectgaps": False, 
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 128, 255)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "55-64_Men", 
  "opacity": 1, 
  "showlegend": False, 
  "text": df['55-64_Men_text'],
  "type": "scatter", 
  "visible": True, 
}
trace3 = {
  "x": df.index,  
  "y": df['65-over_Men'],
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 0, 153)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "65-over_Men", 
  "showlegend": False, 
  "text": df['65-over_Men_text'],
  "type": "scatter"
}
trace4 = {
  "x": df.index,  
  "y": df['16-24_Men'],
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(140, 176, 242)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "16-24 Men", 
  "showlegend": False, 
  "text": df['16-24_Men_text'],
  "type": "scatter"
}
data = Data([trace1, trace2, trace3, trace4])
layout = {
  "annotations": [
    {
      "x": -0.04, 
      "y": -0.181328320802, 
      "align": "left", 
      "font": {
        "family": "Open Sans, sans-serif", 
        "size": 10
      }, 
      "showarrow": False, 
      "text": "http://cepr.net<br>Source: Bureau of Labor Statistics, labor force statistics from the current population survey.  ", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.04, 
      "y": 1.15214285714, 
      "align": "left", 
      "font": {
        "family": "Balto", 
        "size": 15
      }, 
      "showarrow": False, 
      "text": "<b>Figure 4b. Employment to population ratio (EPOP), men<br> &nbsp;</b><i>Share of population that is employed, by age group</i>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.09, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "High-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.84, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "Low-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.963333333333, 
      "y": 0.825000000001, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>55-64</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0438888888897, 
      "y": 0.0509398496233, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>65+</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.742222222223, 
      "y": 0.621428571428, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>16-24</b>", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "font": {"family": "Balto"}, 
  "height": 400, 
  "hovermode": "x", 
  "legend": {
    "x": 0.681502859035, 
    "y": 1.09189189189, 
    "font": {"size": 12}, 
    "orientation": "v", 
    "traceorder": "normal"
  }, 
  "margin": {
    "r": 10, 
    "t": 50, 
    "b": 70, 
    "l": 40
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "showlegend": True, 
  "title": "", 
  "titlefont": {
    "family": "Balto", 
    "size": 16
  }, 
  "width": 500, 
  "xaxis": {
    "autorange": False, 
    "fixedrange": True, 
    "nticks": 11, 
    "range": ["1992-06-01", "2012-06-01"], 
    "showgrid": False, 
    "tickfont": {"family": "Balto"}, 
    "ticks": "inside", 
    "ticksuffix": "", 
    "title": "", 
    "type": "date"
  }, 
  "yaxis": {
    "autorange": False, 
    "dtick": 10, 
    "fixedrange": True, 
    "range": [14, 75], 
    "showgrid": True, 
    "showticklabels": True, 
    "tick0": 0, 
    "tickfont": {"family": "Balto"}, 
    "tickmode": "linear", 
    "ticks": "", 
    "ticksuffix": "%", 
    "title": "", 
    "type": "linear"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='EPOPs and taxes_fig4b')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bdew/131.embed" height="400px" width="500px"></iframe>

# %%
trace1 = {
  "x": df.index,
  "y": df['Shading'],
  "fill": "tonexty", 
  "fillcolor": "rgba(135, 143, 135, 0.2)", 
  "hoverinfo": "none", 
  "line": {
    "shape": "hv", 
    "width": 0
  }, 
  "mode": "lines", 
  "name": "Shaded region", 
  "showlegend": False, 
  "type": "scatter"
}
trace2 = {
  "x": df.index,  
  "y": df['25-34_Women'],
  "connectgaps": False, 
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 128, 255)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "25-34_Women", 
  "opacity": 1, 
  "showlegend": False, 
  "text": df['25-34_Women_text'],
  "type": "scatter", 
  "visible": True, 
}
trace3 = {
  "x": df.index,  
  "y": df['35-44_Women'],
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 0, 153)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "35-44_Women", 
  "showlegend": False, 
  "text": df['35-44_Women_text'],
  "type": "scatter"
}
trace4 = {
  "x": df.index,  
  "y": df['45-54_Women'],
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(140, 176, 242)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "45-54 Women", 
  "showlegend": False, 
  "text": df['45-54_Women_text'],
  "type": "scatter"
}
data = Data([trace1, trace2, trace3, trace4])
layout = {
  "annotations": [
    {
      "x": -0.04, 
      "y": -0.181328320802, 
      "align": "left", 
      "font": {
        "family": "Open Sans, sans-serif", 
        "size": 10
      }, 
      "showarrow": False, 
      "text": "http://cepr.net<br>Source: Bureau of Labor Statistics, labor force statistics from the current population survey.  ", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.04, 
      "y": 1.15214285714, 
      "align": "left", 
      "font": {
        "family": "Balto", 
        "size": 15
      }, 
      "showarrow": False, 
      "text": "<b>Figure 5a. Employment to population ratio (EPOP), women<br> &nbsp;</b><i>Share of prime-age population that is employed, by age group</i>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.09, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "High-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.84, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "Low-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.853333333333, 
      "y": 0.757142857144, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>45-54</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0261111111119, 
      "y": 0.783082706766, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>35-44</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0533333333341, 
      "y": 0.207142857142, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>25-34</b>", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "font": {"family": "Balto"}, 
  "height": 400, 
  "hovermode": "x", 
  "legend": {
    "x": 0.681502859035, 
    "y": 1.09189189189, 
    "font": {"size": 12}, 
    "orientation": "v", 
    "traceorder": "normal"
  }, 
  "margin": {
    "r": 10, 
    "t": 50, 
    "b": 70, 
    "l": 40
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "showlegend": True, 
  "title": "", 
  "titlefont": {
    "family": "Balto", 
    "size": 16
  }, 
  "width": 500, 
  "xaxis": {
    "autorange": False, 
    "fixedrange": True, 
    "nticks": 11, 
    "range": ["1992-06-01", "2012-06-01"], 
    "showgrid": False, 
    "tickfont": {"family": "Balto"}, 
    "ticks": "inside", 
    "ticksuffix": "", 
    "title": "", 
    "type": "date"
  }, 
  "yaxis": {
    "autorange": False, 
    "dtick": 5, 
    "fixedrange": True, 
    "range": [65, 78], 
    "showgrid": True, 
    "showticklabels": True, 
    "tick0": 0, 
    "tickfont": {"family": "Balto"}, 
    "tickmode": "linear", 
    "ticks": "", 
    "ticksuffix": "%", 
    "title": "", 
    "type": "linear"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='EPOPs and taxes_fig5a')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bdew/129.embed" height="400px" width="500px"></iframe>

# %%
trace1 = {
  "x": df.index,
  "y": df['Shading'],
  "fill": "tonexty", 
  "fillcolor": "rgba(135, 143, 135, 0.2)", 
  "hoverinfo": "none", 
  "line": {
    "shape": "hv", 
    "width": 0
  }, 
  "mode": "lines", 
  "name": "Shaded region", 
  "showlegend": False, 
  "type": "scatter"
}
trace2 = {
  "x": df.index,  
  "y": df['55-64_Women'],
  "connectgaps": False, 
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 128, 255)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "55-64_Women", 
  "opacity": 1, 
  "showlegend": False, 
  "text": df['55-64_Women_text'],
  "type": "scatter", 
  "visible": True, 
}
trace3 = {
  "x": df.index,  
  "y": df['65-over_Women'],
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(0, 0, 153)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "65-over_Women", 
  "showlegend": False, 
  "text": df['65-over_Women_text'],
  "type": "scatter"
}
trace4 = {
  "x": df.index,  
  "y": df['16-24_Women'],
  "hoverinfo": "text", 
  "line": {
    "color": "rgb(140, 176, 242)", 
    "width": 3
  }, 
  "mode": "lines", 
  "name": "16-24 Women", 
  "showlegend": False, 
  "text": df['16-24_Women_text'],
  "type": "scatter"
}
data = Data([trace1, trace2, trace3, trace4])
layout = {
  "annotations": [
    {
      "x": -0.04, 
      "y": -0.181328320802, 
      "align": "left", 
      "font": {
        "family": "Open Sans, sans-serif", 
        "size": 10
      }, 
      "showarrow": False, 
      "text": "http://cepr.net<br>Source: Bureau of Labor Statistics, labor force statistics from the current population survey.  ", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": -0.04, 
      "y": 1.15214285714, 
      "align": "left", 
      "font": {
        "family": "Balto", 
        "size": 15
      }, 
      "showarrow": False, 
      "text": "<b>Figure 5b. Employment to population ratio (EPOP), women<br> &nbsp;</b><i>Share of population that is employed, by age group</i>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.09, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "High-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.84, 
      "y": 0.98, 
      "font": {"size": 18}, 
      "showarrow": False, 
      "text": "Low-tax period", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0611111111108, 
      "y": 0.603571428572, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>55-64</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0350000000008, 
      "y": 0.0723684210519, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>65+</b>", 
      "xref": "paper", 
      "yref": "paper"
    }, 
    {
      "x": 0.0288888888897, 
      "y": 0.878571428571, 
      "font": {"size": 20}, 
      "showarrow": False, 
      "text": "<b>16-24</b>", 
      "xref": "paper", 
      "yref": "paper"
    }
  ], 
  "autosize": False, 
  "font": {"family": "Balto"}, 
  "height": 400, 
  "hovermode": "x", 
  "legend": {
    "x": 0.681502859035, 
    "y": 1.09189189189, 
    "font": {"size": 12}, 
    "orientation": "v", 
    "traceorder": "normal"
  }, 
  "margin": {
    "r": 10, 
    "t": 50, 
    "b": 70, 
    "l": 40
  }, 
  "paper_bgcolor": "rgb(255, 252, 245)", 
  "plot_bgcolor": "rgb(255, 252, 245)", 
  "showlegend": True, 
  "title": "", 
  "titlefont": {
    "family": "Balto", 
    "size": 16
  }, 
  "width": 500, 
  "xaxis": {
    "autorange": False, 
    "fixedrange": True, 
    "nticks": 11, 
    "range": ["1992-06-01", "2012-06-01"], 
    "showgrid": False, 
    "tickfont": {"family": "Balto"}, 
    "ticks": "inside", 
    "ticksuffix": "", 
    "title": "", 
    "type": "date"
  }, 
  "yaxis": {
    "autorange": False, 
    "dtick": 10, 
    "fixedrange": True, 
    "range": [5, 69], 
    "showgrid": True, 
    "showticklabels": True, 
    "tick0": 0, 
    "tickfont": {"family": "Balto"}, 
    "tickmode": "linear", 
    "ticks": "", 
    "ticksuffix": "%", 
    "title": "", 
    "type": "linear"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='EPOPs and taxes_fig5b')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bdew/133.embed" height="400px" width="500px"></iframe>
