# %% [markdown]
# ### Trade-weighted U.S. dollar
#
# Objective: plot changes to the value of the trade-weighted U.S. dollar (broad index ['DTWEXB'] and against major currencies ['DTWEXM'])

# %%
# %matplotlib inline
import pandas_datareader.data as webdata
webdata.DataReader(['DTWEXM','DTWEXB'], 'fred').plot(
    title='Trade-weighted U.S. Dollar Indices')
