# %% [markdown]
# Note November 19, 2017:
#
# File still messy. Need to clean up. Text labels currently misleading--showing percent change in jobs not unemp.
#
#
#
#
#
#
#
# ## U.S. Unemployment Rate Change by Metropolitan Statistical Area (MSA)

# %% [markdown]
# Created by Brian Dew (brianwdew@gmail.com), March 27, 2017.
#
# The goal of this notebook is to create a U.S. map that shows how unemployment rates are changing by city. '
#
# See https://www.bls.gov/lau/ for advance release information.
#
# https://download.bls.gov/pub/time.series/la/la.areamaps (list of codes of all local areas)
#
# http://gis.stackexchange.com/questions/198530/plotting-us-cities-on-a-map-with-matplotlib-and-basemap
#
# http://stackoverflow.com/questions/39742305/how-to-use-basemap-python-to-plot-us-with-50-states
#
# This folder on GitHub (https://github.com/bdecon/Python/Unemp_Map) contains four files needed to make the code work:
# 1. MSA.csv - contains the names, codes, and locations for metropolitan statistical areas
# 2. st99_d00.dbf - one of the files used for drawing state shapes
# 3. st99_d00.shp - main state shapefile
# 4. st99_d00.shx - final file for drawing state shapes

# %% [markdown]
# ### Obtaining the city locations and their unemployment rate change values
#
# First, we load the pandas and matplotlib libraries that will allow us to work with data and map it. The second step is to load both the data that do not change (city names, codes, and locations) and the data that do change (BLS unemployment rate estimates). The third step is to combine the two datasets.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from mpl_toolkits.basemap import Basemap as Basemap

# %%
# CSV file contains city names, their BLS codes (Metropolitan 
# MTAs/NECTAs only), and their latitude and longitude
MSA = pd.read_csv('MSA-e.csv')

# BLS flat file contains the unemployment rate by month since 2015
url = 'https://download.bls.gov/pub/time.series/la/la.data.0.CurrentU15-19'
df = pd.read_table(url, sep='\s+', low_memory=False)
# Out:
# c:\users\bdew\anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Take only the unemployment data for MSAs and monthly series 
# (M13 is annual average)
df = pd.DataFrame(df[df['series_id'].isin(MSA['fullcode']) 
                 & ~df['period'].isin(['M13'])])

# Clean up the date to convert it to pandas datetime
df.loc[:,'month'] = df['period'].replace(regex=True, 
                                         to_replace=r'M', 
                                         value=r'')
df.loc[:,'day'] = 1
df.loc[:,'date'] = pd.to_datetime(df[['year', 'month', 'day']])
df = df.set_index(['series_id','date'])

# Calculate one year change in unemployment rate for each MSA
df.loc[:,'value'] = df['value'].astype('float')
df.loc[:,'value_ch'] = df['value'].pct_change(periods=12)

# Keep only the latest value for each MSA
df = df.reset_index().groupby(['series_id']).tail(1)
df.rename(columns={'series_id':'fullcode'}, inplace=True)

# Take the date for use in chart title
date = df['date'].iloc[0].strftime('%B %Y')

# Combine the two datasets and show 2 rows to verify 
unemp_list = df.merge(MSA, on='fullcode')

# %%
# Settings for the map
m = Basemap(llcrnrlon=-96, llcrnrlat=37, urcrnrlon=-72, urcrnrlat=46, resolution='i',
            projection='lcc', lat_1=33, lat_2=45, lon_0=-90)
# Show full US:
#m = Basemap(llcrnrlon=-121, llcrnrlat=20, urcrnrlon=-64, urcrnrlat=49, resolution='i',
#            projection='lcc', lat_1=33, lat_2=45, lon_0=-95)

# %%
# From the change in unemployment rate, mark increases red, decreases green,
#   no change is gray. The size of the circle to draw is the absolute value 
#   of the change times 8. Alaska and Hawaii are shifted (Alaska is also 
#   scaled down) and locations are otherwise mapped.

for index, row in unemp_list.iterrows():
    x, y = m(row['longitude'],row['latitude'])
    unemp_list.loc[index,'x'] = x
    unemp_list.loc[index,'y'] = y
    if row['value_ch'] < 0:
        unemp_list.loc[index,'color'] = 'Red'
        unemp_list.loc[index,'size'] = abs(row['value_ch'])*500
    if row['value_ch'] > 0:
        unemp_list.loc[index,'color'] = 'Limegreen'
        unemp_list.loc[index,'size'] = abs(row['value_ch'])*500
    if row['value_ch'] == 0:
        unemp_list.loc[index,'color'] = 'Lightgray'
        unemp_list.loc[index,'size'] = 10   # Just to mark location

# %% [markdown]
# ### Mapping the values
#
# The second part involves mapping the data. There are three map/shape files located in the same folder as the ipynb, which are read by the basemap package as U.S. states. To include Alaska and Hawaii, the values for these two states are transformed. Alaska is scaled down to 35 percent of it's actual size and moved, with Hawaii to fit underneath the continental U.S.

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.patches import PathPatch
import numpy as np

plt.gcf()
fig = plt.figure(figsize=(16,12))

# Read the shapefile contained in the same folder (and the two related files)
m.readshapefile('st99_d00', 'states', drawbounds=True, color='grey')
m.readshapefile('roadtrl020', 'roads', drawbounds=False)
m.readshapefile('cb_2016_us_csa_500k', 'msa', drawbounds=False, color='grey')
#m.drawlsmask(land_color='#F2F3F4',ocean_color='white', resolution='i')
m.fillcontinents(color='#F2F3F4')
ax = plt.gca()

for info, shape in zip(m.roads_info, m.roads):
    if 'Highway' in info['FEATURE']:
        x, y = zip(*shape) 
        m.plot(x, y, marker=None,color='lightgray')

patches   = []

for info, shape in zip(m.msa_info, m.msa):
    if info['NAME'] == 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA':
        patches.append( Polygon(np.array(shape), True) )
        
ax.add_collection(PatchCollection(patches, facecolor= 'blue', edgecolor='k', alpha=0.1, linewidths=1., zorder=2))

# Plot each location, value, and color as identified in the previous section        
for index, row in unemp_list.iterrows():
    m.plot(row['x'], row['y'], marker='o', color=row['color'], alpha=0.5, 
           markersize = row['size'], markeredgecolor='Black', markeredgewidth=.25)

ax.axis('off')    # Remove default border
plt.title('One-year Change in Unemployment Rate, as of ' + date)
plt.annotate('Data Source: U.S. Bureau of Labor Statistics, Local Area Unemployment Statistics; \n' \
             'Code: https://github.com/bdecon/Python/tree/master/Unemp_Map',
             (0,0), (0, 0), fontsize=9, xycoords='axes fraction', textcoords='offset points', va='top')

# Legend 
l1 = plt.scatter([],[], marker='o',color='Limegreen', alpha=0.5, 
              s = 130, edgecolors='Black', linewidth=.25)
l2 = plt.scatter([],[], marker='o',color='Red', alpha=0.5, 
              s = 130, edgecolors='Black', linewidth=.25)

labels = ["$-$1%", "+1%"]

leg = plt.legend([l1, l2], labels, ncol=1, frameon=False, fontsize=10,
    handlelength=2, loc = 2, borderpad = 1.8,
    handletextpad=1, title='Legend', scatterpoints = 1)
plt.savefig('C:\Users\BDew\Dropbox (CEPR)\homestata\Brian\For_Alan\State_Labor\Graphics\unemp_map.pdf', bbox_inches='tight', dpi=500)
plt.show()

# %%
m.roads_info
# Out:
# [{'FEATURE': 'Other Highway',
#   'FNODE_': 1,
#   'LENGTH': 0.041,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 1,
#   'RPOLY_': 0,
#   'SHAPENUM': 1,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 2},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 2,
#   'LENGTH': 0.023,
#   'LPOLY_': 0,
#   'NAME': 'State Route 131',
#   'RINGNUM': 1,
#   'ROADTRL020': 2,
#   'RPOLY_': 0,
#   'SHAPENUM': 2,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 3},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 15,
#   'LENGTH': 0.658,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 3,
#   'RPOLY_': 0,
#   'SHAPENUM': 3,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 14},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 50,
#   'LENGTH': 0.54,
#   'LPOLY_': 0,
#   'NAME': 'State Route 3',
#   'RINGNUM': 1,
#   'ROADTRL020': 4,
#   'RPOLY_': 0,
#   'SHAPENUM': 4,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 43},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 52,
#   'LENGTH': 0.395,
#   'LPOLY_': 0,
#   'NAME': 'State Route 3',
#   'RINGNUM': 1,
#   'ROADTRL020': 5,
#   'RPOLY_': 0,
#   'SHAPENUM': 5,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 50},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 55,
#   'LENGTH': 0.235,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 6,
#   'RPOLY_': 0,
#   'SHAPENUM': 6,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 56},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 52,
#   'LENGTH': 0.555,
#   'LPOLY_': 0,
#   'NAME': 'State Route 3',
#   'RINGNUM': 1,
#   'ROADTRL020': 7,
#   'RPOLY_': 0,
#   'SHAPENUM': 7,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 60},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 65,
#   'LENGTH': 0.023,
#   'LPOLY_': 0,
#   'NAME': 'State Route 411',
#   'RINGNUM': 1,
#   'ROADTRL020': 8,
#   'RPOLY_': 0,
#   'SHAPENUM': 8,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 66},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 60,
#   'LENGTH': 2.006,
#   'LPOLY_': 0,
#   'NAME': 'State Route 3',
#   'RINGNUM': 1,
#   'ROADTRL020': 9,
#   'RPOLY_': 0,
#   'SHAPENUM': 9,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 69},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 71,
#   'LENGTH': 0.329,
#   'LPOLY_': 0,
#   'NAME': 'State Route 3',
#   'RINGNUM': 1,
#   'ROADTRL020': 10,
#   'RPOLY_': 0,
#   'SHAPENUM': 10,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 69},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 72,
#   'LENGTH': 0.082,
#   'LPOLY_': 0,
#   'NAME': 'State Route 5, State Route 786',
#   'RINGNUM': 1,
#   'ROADTRL020': 11,
#   'RPOLY_': 0,
#   'SHAPENUM': 11,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 74},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 76,
#   'LENGTH': 0.434,
#   'LPOLY_': 0,
#   'NAME': 'State Route 3',
#   'RINGNUM': 1,
#   'ROADTRL020': 12,
#   'RPOLY_': 0,
#   'SHAPENUM': 12,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 71},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 79,
#   'LENGTH': 1.475,
#   'LPOLY_': 0,
#   'NAME': 'State Route 4',
#   'RINGNUM': 1,
#   'ROADTRL020': 13,
#   'RPOLY_': 0,
#   'SHAPENUM': 13,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 67},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 82,
#   'LENGTH': 0.039,
#   'LPOLY_': 0,
#   'NAME': 'State Route 3',
#   'RINGNUM': 1,
#   'ROADTRL020': 14,
#   'RPOLY_': 0,
#   'SHAPENUM': 14,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 83},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 85,
#   'LENGTH': 0.071,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 15,
#   'RPOLY_': 0,
#   'SHAPENUM': 15,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 87},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 88,
#   'LENGTH': 0.277,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 16,
#   'RPOLY_': 0,
#   'SHAPENUM': 16,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 89},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 91,
#   'LENGTH': 0.021,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 17,
#   'RPOLY_': 0,
#   'SHAPENUM': 17,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 89},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 91,
#   'LENGTH': 0.009,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 18,
#   'RPOLY_': 0,
#   'SHAPENUM': 18,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 93},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 100,
#   'LENGTH': 0.026,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 19,
#   'RPOLY_': 0,
#   'SHAPENUM': 19,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 99},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 107,
#   'LENGTH': 2.989,
#   'LPOLY_': 0,
#   'NAME': 'State Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 20,
#   'RPOLY_': 0,
#   'SHAPENUM': 20,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 67},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 107,
#   'LENGTH': 0.368,
#   'LPOLY_': 0,
#   'NAME': 'State Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 21,
#   'RPOLY_': 0,
#   'SHAPENUM': 21,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 117},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 119,
#   'LENGTH': 2.607,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 22,
#   'RPOLY_': 0,
#   'SHAPENUM': 22,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 88},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 120,
#   'LENGTH': 0.958,
#   'LPOLY_': 0,
#   'NAME': 'State Route 4',
#   'RINGNUM': 1,
#   'ROADTRL020': 23,
#   'RPOLY_': 0,
#   'SHAPENUM': 23,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 79},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 121,
#   'LENGTH': 1.491,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 24,
#   'RPOLY_': 0,
#   'SHAPENUM': 24,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 120},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 123,
#   'LENGTH': 0.255,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1, State Route 4',
#   'RINGNUM': 1,
#   'ROADTRL020': 25,
#   'RPOLY_': 0,
#   'SHAPENUM': 25,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 120},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 123,
#   'LENGTH': 0.914,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 26,
#   'RPOLY_': 0,
#   'SHAPENUM': 26,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 119},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 122,
#   'LENGTH': 0.511,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 27,
#   'RPOLY_': 0,
#   'SHAPENUM': 27,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 124},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 122,
#   'LENGTH': 0.321,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 28,
#   'RPOLY_': 0,
#   'SHAPENUM': 28,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 127},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 130,
#   'LENGTH': 3.136,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 29,
#   'RPOLY_': 0,
#   'SHAPENUM': 29,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 99},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 130,
#   'LENGTH': 0.058,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 30,
#   'RPOLY_': 0,
#   'SHAPENUM': 30,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 132},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 134,
#   'LENGTH': 0.035,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 31,
#   'RPOLY_': 0,
#   'SHAPENUM': 31,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 131},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 130,
#   'LENGTH': 0.23,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 32,
#   'RPOLY_': 0,
#   'SHAPENUM': 32,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 137},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 137,
#   'LENGTH': 0.028,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 33,
#   'RPOLY_': 0,
#   'SHAPENUM': 33,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 139},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 145,
#   'LENGTH': 0.709,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 34,
#   'RPOLY_': 0,
#   'SHAPENUM': 34,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 127},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 147,
#   'LENGTH': 0.691,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 35,
#   'RPOLY_': 0,
#   'SHAPENUM': 35,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 148},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 155,
#   'LENGTH': 1.381,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 36,
#   'RPOLY_': 0,
#   'SHAPENUM': 36,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 148},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 137,
#   'LENGTH': 1.657,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 37,
#   'RPOLY_': 0,
#   'SHAPENUM': 37,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 156},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 158,
#   'LENGTH': 0.186,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 38,
#   'RPOLY_': 0,
#   'SHAPENUM': 38,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 156},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 163,
#   'LENGTH': 0.014,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 39,
#   'RPOLY_': 0,
#   'SHAPENUM': 39,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 165},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 166,
#   'LENGTH': 0.186,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 40,
#   'RPOLY_': 0,
#   'SHAPENUM': 40,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 163},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 168,
#   'LENGTH': 0.092,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 41,
#   'RPOLY_': 0,
#   'SHAPENUM': 41,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 163},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 177,
#   'LENGTH': 0.262,
#   'LPOLY_': 0,
#   'NAME': 'State Route 97',
#   'RINGNUM': 1,
#   'ROADTRL020': 42,
#   'RPOLY_': 0,
#   'SHAPENUM': 42,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 176},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 177,
#   'LENGTH': 0.253,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 43,
#   'RPOLY_': 0,
#   'SHAPENUM': 43,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 179},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 198,
#   'LENGTH': 0.82,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 44,
#   'RPOLY_': 0,
#   'SHAPENUM': 44,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 200},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 201,
#   'LENGTH': 0.005,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 45,
#   'RPOLY_': 0,
#   'SHAPENUM': 45,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 200},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 225,
#   'LENGTH': 0.002,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 46,
#   'RPOLY_': 0,
#   'SHAPENUM': 46,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 226},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 222,
#   'LENGTH': 0.355,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 47,
#   'RPOLY_': 0,
#   'SHAPENUM': 47,
#   'STATE': 'AK',
#   'STATE_FIPS': '02',
#   'TNODE_': 226},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 230,
#   'LENGTH': 0.012,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 48,
#   'RPOLY_': 0,
#   'SHAPENUM': 48,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 229},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 232,
#   'LENGTH': 0.015,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 49,
#   'RPOLY_': 0,
#   'SHAPENUM': 49,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 231},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 230,
#   'LENGTH': 0.433,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 50,
#   'RPOLY_': 0,
#   'SHAPENUM': 50,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 232},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 234,
#   'LENGTH': 0.331,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 51,
#   'RPOLY_': 0,
#   'SHAPENUM': 51,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 230},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 235,
#   'LENGTH': 0.003,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 52,
#   'RPOLY_': 0,
#   'SHAPENUM': 52,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 234},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 233,
#   'LENGTH': 0.007,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 53,
#   'RPOLY_': 0,
#   'SHAPENUM': 53,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 235},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 236,
#   'LENGTH': 0.343,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 54,
#   'RPOLY_': 0,
#   'SHAPENUM': 54,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 232},
#  {'FEATURE': 'Principal Highway   Alternate Route',
#   'FNODE_': 238,
#   'LENGTH': 0.512,
#   'LPOLY_': 0,
#   'NAME': 'Alternate US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 55,
#   'RPOLY_': 0,
#   'SHAPENUM': 55,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 232},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 236,
#   'LENGTH': 0.168,
#   'LPOLY_': 0,
#   'NAME': 'State Route 161',
#   'RINGNUM': 1,
#   'ROADTRL020': 56,
#   'RPOLY_': 0,
#   'SHAPENUM': 56,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 238},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 238,
#   'LENGTH': 0.066,
#   'LPOLY_': 0,
#   'NAME': 'State Route 167',
#   'RINGNUM': 1,
#   'ROADTRL020': 57,
#   'RPOLY_': 0,
#   'SHAPENUM': 57,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 237},
#  {'FEATURE': 'Principal Highway   Alternate Route',
#   'FNODE_': 241,
#   'LENGTH': 0.008,
#   'LPOLY_': 0,
#   'NAME': 'Alternate US Route 1, State Route 167',
#   'RINGNUM': 1,
#   'ROADTRL020': 58,
#   'RPOLY_': 0,
#   'SHAPENUM': 58,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 238},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 239,
#   'LENGTH': 0.569,
#   'LPOLY_': 0,
#   'NAME': 'State Route 161',
#   'RINGNUM': 1,
#   'ROADTRL020': 59,
#   'RPOLY_': 0,
#   'SHAPENUM': 59,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 235},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 243,
#   'LENGTH': 0.018,
#   'LPOLY_': 0,
#   'NAME': 'State Route 543',
#   'RINGNUM': 1,
#   'ROADTRL020': 60,
#   'RPOLY_': 0,
#   'SHAPENUM': 60,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 242},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 243,
#   'LENGTH': 0.024,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 61,
#   'RPOLY_': 0,
#   'SHAPENUM': 61,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 240},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 246,
#   'LENGTH': 0.045,
#   'LPOLY_': 0,
#   'NAME': 'State Route 539',
#   'RINGNUM': 1,
#   'ROADTRL020': 62,
#   'RPOLY_': 0,
#   'SHAPENUM': 62,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 244},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 247,
#   'LENGTH': 0.189,
#   'LPOLY_': 0,
#   'NAME': 'State Route 167',
#   'RINGNUM': 1,
#   'ROADTRL020': 63,
#   'RPOLY_': 0,
#   'SHAPENUM': 63,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 241},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 247,
#   'LENGTH': 0.185,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 64,
#   'RPOLY_': 0,
#   'SHAPENUM': 64,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 236},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 245,
#   'LENGTH': 0.078,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 65,
#   'RPOLY_': 0,
#   'SHAPENUM': 65,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 248},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 246,
#   'LENGTH': 0.167,
#   'LPOLY_': 0,
#   'NAME': 'State Route 546',
#   'RINGNUM': 1,
#   'ROADTRL020': 66,
#   'RPOLY_': 0,
#   'SHAPENUM': 66,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 248},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 248,
#   'LENGTH': 0.037,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 67,
#   'RPOLY_': 0,
#   'SHAPENUM': 67,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 249},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 250,
#   'LENGTH': 0.068,
#   'LPOLY_': 0,
#   'NAME': 'State Route 539',
#   'RINGNUM': 1,
#   'ROADTRL020': 68,
#   'RPOLY_': 0,
#   'SHAPENUM': 68,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 246},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 250,
#   'LENGTH': 0.178,
#   'LPOLY_': 0,
#   'NAME': 'State Route 544',
#   'RINGNUM': 1,
#   'ROADTRL020': 69,
#   'RPOLY_': 0,
#   'SHAPENUM': 69,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 249},
#  {'FEATURE': 'Principal Highway   Alternate Route',
#   'FNODE_': 251,
#   'LENGTH': 0.27,
#   'LPOLY_': 0,
#   'NAME': 'Alternate US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 70,
#   'RPOLY_': 0,
#   'SHAPENUM': 70,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 241},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 251,
#   'LENGTH': 0.237,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 71,
#   'RPOLY_': 0,
#   'SHAPENUM': 71,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 247},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 249,
#   'LENGTH': 0.1,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 72,
#   'RPOLY_': 0,
#   'SHAPENUM': 72,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 252},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 254,
#   'LENGTH': 0.108,
#   'LPOLY_': 0,
#   'NAME': 'State Route 539',
#   'RINGNUM': 1,
#   'ROADTRL020': 73,
#   'RPOLY_': 0,
#   'SHAPENUM': 73,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 250},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 243,
#   'LENGTH': 0.337,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 74,
#   'RPOLY_': 0,
#   'SHAPENUM': 74,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 254},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 255,
#   'LENGTH': 0.702,
#   'LPOLY_': 0,
#   'NAME': 'State Route 11',
#   'RINGNUM': 1,
#   'ROADTRL020': 75,
#   'RPOLY_': 0,
#   'SHAPENUM': 75,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 234},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 256,
#   'LENGTH': 0.387,
#   'LPOLY_': 0,
#   'NAME': 'State Route 163',
#   'RINGNUM': 1,
#   'ROADTRL020': 76,
#   'RPOLY_': 0,
#   'SHAPENUM': 76,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 247},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 256,
#   'LENGTH': 0.044,
#   'LPOLY_': 0,
#   'NAME': 'State Route 11',
#   'RINGNUM': 1,
#   'ROADTRL020': 77,
#   'RPOLY_': 0,
#   'SHAPENUM': 77,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 255},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 257,
#   'LENGTH': 0.191,
#   'LPOLY_': 0,
#   'NAME': 'State Route 542',
#   'RINGNUM': 1,
#   'ROADTRL020': 78,
#   'RPOLY_': 0,
#   'SHAPENUM': 78,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 252},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 257,
#   'LENGTH': 0.027,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 79,
#   'RPOLY_': 0,
#   'SHAPENUM': 79,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 254},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 257,
#   'LENGTH': 0.043,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 80,
#   'RPOLY_': 0,
#   'SHAPENUM': 80,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 254},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 258,
#   'LENGTH': 0.097,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9, State Route 542',
#   'RINGNUM': 1,
#   'ROADTRL020': 81,
#   'RPOLY_': 0,
#   'SHAPENUM': 81,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 252},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 259,
#   'LENGTH': 0.092,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 82,
#   'RPOLY_': 0,
#   'SHAPENUM': 82,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 255},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 260,
#   'LENGTH': 0.07,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 83,
#   'RPOLY_': 0,
#   'SHAPENUM': 83,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 257},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 258,
#   'LENGTH': 0.724,
#   'LPOLY_': 0,
#   'NAME': 'State Route 542',
#   'RINGNUM': 1,
#   'ROADTRL020': 84,
#   'RPOLY_': 0,
#   'SHAPENUM': 84,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 261},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 262,
#   'LENGTH': 0.306,
#   'LPOLY_': 0,
#   'NAME': 'State Route 112',
#   'RINGNUM': 1,
#   'ROADTRL020': 85,
#   'RPOLY_': 0,
#   'SHAPENUM': 85,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 253},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 262,
#   'LENGTH': 0.448,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 86,
#   'RPOLY_': 0,
#   'SHAPENUM': 86,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 263},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 265,
#   'LENGTH': 0.172,
#   'LPOLY_': 0,
#   'NAME': 'State Route 112',
#   'RINGNUM': 1,
#   'ROADTRL020': 87,
#   'RPOLY_': 0,
#   'SHAPENUM': 87,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 262},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 268,
#   'LENGTH': 0.003,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 88,
#   'RPOLY_': 0,
#   'SHAPENUM': 88,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 267},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 269,
#   'LENGTH': 0.048,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 95',
#   'RINGNUM': 1,
#   'ROADTRL020': 89,
#   'RPOLY_': 0,
#   'SHAPENUM': 89,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 268},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 269,
#   'LENGTH': 0.383,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 90,
#   'RPOLY_': 0,
#   'SHAPENUM': 90,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 251},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 271,
#   'LENGTH': 0.338,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 91,
#   'RPOLY_': 0,
#   'SHAPENUM': 91,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 258},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 272,
#   'LENGTH': 0.015,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9, State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 92,
#   'RPOLY_': 0,
#   'SHAPENUM': 92,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 271},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 273,
#   'LENGTH': 0.299,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 93,
#   'RPOLY_': 0,
#   'SHAPENUM': 93,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 260},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 260,
#   'LENGTH': 0.289,
#   'LPOLY_': 0,
#   'NAME': 'State Route 11',
#   'RINGNUM': 1,
#   'ROADTRL020': 94,
#   'RPOLY_': 0,
#   'SHAPENUM': 94,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 273},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 274,
#   'LENGTH': 0.048,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 95,
#   'RPOLY_': 0,
#   'SHAPENUM': 95,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 268},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 274,
#   'LENGTH': 0.013,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 96,
#   'RPOLY_': 0,
#   'SHAPENUM': 96,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 269},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 276,
#   'LENGTH': 0.008,
#   'LPOLY_': 0,
#   'NAME': 'US Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 97,
#   'RPOLY_': 0,
#   'SHAPENUM': 97,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 274},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 277,
#   'LENGTH': 0.112,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 98,
#   'RPOLY_': 0,
#   'SHAPENUM': 98,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 272},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 277,
#   'LENGTH': 0.022,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 99,
#   'RPOLY_': 0,
#   'SHAPENUM': 99,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 273},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 279,
#   'LENGTH': 0.086,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 100,
#   'RPOLY_': 0,
#   'SHAPENUM': 100,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 277},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 266,
#   'LENGTH': 0.162,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 101,
#   'RPOLY_': 0,
#   'SHAPENUM': 101,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 279},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 265,
#   'LENGTH': 0.158,
#   'LPOLY_': 0,
#   'NAME': 'State Route 113',
#   'RINGNUM': 1,
#   'ROADTRL020': 102,
#   'RPOLY_': 0,
#   'SHAPENUM': 102,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 280},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 281,
#   'LENGTH': 0.215,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 95',
#   'RINGNUM': 1,
#   'ROADTRL020': 103,
#   'RPOLY_': 0,
#   'SHAPENUM': 103,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 269},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 281,
#   'LENGTH': 0.218,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 104,
#   'RPOLY_': 0,
#   'SHAPENUM': 104,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 274},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 282,
#   'LENGTH': 0.032,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 105,
#   'RPOLY_': 0,
#   'SHAPENUM': 105,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 277},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 256,
#   'LENGTH': 0.474,
#   'LPOLY_': 0,
#   'NAME': 'State Route 11',
#   'RINGNUM': 1,
#   'ROADTRL020': 106,
#   'RPOLY_': 0,
#   'SHAPENUM': 106,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 283},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 284,
#   'LENGTH': 0.022,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 107,
#   'RPOLY_': 0,
#   'SHAPENUM': 107,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 282},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 279,
#   'LENGTH': 0.099,
#   'LPOLY_': 0,
#   'NAME': 'State Route 536',
#   'RINGNUM': 1,
#   'ROADTRL020': 108,
#   'RPOLY_': 0,
#   'SHAPENUM': 108,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 284},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 285,
#   'LENGTH': 0.105,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 109,
#   'RPOLY_': 0,
#   'SHAPENUM': 109,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 272},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 285,
#   'LENGTH': 0.076,
#   'LPOLY_': 0,
#   'NAME': 'State Route 538',
#   'RINGNUM': 1,
#   'ROADTRL020': 110,
#   'RPOLY_': 0,
#   'SHAPENUM': 110,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 282},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 286,
#   'LENGTH': 0.135,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 111,
#   'RPOLY_': 0,
#   'SHAPENUM': 111,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 281},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 286,
#   'LENGTH': 0.173,
#   'LPOLY_': 0,
#   'NAME': 'State Route 212',
#   'RINGNUM': 1,
#   'ROADTRL020': 112,
#   'RPOLY_': 0,
#   'SHAPENUM': 112,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 283},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 280,
#   'LENGTH': 0.189,
#   'LPOLY_': 0,
#   'NAME': 'US Route 101',
#   'RINGNUM': 1,
#   'ROADTRL020': 113,
#   'RPOLY_': 0,
#   'SHAPENUM': 113,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 287},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 281,
#   'LENGTH': 0.141,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 95',
#   'RINGNUM': 1,
#   'ROADTRL020': 114,
#   'RPOLY_': 0,
#   'SHAPENUM': 114,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 289},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 289,
#   'LENGTH': 0.028,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 115,
#   'RPOLY_': 0,
#   'SHAPENUM': 115,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 286},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 290,
#   'LENGTH': 0.695,
#   'LPOLY_': 0,
#   'NAME': 'State Route 112',
#   'RINGNUM': 1,
#   'ROADTRL020': 116,
#   'RPOLY_': 0,
#   'SHAPENUM': 116,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 265},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 287,
#   'LENGTH': 0.263,
#   'LPOLY_': 0,
#   'NAME': 'State Route 110',
#   'RINGNUM': 1,
#   'ROADTRL020': 117,
#   'RPOLY_': 0,
#   'SHAPENUM': 117,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 288},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 271,
#   'LENGTH': 0.655,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 118,
#   'RPOLY_': 0,
#   'SHAPENUM': 118,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 291},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 292,
#   'LENGTH': 0.074,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 119,
#   'RPOLY_': 0,
#   'SHAPENUM': 119,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 284},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 295,
#   'LENGTH': 0.041,
#   'LPOLY_': 0,
#   'NAME': 'State Route 117',
#   'RINGNUM': 1,
#   'ROADTRL020': 120,
#   'RPOLY_': 0,
#   'SHAPENUM': 120,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 294},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 295,
#   'LENGTH': 0.1,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 121,
#   'RPOLY_': 0,
#   'SHAPENUM': 121,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 290},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 290,
#   'LENGTH': 0.027,
#   'LPOLY_': 0,
#   'NAME': 'State Route 112',
#   'RINGNUM': 1,
#   'ROADTRL020': 122,
#   'RPOLY_': 0,
#   'SHAPENUM': 122,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 296},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 297,
#   'LENGTH': 0.047,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 123,
#   'RPOLY_': 0,
#   'SHAPENUM': 123,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 295},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 297,
#   'LENGTH': 0.133,
#   'LPOLY_': 0,
#   'NAME': 'US Route 101',
#   'RINGNUM': 1,
#   'ROADTRL020': 124,
#   'RPOLY_': 0,
#   'SHAPENUM': 124,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 296},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 296,
#   'LENGTH': 0.768,
#   'LPOLY_': 0,
#   'NAME': 'US Route 101',
#   'RINGNUM': 1,
#   'ROADTRL020': 125,
#   'RPOLY_': 0,
#   'SHAPENUM': 125,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 280},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 298,
#   'LENGTH': 0.153,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 126,
#   'RPOLY_': 0,
#   'SHAPENUM': 126,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 285},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 298,
#   'LENGTH': 0.101,
#   'LPOLY_': 0,
#   'NAME': 'State Route 534',
#   'RINGNUM': 1,
#   'ROADTRL020': 127,
#   'RPOLY_': 0,
#   'SHAPENUM': 127,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 292},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 278,
#   'LENGTH': 0.43,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 128,
#   'RPOLY_': 0,
#   'SHAPENUM': 128,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 303},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 303,
#   'LENGTH': 0.069,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 129,
#   'RPOLY_': 0,
#   'SHAPENUM': 129,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 304},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 305,
#   'LENGTH': 0.137,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 130,
#   'RPOLY_': 0,
#   'SHAPENUM': 130,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 292},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 305,
#   'LENGTH': 0.216,
#   'LPOLY_': 0,
#   'NAME': 'State Route 532',
#   'RINGNUM': 1,
#   'ROADTRL020': 131,
#   'RPOLY_': 0,
#   'SHAPENUM': 131,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 300},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 304,
#   'LENGTH': 0.004,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 132,
#   'RPOLY_': 0,
#   'SHAPENUM': 132,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 306},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 301,
#   'LENGTH': 0.274,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 133,
#   'RPOLY_': 0,
#   'SHAPENUM': 133,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 307},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 306,
#   'LENGTH': 0.031,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 134,
#   'RPOLY_': 0,
#   'SHAPENUM': 134,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 308},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 308,
#   'LENGTH': 0.55,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 135,
#   'RPOLY_': 0,
#   'SHAPENUM': 135,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 275},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 308,
#   'LENGTH': 0.064,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 136,
#   'RPOLY_': 0,
#   'SHAPENUM': 136,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 309},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 310,
#   'LENGTH': 0.258,
#   'LPOLY_': 0,
#   'NAME': 'State Route 11',
#   'RINGNUM': 1,
#   'ROADTRL020': 137,
#   'RPOLY_': 0,
#   'SHAPENUM': 137,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 283},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 311,
#   'LENGTH': 0.335,
#   'LPOLY_': 0,
#   'NAME': 'US Route 97',
#   'RINGNUM': 1,
#   'ROADTRL020': 138,
#   'RPOLY_': 0,
#   'SHAPENUM': 138,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 270},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 310,
#   'LENGTH': 0.15,
#   'LPOLY_': 0,
#   'NAME': 'State Route 159',
#   'RINGNUM': 1,
#   'ROADTRL020': 139,
#   'RPOLY_': 0,
#   'SHAPENUM': 139,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 301},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 312,
#   'LENGTH': 0.067,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 140,
#   'RPOLY_': 0,
#   'SHAPENUM': 140,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 305},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 313,
#   'LENGTH': 0.17,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 141,
#   'RPOLY_': 0,
#   'SHAPENUM': 141,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 298},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 313,
#   'LENGTH': 0.008,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9, State Route 530',
#   'RINGNUM': 1,
#   'ROADTRL020': 142,
#   'RPOLY_': 0,
#   'SHAPENUM': 142,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 314},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 312,
#   'LENGTH': 0.069,
#   'LPOLY_': 0,
#   'NAME': 'State Route 530',
#   'RINGNUM': 1,
#   'ROADTRL020': 143,
#   'RPOLY_': 0,
#   'SHAPENUM': 143,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 313},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 291,
#   'LENGTH': 0.847,
#   'LPOLY_': 0,
#   'NAME': 'State Route 530',
#   'RINGNUM': 1,
#   'ROADTRL020': 144,
#   'RPOLY_': 0,
#   'SHAPENUM': 144,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 314},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 309,
#   'LENGTH': 0.227,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 145,
#   'RPOLY_': 0,
#   'SHAPENUM': 145,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 316},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 297,
#   'LENGTH': 0.66,
#   'LPOLY_': 0,
#   'NAME': 'US Route 101',
#   'RINGNUM': 1,
#   'ROADTRL020': 146,
#   'RPOLY_': 0,
#   'SHAPENUM': 146,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 316},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 317,
#   'LENGTH': 0.301,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 147,
#   'RPOLY_': 0,
#   'SHAPENUM': 147,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 289},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 317,
#   'LENGTH': 0.076,
#   'LPOLY_': 0,
#   'NAME': 'State Route 158',
#   'RINGNUM': 1,
#   'ROADTRL020': 148,
#   'RPOLY_': 0,
#   'SHAPENUM': 148,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 318},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 318,
#   'LENGTH': 0.334,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 95',
#   'RINGNUM': 1,
#   'ROADTRL020': 149,
#   'RPOLY_': 0,
#   'SHAPENUM': 149,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 289},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 318,
#   'LENGTH': 0.16,
#   'LPOLY_': 0,
#   'NAME': 'State Route 11',
#   'RINGNUM': 1,
#   'ROADTRL020': 150,
#   'RPOLY_': 0,
#   'SHAPENUM': 150,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 310},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 316,
#   'LENGTH': 0.04,
#   'LPOLY_': 0,
#   'NAME': 'US Route 101',
#   'RINGNUM': 1,
#   'ROADTRL020': 151,
#   'RPOLY_': 0,
#   'SHAPENUM': 151,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 319},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 322,
#   'LENGTH': 0.784,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 152,
#   'RPOLY_': 0,
#   'SHAPENUM': 152,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 311},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 324,
#   'LENGTH': 0.436,
#   'LPOLY_': 0,
#   'NAME': 'State Route 21',
#   'RINGNUM': 1,
#   'ROADTRL020': 153,
#   'RPOLY_': 0,
#   'SHAPENUM': 153,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 293},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 324,
#   'LENGTH': 0.05,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20, State Route 21',
#   'RINGNUM': 1,
#   'ROADTRL020': 154,
#   'RPOLY_': 0,
#   'SHAPENUM': 154,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 322},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 327,
#   'LENGTH': 0.181,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 155,
#   'RPOLY_': 0,
#   'SHAPENUM': 155,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 314},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 323,
#   'LENGTH': 0.111,
#   'LPOLY_': 0,
#   'NAME': 'State Route 92',
#   'RINGNUM': 1,
#   'ROADTRL020': 156,
#   'RPOLY_': 0,
#   'SHAPENUM': 156,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 327},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 303,
#   'LENGTH': 0.393,
#   'LPOLY_': 0,
#   'NAME': 'State Route 525',
#   'RINGNUM': 1,
#   'ROADTRL020': 157,
#   'RPOLY_': 0,
#   'SHAPENUM': 157,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 328},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 329,
#   'LENGTH': 0.021,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 158,
#   'RPOLY_': 0,
#   'SHAPENUM': 158,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 327},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 291,
#   'LENGTH': 1.849,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 159,
#   'RPOLY_': 0,
#   'SHAPENUM': 159,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 330},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 333,
#   'LENGTH': 0.049,
#   'LPOLY_': 0,
#   'NAME': 'State Route 525',
#   'RINGNUM': 1,
#   'ROADTRL020': 160,
#   'RPOLY_': 0,
#   'SHAPENUM': 160,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 328},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 334,
#   'LENGTH': 0.045,
#   'LPOLY_': 0,
#   'NAME': 'State Route 204',
#   'RINGNUM': 1,
#   'ROADTRL020': 161,
#   'RPOLY_': 0,
#   'SHAPENUM': 161,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 329},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 331,
#   'LENGTH': 0.056,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 162,
#   'RPOLY_': 0,
#   'SHAPENUM': 162,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 334},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 332,
#   'LENGTH': 0.471,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 163,
#   'RPOLY_': 0,
#   'SHAPENUM': 163,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 323},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 335,
#   'LENGTH': 0.047,
#   'LPOLY_': 0,
#   'NAME': 'State Route 153',
#   'RINGNUM': 1,
#   'ROADTRL020': 164,
#   'RPOLY_': 0,
#   'SHAPENUM': 164,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 330},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 336,
#   'LENGTH': 0.023,
#   'LPOLY_': 0,
#   'NAME': 'State Route 525',
#   'RINGNUM': 1,
#   'ROADTRL020': 165,
#   'RPOLY_': 0,
#   'SHAPENUM': 165,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 333},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 337,
#   'LENGTH': 0.28,
#   'LPOLY_': 0,
#   'NAME': 'US Route 95',
#   'RINGNUM': 1,
#   'ROADTRL020': 166,
#   'RPOLY_': 0,
#   'SHAPENUM': 166,
#   'STATE': 'ID',
#   'STATE_FIPS': '16',
#   'TNODE_': 325},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 321,
#   'LENGTH': 0.184,
#   'LPOLY_': 0,
#   'NAME': 'State Route 1',
#   'RINGNUM': 1,
#   'ROADTRL020': 167,
#   'RPOLY_': 0,
#   'SHAPENUM': 167,
#   'STATE': 'ID',
#   'STATE_FIPS': '16',
#   'TNODE_': 337},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 338,
#   'LENGTH': 0.352,
#   'LPOLY_': 0,
#   'NAME': 'US Route 97, State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 168,
#   'RPOLY_': 0,
#   'SHAPENUM': 168,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 311},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 339,
#   'LENGTH': 0.034,
#   'LPOLY_': 0,
#   'NAME': 'State Route 155',
#   'RINGNUM': 1,
#   'ROADTRL020': 169,
#   'RPOLY_': 0,
#   'SHAPENUM': 169,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 338},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 341,
#   'LENGTH': 0.432,
#   'LPOLY_': 0,
#   'NAME': 'US Route 395',
#   'RINGNUM': 1,
#   'ROADTRL020': 170,
#   'RPOLY_': 0,
#   'SHAPENUM': 170,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 299},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 342,
#   'LENGTH': 0.019,
#   'LPOLY_': 0,
#   'NAME': 'US Route 97, State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 171,
#   'RPOLY_': 0,
#   'SHAPENUM': 171,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 338},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 331,
#   'LENGTH': 0.058,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 172,
#   'RPOLY_': 0,
#   'SHAPENUM': 172,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 343},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 336,
#   'LENGTH': 0.09,
#   'LPOLY_': 0,
#   'NAME': 'State Route 526',
#   'RINGNUM': 1,
#   'ROADTRL020': 173,
#   'RPOLY_': 0,
#   'SHAPENUM': 173,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 343},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 344,
#   'LENGTH': 0.075,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 174,
#   'RPOLY_': 0,
#   'SHAPENUM': 174,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 329},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 334,
#   'LENGTH': 0.058,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 175,
#   'RPOLY_': 0,
#   'SHAPENUM': 175,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 344},
#  {'FEATURE': 'Principal Highway   Alternate Route',
#   'FNODE_': 345,
#   'LENGTH': 0.708,
#   'LPOLY_': 0,
#   'NAME': 'Alternate US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 176,
#   'RPOLY_': 0,
#   'SHAPENUM': 176,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 276},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 345,
#   'LENGTH': 0.257,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 177,
#   'RPOLY_': 0,
#   'SHAPENUM': 177,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 317},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 346,
#   'LENGTH': 0.706,
#   'LPOLY_': 0,
#   'NAME': 'State Route 25',
#   'RINGNUM': 1,
#   'ROADTRL020': 178,
#   'RPOLY_': 0,
#   'SHAPENUM': 178,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 302},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 346,
#   'LENGTH': 0.05,
#   'LPOLY_': 0,
#   'NAME': 'US Route 395, State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 179,
#   'RPOLY_': 0,
#   'SHAPENUM': 179,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 341},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 324,
#   'LENGTH': 0.667,
#   'LPOLY_': 0,
#   'NAME': 'State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 180,
#   'RPOLY_': 0,
#   'SHAPENUM': 180,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 341},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 344,
#   'LENGTH': 0.018,
#   'LPOLY_': 0,
#   'NAME': 'State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 181,
#   'RPOLY_': 0,
#   'SHAPENUM': 181,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 347},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 348,
#   'LENGTH': 0.073,
#   'LPOLY_': 0,
#   'NAME': 'State Route 215',
#   'RINGNUM': 1,
#   'ROADTRL020': 182,
#   'RPOLY_': 0,
#   'SHAPENUM': 182,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 339},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 343,
#   'LENGTH': 0.083,
#   'LPOLY_': 0,
#   'NAME': 'State Route 99',
#   'RINGNUM': 1,
#   'ROADTRL020': 183,
#   'RPOLY_': 0,
#   'SHAPENUM': 183,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 349},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 349,
#   'LENGTH': 0.055,
#   'LPOLY_': 0,
#   'NAME': 'State Route 525',
#   'RINGNUM': 1,
#   'ROADTRL020': 184,
#   'RPOLY_': 0,
#   'SHAPENUM': 184,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 336},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 350,
#   'LENGTH': 0.092,
#   'LPOLY_': 0,
#   'NAME': 'US Route 97, State Route 20',
#   'RINGNUM': 1,
#   'ROADTRL020': 185,
#   'RPOLY_': 0,
#   'SHAPENUM': 185,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 342},
# ...
#   'SHAPENUM': 937,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 923},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 924,
#   'LENGTH': 0.543,
#   'LPOLY_': 0,
#   'NAME': 'State Route 17',
#   'RINGNUM': 1,
#   'ROADTRL020': 938,
#   'RPOLY_': 0,
#   'SHAPENUM': 938,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 788},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 925,
#   'LENGTH': 0.149,
#   'LPOLY_': 0,
#   'NAME': 'State Route 26',
#   'RINGNUM': 1,
#   'ROADTRL020': 939,
#   'RPOLY_': 0,
#   'SHAPENUM': 939,
#   'STATE': 'NH',
#   'STATE_FIPS': '33',
#   'TNODE_': 898},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 926,
#   'LENGTH': 0.023,
#   'LPOLY_': 0,
#   'NAME': 'State Route 24',
#   'RINGNUM': 1,
#   'ROADTRL020': 940,
#   'RPOLY_': 0,
#   'SHAPENUM': 940,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 914},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 908,
#   'LENGTH': 0.057,
#   'LPOLY_': 0,
#   'NAME': 'State Route 42',
#   'RINGNUM': 1,
#   'ROADTRL020': 941,
#   'RPOLY_': 0,
#   'SHAPENUM': 941,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 926},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 878,
#   'LENGTH': 0.365,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 942,
#   'RPOLY_': 0,
#   'SHAPENUM': 942,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 924},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 921,
#   'LENGTH': 0.413,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 943,
#   'RPOLY_': 0,
#   'SHAPENUM': 943,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 927},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 927,
#   'LENGTH': 0.662,
#   'LPOLY_': 0,
#   'NAME': 'State Route 14',
#   'RINGNUM': 1,
#   'ROADTRL020': 944,
#   'RPOLY_': 0,
#   'SHAPENUM': 944,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 721},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 877,
#   'LENGTH': 0.125,
#   'LPOLY_': 0,
#   'NAME': 'State Route 28',
#   'RINGNUM': 1,
#   'ROADTRL020': 945,
#   'RPOLY_': 0,
#   'SHAPENUM': 945,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 928},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 929,
#   'LENGTH': 0.217,
#   'LPOLY_': 0,
#   'NAME': 'US Route 202, State Route 3, State Route 9',
#   'RINGNUM': 1,
#   'ROADTRL020': 946,
#   'RPOLY_': 0,
#   'SHAPENUM': 946,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 876},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 929,
#   'LENGTH': 0.269,
#   'LPOLY_': 0,
#   'NAME': 'US Route 201, State Route 100',
#   'RINGNUM': 1,
#   'ROADTRL020': 947,
#   'RPOLY_': 0,
#   'SHAPENUM': 947,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 834},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 930,
#   'LENGTH': 0.656,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 948,
#   'RPOLY_': 0,
#   'SHAPENUM': 948,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 928},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 930,
#   'LENGTH': 0.267,
#   'LPOLY_': 0,
#   'NAME': 'State Route 8',
#   'RINGNUM': 1,
#   'ROADTRL020': 949,
#   'RPOLY_': 0,
#   'SHAPENUM': 949,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 837},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 910,
#   'LENGTH': 0.566,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 950,
#   'RPOLY_': 0,
#   'SHAPENUM': 950,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 930},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 931,
#   'LENGTH': 0.177,
#   'LPOLY_': 0,
#   'NAME': 'US Route 26',
#   'RINGNUM': 1,
#   'ROADTRL020': 951,
#   'RPOLY_': 0,
#   'SHAPENUM': 951,
#   'STATE': 'OR',
#   'STATE_FIPS': '41',
#   'TNODE_': 904},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 916,
#   'LENGTH': 0.045,
#   'LPOLY_': 0,
#   'NAME': 'US Route 5',
#   'RINGNUM': 1,
#   'ROADTRL020': 952,
#   'RPOLY_': 0,
#   'SHAPENUM': 952,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 932},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 913,
#   'LENGTH': 0.047,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 82, US Route 12, US Route 97',
#   'RINGNUM': 1,
#   'ROADTRL020': 953,
#   'RPOLY_': 0,
#   'SHAPENUM': 953,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 933},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 934,
#   'LENGTH': 0.246,
#   'LPOLY_': 0,
#   'NAME': 'US Route 52',
#   'RINGNUM': 1,
#   'ROADTRL020': 954,
#   'RPOLY_': 0,
#   'SHAPENUM': 954,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 877},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 928,
#   'LENGTH': 0.21,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 955,
#   'RPOLY_': 0,
#   'SHAPENUM': 955,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 934},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 935,
#   'LENGTH': 0.024,
#   'LPOLY_': 0,
#   'NAME': 'US Route 5, State Route 105',
#   'RINGNUM': 1,
#   'ROADTRL020': 956,
#   'RPOLY_': 0,
#   'SHAPENUM': 956,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 932},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 935,
#   'LENGTH': 0.063,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 91',
#   'RINGNUM': 1,
#   'ROADTRL020': 957,
#   'RPOLY_': 0,
#   'SHAPENUM': 957,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 916},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 660,
#   'LENGTH': 1.248,
#   'LPOLY_': 0,
#   'NAME': 'US Route 87',
#   'RINGNUM': 1,
#   'ROADTRL020': 958,
#   'RPOLY_': 0,
#   'SHAPENUM': 958,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 937},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 627,
#   'LENGTH': 0.842,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 959,
#   'RPOLY_': 0,
#   'SHAPENUM': 959,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 937},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 936,
#   'LENGTH': 0.045,
#   'LPOLY_': 0,
#   'NAME': 'US Route 201, US Route 202, State Route 100',
#   'RINGNUM': 1,
#   'ROADTRL020': 960,
#   'RPOLY_': 0,
#   'SHAPENUM': 960,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 929},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 938,
#   'LENGTH': 0.031,
#   'LPOLY_': 0,
#   'NAME': 'US Route 202, State Route 11, State Route 100',
#   'RINGNUM': 1,
#   'ROADTRL020': 961,
#   'RPOLY_': 0,
#   'SHAPENUM': 961,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 936},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 938,
#   'LENGTH': 0.361,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 95',
#   'RINGNUM': 1,
#   'ROADTRL020': 962,
#   'RPOLY_': 0,
#   'SHAPENUM': 962,
#   'STATE': 'ME',
#   'STATE_FIPS': '23',
#   'TNODE_': 807},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 927,
#   'LENGTH': 0.079,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2, State Route 14',
#   'RINGNUM': 1,
#   'ROADTRL020': 963,
#   'RPOLY_': 0,
#   'SHAPENUM': 963,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 940},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 914,
#   'LENGTH': 0.246,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 964,
#   'RPOLY_': 0,
#   'SHAPENUM': 964,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 941},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 942,
#   'LENGTH': 0.459,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 965,
#   'RPOLY_': 0,
#   'SHAPENUM': 965,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 921},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 912,
#   'LENGTH': 0.672,
#   'LPOLY_': 0,
#   'NAME': 'State Route 24',
#   'RINGNUM': 1,
#   'ROADTRL020': 966,
#   'RPOLY_': 0,
#   'SHAPENUM': 966,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 943},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 943,
#   'LENGTH': 0.458,
#   'LPOLY_': 0,
#   'NAME': 'State Route 243',
#   'RINGNUM': 1,
#   'ROADTRL020': 967,
#   'RPOLY_': 0,
#   'SHAPENUM': 967,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 819},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 944,
#   'LENGTH': 0.222,
#   'LPOLY_': 0,
#   'NAME': 'State Route 3',
#   'RINGNUM': 1,
#   'ROADTRL020': 968,
#   'RPOLY_': 0,
#   'SHAPENUM': 968,
#   'STATE': 'ID',
#   'STATE_FIPS': '16',
#   'TNODE_': 869},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 945,
#   'LENGTH': 0.05,
#   'LPOLY_': 0,
#   'NAME': 'US Route 5, State Route 105',
#   'RINGNUM': 1,
#   'ROADTRL020': 969,
#   'RPOLY_': 0,
#   'SHAPENUM': 969,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 935},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 946,
#   'LENGTH': 0.023,
#   'LPOLY_': 0,
#   'NAME': 'US Route 87',
#   'RINGNUM': 1,
#   'ROADTRL020': 970,
#   'RPOLY_': 0,
#   'SHAPENUM': 970,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 937},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 947,
#   'LENGTH': 0.036,
#   'LPOLY_': 0,
#   'NAME': 'State Route 80',
#   'RINGNUM': 1,
#   'ROADTRL020': 971,
#   'RPOLY_': 0,
#   'SHAPENUM': 971,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 937},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 946,
#   'LENGTH': 0.029,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 972,
#   'RPOLY_': 0,
#   'SHAPENUM': 972,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 947},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 948,
#   'LENGTH': 0.037,
#   'LPOLY_': 0,
#   'NAME': 'State Route 243',
#   'RINGNUM': 1,
#   'ROADTRL020': 973,
#   'RPOLY_': 0,
#   'SHAPENUM': 973,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 939},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 757,
#   'LENGTH': 0.48,
#   'LPOLY_': 0,
#   'NAME': 'US Route 83',
#   'RINGNUM': 1,
#   'ROADTRL020': 974,
#   'RPOLY_': 0,
#   'SHAPENUM': 974,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 949},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 950,
#   'LENGTH': 0.034,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 91',
#   'RINGNUM': 1,
#   'ROADTRL020': 975,
#   'RPOLY_': 0,
#   'SHAPENUM': 975,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 935},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 950,
#   'LENGTH': 0.033,
#   'LPOLY_': 0,
#   'NAME': 'State Route 191',
#   'RINGNUM': 1,
#   'ROADTRL020': 976,
#   'RPOLY_': 0,
#   'SHAPENUM': 976,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 945},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 951,
#   'LENGTH': 0.021,
#   'LPOLY_': 0,
#   'NAME': 'US Route 5, State Route 105',
#   'RINGNUM': 1,
#   'ROADTRL020': 977,
#   'RPOLY_': 0,
#   'SHAPENUM': 977,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 945},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 952,
#   'LENGTH': 0.22,
#   'LPOLY_': 0,
#   'NAME': 'US Route 195',
#   'RINGNUM': 1,
#   'ROADTRL020': 978,
#   'RPOLY_': 0,
#   'SHAPENUM': 978,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 868},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 952,
#   'LENGTH': 0.791,
#   'LPOLY_': 0,
#   'NAME': 'State Route 23',
#   'RINGNUM': 1,
#   'ROADTRL020': 979,
#   'RPOLY_': 0,
#   'SHAPENUM': 979,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 795},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 953,
#   'LENGTH': 0.211,
#   'LPOLY_': 0,
#   'NAME': 'State Route 114',
#   'RINGNUM': 1,
#   'ROADTRL020': 980,
#   'RPOLY_': 0,
#   'SHAPENUM': 980,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 872},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 932,
#   'LENGTH': 0.263,
#   'LPOLY_': 0,
#   'NAME': 'State Route 111',
#   'RINGNUM': 1,
#   'ROADTRL020': 981,
#   'RPOLY_': 0,
#   'SHAPENUM': 981,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 953},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 954,
#   'LENGTH': 0.252,
#   'LPOLY_': 0,
#   'NAME': 'US Route 395',
#   'RINGNUM': 1,
#   'ROADTRL020': 982,
#   'RPOLY_': 0,
#   'SHAPENUM': 982,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 890},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 918,
#   'LENGTH': 0.384,
#   'LPOLY_': 0,
#   'NAME': 'State Route 26',
#   'RINGNUM': 1,
#   'ROADTRL020': 983,
#   'RPOLY_': 0,
#   'SHAPENUM': 983,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 954},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 932,
#   'LENGTH': 0.116,
#   'LPOLY_': 0,
#   'NAME': 'State Route 5A, State Route 105',
#   'RINGNUM': 1,
#   'ROADTRL020': 984,
#   'RPOLY_': 0,
#   'SHAPENUM': 984,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 955},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 933,
#   'LENGTH': 0.061,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 82, US Route 12',
#   'RINGNUM': 1,
#   'ROADTRL020': 985,
#   'RPOLY_': 0,
#   'SHAPENUM': 985,
#   'STATE': 'WA',
#   'STATE_FIPS': '53',
#   'TNODE_': 956},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 907,
#   'LENGTH': 0.136,
#   'LPOLY_': 0,
#   'NAME': 'State Route 200',
#   'RINGNUM': 1,
#   'ROADTRL020': 986,
#   'RPOLY_': 0,
#   'SHAPENUM': 986,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 957},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 867,
#   'LENGTH': 0.226,
#   'LPOLY_': 0,
#   'NAME': 'US Route 281',
#   'RINGNUM': 1,
#   'ROADTRL020': 987,
#   'RPOLY_': 0,
#   'SHAPENUM': 987,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 958},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 942,
#   'LENGTH': 0.329,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2',
#   'RINGNUM': 1,
#   'ROADTRL020': 988,
#   'RPOLY_': 0,
#   'SHAPENUM': 988,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 958},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 829,
#   'LENGTH': 0.617,
#   'LPOLY_': 0,
#   'NAME': 'US Route 53',
#   'RINGNUM': 1,
#   'ROADTRL020': 989,
#   'RPOLY_': 0,
#   'SHAPENUM': 989,
#   'STATE': 'MN',
#   'STATE_FIPS': '27',
#   'TNODE_': 959},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 958,
#   'LENGTH': 0.025,
#   'LPOLY_': 0,
#   'NAME': 'US Route 2, US Route 281',
#   'RINGNUM': 1,
#   'ROADTRL020': 990,
#   'RPOLY_': 0,
#   'SHAPENUM': 990,
#   'STATE': 'ND',
#   'STATE_FIPS': '38',
#   'TNODE_': 961},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 960,
#   'LENGTH': 0.067,
#   'LPOLY_': 0,
#   'NAME': 'State Route 105',
#   'RINGNUM': 1,
#   'ROADTRL020': 991,
#   'RPOLY_': 0,
#   'SHAPENUM': 991,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 951},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 948,
#   'LENGTH': 0.105,
#   'LPOLY_': 0,
#   'NAME': 'State Route 105',
#   'RINGNUM': 1,
#   'ROADTRL020': 992,
#   'RPOLY_': 0,
#   'SHAPENUM': 992,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 960},
#  {'FEATURE': 'Other Highway',
#   'FNODE_': 959,
#   'LENGTH': 0.377,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 993,
#   'RPOLY_': 0,
#   'SHAPENUM': 993,
#   'STATE': 'MN',
#   'STATE_FIPS': '27',
#   'TNODE_': 899},
#  {'FEATURE': 'Limited Access Highway',
#   'FNODE_': 863,
#   'LENGTH': 0.628,
#   'LPOLY_': 0,
#   'NAME': 'Interstate Route 90',
#   'RINGNUM': 1,
#   'ROADTRL020': 994,
#   'RPOLY_': 0,
#   'SHAPENUM': 994,
#   'STATE': 'MT',
#   'STATE_FIPS': '30',
#   'TNODE_': 963},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 962,
#   'LENGTH': 0.013,
#   'LPOLY_': 0,
#   'NAME': 'State Route 105',
#   'RINGNUM': 1,
#   'ROADTRL020': 995,
#   'RPOLY_': 0,
#   'SHAPENUM': 995,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 964},
#  {'FEATURE': 'Other Through Highway',
#   'FNODE_': 886,
#   'LENGTH': 0.198,
#   'LPOLY_': 0,
#   'NAME': 'State Route 102',
#   'RINGNUM': 1,
#   'ROADTRL020': 996,
#   'RPOLY_': 0,
#   'SHAPENUM': 996,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 964},
#  {'FEATURE': 'Ferry Crossing',
#   'FNODE_': 917,
#   'LENGTH': 1.032,
#   'LPOLY_': 0,
#   'NAME': '                                                                                                                        ',
#   'RINGNUM': 1,
#   'ROADTRL020': 997,
#   'RPOLY_': 0,
#   'SHAPENUM': 997,
#   'STATE': 'MI',
#   'STATE_FIPS': '26',
#   'TNODE_': 781},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 965,
#   'LENGTH': 0.197,
#   'LPOLY_': 0,
#   'NAME': 'US Route 3',
#   'RINGNUM': 1,
#   'ROADTRL020': 998,
#   'RPOLY_': 0,
#   'SHAPENUM': 998,
#   'STATE': 'NH',
#   'STATE_FIPS': '33',
#   'TNODE_': 885},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 965,
#   'LENGTH': 0.026,
#   'LPOLY_': 0,
#   'NAME': 'State Route 105',
#   'RINGNUM': 1,
#   'ROADTRL020': 999,
#   'RPOLY_': 0,
#   'SHAPENUM': 999,
#   'STATE': 'NH',
#   'STATE_FIPS': '33',
#   'TNODE_': 962},
#  {'FEATURE': 'Principal Highway',
#   'FNODE_': 966,
#   'LENGTH': 0.047,
#   'LPOLY_': 0,
#   'NAME': 'State Route 114',
#   'RINGNUM': 1,
#   'ROADTRL020': 1000,
#   'RPOLY_': 0,
#   'SHAPENUM': 1000,
#   'STATE': 'VT',
#   'STATE_FIPS': '50',
#   'TNODE_': 953},
#  ...]

# %%
unemp_list
# Out:
#                  fullcode       date  year period      value footnote_codes  \
# 0    LAUMT011150000000005 2017-09-01  2017    M09    43191.0              p
# 1    LAUMT011222000000005 2017-09-01  2017    M09    72274.0              p
# 2    LAUMT011382000000005 2017-09-01  2017    M09   515125.0              p
# 3    LAUMT011930000000005 2017-09-01  2017    M09    90064.0              p
# 4    LAUMT011946000000005 2017-09-01  2017    M09    66701.0              p
# 5    LAUMT012002000000005 2017-09-01  2017    M09    60627.0              p
# 6    LAUMT012252000000005 2017-09-01  2017    M09    63719.0              p
# 7    LAUMT012346000000005 2017-09-01  2017    M09    42394.0              p
# 8    LAUMT012662000000005 2017-09-01  2017    M09   210978.0              p
# 9    LAUMT013366000000005 2017-09-01  2017    M09   173676.0              p
# 10   LAUMT013386000000005 2017-09-01  2017    M09   163426.0              p
# 11   LAUMT014622000000005 2017-09-01  2017    M09   111305.0              p
# 12   LAUMT021126000000005 2017-09-01  2017    M09   190082.0              p
# 13   LAUMT022182000000005 2017-09-01  2017    M09    43929.0              p
# 14   LAUMT042238000000005 2017-09-01  2017    M09    74232.0              p
# 15   LAUMT042942000000005 2017-09-01  2017    M09    78150.0              p
# 16   LAUMT043806000000005 2017-09-01  2017    M09  2225271.0              p
# 17   LAUMT043914000000005 2017-09-01  2017    M09    98032.0              p
# 18   LAUMT044342000000005 2017-09-01  2017    M09    49507.0              p
# 19   LAUMT044606000000005 2017-09-01  2017    M09   458164.0              p
# 20   LAUMT044974000000005 2017-09-01  2017    M09    79646.0              p
# 21   LAUMT052222000000005 2017-09-01  2017    M09   270724.0              p
# 22   LAUMT052290000000005 2017-09-01  2017    M09   117905.0              p
# 23   LAUMT052630000000005 2017-09-01  2017    M09    39610.0              p
# 24   LAUMT052786000000005 2017-09-01  2017    M09    62551.0              p
# 25   LAUMT053078000000005 2017-09-01  2017    M09   347802.0              p
# 26   LAUMT053822000000005 2017-09-01  2017    M09    34362.0              p
# 27   LAUMT061254000000005 2017-09-01  2017    M09   360132.0              p
# 28   LAUMT061702000000005 2017-09-01  2017    M09    99383.0              p
# 29   LAUMT062094000000005 2017-09-01  2017    M09    58918.0              p
# ..                    ...        ...   ...    ...        ...            ...
# 361  LAUMT531474000000005 2017-09-01  2017    M09   114662.0              p
# 362  LAUMT532842000000005 2017-09-01  2017    M09   133034.0              p
# 363  LAUMT533102000000005 2017-09-01  2017    M09    43536.0              p
# 364  LAUMT533458000000005 2017-09-01  2017    M09    58162.0              p
# 365  LAUMT533650000000005 2017-09-01  2017    M09   129633.0              p
# 366  LAUMT534266000000005 2017-09-01  2017    M09  2004544.0              p
# 367  LAUMT534406000000005 2017-09-01  2017    M09   251745.0              p
# 368  LAUMT534746000000005 2017-09-01  2017    M09    30223.0              p
# 369  LAUMT534830000000005 2017-09-01  2017    M09    67029.0              p
# 370  LAUMT534942000000005 2017-09-01  2017    M09   130271.0              p
# 371  LAUMT541322000000005 2017-09-01  2017    M09    42649.0              p
# 372  LAUMT541662000000005 2017-09-01  2017    M09    92724.0              p
# 373  LAUMT542658000000005 2017-09-01  2017    M09   139978.0              p
# 374  LAUMT543406000000005 2017-09-01  2017    M09    65701.0              p
# 375  LAUMT543762000000005 2017-09-01  2017    M09    36554.0              p
# 376  LAUMT544854000000005 2017-09-01  2017    M09    60974.0              p
# 377  LAUMT551154000000005 2017-09-01  2017    M09   131437.0              p
# 378  LAUMT552074000000005 2017-09-01  2017    M09    89471.0              p
# 379  LAUMT552254000000005 2017-09-01  2017    M09    56841.0              p
# 380  LAUMT552458000000005 2017-09-01  2017    M09   169988.0              p
# 381  LAUMT552750000000005 2017-09-01  2017    M09    84028.0              p
# 382  LAUMT552910000000005 2017-09-01  2017    M09    77114.0              p
# 383  LAUMT553154000000005 2017-09-01  2017    M09   384389.0              p
# 384  LAUMT553334000000005 2017-09-01  2017    M09   807494.0              p
# 385  LAUMT553678000000005 2017-09-01  2017    M09    91814.0              p
# 386  LAUMT553954000000005 2017-09-01  2017    M09    96816.0              p
# 387  LAUMT554310000000005 2017-09-01  2017    M09    61339.0              p
# 388  LAUMT554814000000005 2017-09-01  2017    M09    73042.0              p
# 389  LAUMT561622000000005 2017-09-01  2017    M09    36840.0              p
# 390  LAUMT561694000000005 2017-09-01  2017    M09    45796.0              p
#
#     month  day  value_ch              fullname   latitude   longitude  \
# 0      09    1  0.016044          Anniston, AL  33.695381  -85.839842
# 1      09    1  0.036157            Auburn, AL  32.655091  -85.503643
# 2      09    1  0.022849        Birmingham, AL  33.520682  -86.802432
# 3      09    1  0.054305            Daphne, AL  30.571851  -87.855586
# 4      09    1  0.030895           Decatur, AL  34.624021  -87.057919
# 5      09    1  0.024382            Dothan, AL  31.223231  -85.390489
# 6      09    1  0.019015          Florence, AL  34.799810  -87.677251
# 7      09    1  0.035591           Gadsden, AL  34.014380  -86.006668
# 8      09    1  0.041095        Huntsville, AL  34.729847  -86.585901
# 9      09    1  0.012741            Mobile, AL  30.694357  -88.043054
# 10     09    1  0.016951        Montgomery, AL  32.366966  -86.300648
# 11     09    1  0.042846        Tuscaloosa, AL  33.266840  -87.486218
# 12     09    1  0.005597         Anchorage, AK  61.216313 -149.894852
# 13     09    1 -0.004487         Fairbanks, AK  64.837845 -147.716675
# 14     09    1  0.027361         Flagstaff, AZ  35.199458 -111.651426
# 15     09    1  0.036500  Lake Havasu City, AZ  34.474279 -114.344001
# 16     09    1  0.034097           Phoenix, AZ  33.448587 -112.077346
# 17     09    1  0.021827          Prescott, AZ  34.540281 -112.469507
# 18     09    1  0.049366      Sierra Vista, AZ  31.554540 -110.303693
# 19     09    1  0.011442            Tucson, AZ  32.221742 -110.926476
# 20     09    1  0.062258              Yuma, AZ  32.665135 -114.476031
# 21     09    1  0.045929      Fayetteville, AR  36.062584  -94.157433
# 22     09    1  0.015914        Fort Smith, AR  35.387222  -94.424898
# 23     09    1  0.038461       Hot Springs, AR  34.448065  -93.046850
# 24     09    1  0.032553         Jonesboro, AR  35.842865  -90.703452
# 25     09    1  0.029899       Little Rock, AR  34.746481  -92.289595
# 26     09    1  0.005913        Pine Bluff, AR  34.228431  -92.003195
# 27     09    1  0.014513       Bakersfield, CA  35.373871 -119.019464
# 28     09    1  0.019386             Chico, CA  39.728495 -121.837478
# 29     09    1  0.015933         El Centro, CA  32.792000 -115.563051
# ..    ...  ...       ...                   ...        ...         ...
# 361    09    1  0.045423         Bremerton, WA  47.532797 -122.754161
# 362    09    1  0.043216         Kennewick, WA  46.211246 -119.137234
# 363    09    1  0.049414          Longview, WA  46.142730 -122.955641
# 364    09    1  0.066234      Mount Vernon, WA  48.420046 -122.326420
# 365    09    1  0.051635           Olympia, WA  47.045020 -122.894872
# 366    09    1  0.027314           Seattle, WA  47.603832 -122.330062
# 367    09    1  0.048208           Spokane, WA  47.658860 -117.424713
# 368    09    1  0.044189       Walla Walla, WA  46.065000 -118.330278
# 369    09    1  0.045042         Wenatchee, WA  47.423460 -120.310349
# 370    09    1  0.039266            Yakima, WA  46.601557 -120.510842
# 371    09    1 -0.008624           Beckley, WV  37.778170  -81.188156
# 372    09    1  0.013277        Charleston, WV  38.350599  -81.633281
# 373    09    1  0.009258        Huntington, WV  38.419250  -82.445154
# 374    09    1  0.023683        Morgantown, WV  39.629681  -79.955944
# 375    09    1 -0.011653       Parkersburg, WV  39.269956  -81.550691
# 376    09    1  0.004382          Wheeling, WV  40.063962  -80.720915
# 377    09    1  0.033529          Appleton, WI  44.261134  -88.406760
# 378    09    1  0.002499        Eau Claire, WI  44.811349  -91.498494
# 379    09    1  0.019259       Fond du Lac, WI  43.774876  -88.445803
# 380    09    1  0.016182         Green Bay, WI  44.529941  -88.024832
# 381    09    1  0.043191        Janesville, WI  42.715185  -88.990774
# 382    09    1  0.025438         La Crosse, WI  43.801356  -91.239581
# 383    09    1  0.028639           Madison, WI  43.074761  -89.383761
# 384    09    1  0.018268         Milwaukee, WI  43.034993  -87.922497
# 385    09    1  0.020711           Oshkosh, WI  44.020692  -88.540857
# 386    09    1  0.021729            Racine, WI  42.726052  -87.782524
# 387    09    1  0.013416         Sheboygan, WI  43.750828  -87.714530
# 388    09    1  0.021781            Wausau, WI  44.959602  -89.629824
# 389    09    1 -0.021436            Casper, WY  42.866632 -106.313081
# 390    09    1 -0.011590          Cheyenne, WY  41.139981 -104.820246
#
#                                              area_code             x  \
# 0    Anniston-Oxford-Jacksonville, AL Metropolitan ...  3.652728e+06
# 1     Auburn-Opelika, AL Metropolitan Statistical Area  3.695694e+06
# 2    Birmingham-Hoover, AL Metropolitan Statistical...  3.565934e+06
# 3    Daphne-Fairhope-Foley, AL Metropolitan Statist...  3.494541e+06
# 4            Decatur, AL Metropolitan Statistical Area  3.531674e+06
# 5             Dothan, AL Metropolitan Statistical Area  3.723075e+06
# 6    Florence-Muscle Shoals, AL Metropolitan Statis...  3.473777e+06
# 7            Gadsden, AL Metropolitan Statistical Area  3.633890e+06
# 8         Huntsville, AL Metropolitan Statistical Area  3.573496e+06
# 9             Mobile, AL Metropolitan Statistical Area  3.475507e+06
# 10        Montgomery, AL Metropolitan Statistical Area  3.624471e+06
# 11        Tuscaloosa, AL Metropolitan Statistical Area  3.505168e+06
# 12         Anchorage, AK Metropolitan Statistical Area -1.931577e+05
# 13         Fairbanks, AK Metropolitan Statistical Area  1.558279e+05
# 14         Flagstaff, AZ Metropolitan Statistical Area  1.308028e+06
# 15   Lake Havasu City-Kingman, AZ Metropolitan Stat...  1.051952e+06
# 16   Phoenix-Mesa-Scottsdale, AZ Metropolitan Stati...  1.233820e+06
# 17          Prescott, AZ Metropolitan Statistical Area  1.221273e+06
# 18   Sierra Vista-Douglas, AZ Metropolitan Statisti...  1.360312e+06
# 19            Tucson, AZ Metropolitan Statistical Area  1.314966e+06
# 20              Yuma, AZ Metropolitan Statistical Area  9.974077e+05
# 21   Fayetteville-Springdale-Rogers, AR-MO Metropol...  2.883135e+06
# 22     Fort Smith, AR-OK Metropolitan Statistical Area  2.859666e+06
# 23       Hot Springs, AR Metropolitan Statistical Area  2.986384e+06
# 24         Jonesboro, AR Metropolitan Statistical Area  3.193333e+06
# 25   Little Rock-North Little Rock-Conway, AR Metro...  3.054653e+06
# 26        Pine Bluff, AR Metropolitan Statistical Area  3.082632e+06
# 27       Bakersfield, CA Metropolitan Statistical Area  6.625754e+05
# 28             Chico, CA Metropolitan Statistical Area  5.580991e+05
# 29         El Centro, CA Metropolitan Statistical Area  9.012187e+05
# ..                                                 ...           ...
# 361  Bremerton-Silverdale, WA Metropolitan Statisti...  7.441762e+05
# 362  Kennewick-Richland, WA Metropolitan Statistica...  9.675144e+05
# 363         Longview, WA Metropolitan Statistical Area  6.826762e+05
# 364  Mount Vernon-Anacortes, WA Metropolitan Statis...  8.044380e+05
# 365  Olympia-Tumwater, WA Metropolitan Statistical ...  7.175696e+05
# 366  Seattle-Tacoma-Bellevue, WA Metropolitan Stati...  7.770979e+05
# 367  Spokane-Spokane Valley, WA Metropolitan Statis...  1.134799e+06
# 368      Walla Walla, WA Metropolitan Statistical Area  1.023515e+06
# 369        Wenatchee, WA Metropolitan Statistical Area  9.175534e+05
# 370           Yakima, WA Metropolitan Statistical Area  8.775404e+05
# 371          Beckley, WV Metropolitan Statistical Area  4.010609e+06
# 372       Charleston, WV Metropolitan Statistical Area  3.962848e+06
# 373  Huntington-Ashland, WV-KY-OH Metropolitan Stat...  3.892103e+06
# 374       Morgantown, WV Metropolitan Statistical Area  4.083241e+06
# 375  Parkersburg-Vienna, WV Metropolitan Statistica...  3.954942e+06
# 376      Wheeling, WV-OH Metropolitan Statistical Area  4.011415e+06
# 377         Appleton, WI Metropolitan Statistical Area  3.331613e+06
# 378       Eau Claire, WI Metropolitan Statistical Area  3.083763e+06
# 379      Fond du Lac, WI Metropolitan Statistical Area  3.332406e+06
# 380        Green Bay, WI Metropolitan Statistical Area  3.359614e+06
# 381  Janesville-Beloit, WI Metropolitan Statistical...  3.296609e+06
# 382  La Crosse-Onalaska, WI-MN Metropolitan Statist...  3.108804e+06
# 383          Madison, WI Metropolitan Statistical Area  3.262217e+06
# 384  Milwaukee-Waukesha-West Allis, WI Metropolitan...  3.380601e+06
# 385   Oshkosh-Neenah, WI Metropolitan Statistical Area  3.322872e+06
# 386           Racine, WI Metropolitan Statistical Area  3.394625e+06
# 387        Sheboygan, WI Metropolitan Statistical Area  3.391042e+06
# 388           Wausau, WI Metropolitan Statistical Area  3.229970e+06
# 389           Casper, WY Metropolitan Statistical Area  1.891095e+06
# 390         Cheyenne, WY Metropolitan Statistical Area  1.990920e+06
#
#                 y      color       size
# 0    1.189556e+06  Limegreen   6.417465
# 1    1.077729e+06  Limegreen  14.462668
# 2    1.161748e+06  Limegreen   9.139467
# 3    8.260081e+05  Limegreen  21.721978
# 4    1.281654e+06  Limegreen  12.358196
# 5    9.201860e+05  Limegreen   9.752636
# 6    1.296345e+06  Limegreen   7.605949
# 7    1.223266e+06  Limegreen  14.236510
# 8    1.297213e+06  Limegreen  16.438194
# 9    8.382602e+05  Limegreen   5.096477
# 10   1.038347e+06  Limegreen   6.780252
# 11   1.128169e+06  Limegreen  17.138253
# 12   5.196061e+06  Limegreen   2.238869
# 13   5.497603e+06        Red   1.794819
# 14   1.451580e+06  Limegreen  10.944571
# 15   1.420963e+06  Limegreen  14.599857
# 16   1.267834e+06  Limegreen  13.638751
# 17   1.393665e+06  Limegreen   8.730639
# 18   1.030865e+06  Limegreen  19.746492
# 19   1.114195e+06  Limegreen   4.576792
# 20   1.227140e+06  Limegreen  24.903305
# 21   1.409771e+06  Limegreen  18.371478
# 22   1.334774e+06  Limegreen   6.365783
# 23   1.232401e+06  Limegreen  15.384212
# 24   1.394205e+06  Limegreen  13.021014
# 25   1.267264e+06  Limegreen  11.959550
# 26   1.210644e+06  Limegreen   2.365340
# 27   1.618280e+06  Limegreen   5.805397
# 28   2.149582e+06  Limegreen   7.754403
# 29   1.263143e+06  Limegreen   6.373073
# ..            ...        ...        ...
# 361  2.999104e+06  Limegreen  18.169220
# 362  2.779791e+06  Limegreen  17.286293
# 363  2.855780e+06  Limegreen  19.765704
# 364  3.084372e+06  Limegreen  26.493611
# 365  2.950332e+06  Limegreen  20.654184
# 366  2.997135e+06  Limegreen  10.925731
# 367  2.903085e+06  Limegreen  19.283249
# 368  2.747951e+06  Limegreen  17.675511
# 369  2.934229e+06  Limegreen  18.016838
# 370  2.850204e+06  Limegreen  15.706547
# 371  1.690868e+06        Red   3.449558
# 372  1.747699e+06  Limegreen   5.310953
# 373  1.745211e+06  Limegreen   3.703116
# 374  1.909864e+06  Limegreen   9.473209
# 375  1.849310e+06        Red   4.661349
# 376  1.946835e+06  Limegreen   1.752652
# 377  2.336022e+06  Limegreen  13.411652
# 378  2.383457e+06  Limegreen   0.999462
# 379  2.281960e+06  Limegreen   7.703481
# 380  2.368057e+06  Limegreen   6.472941
# 381  2.161697e+06  Limegreen  17.276440
# 382  2.272199e+06  Limegreen  10.175397
# 383  2.199429e+06  Limegreen  11.455576
# 384  2.203291e+06  Limegreen   7.307376
# 385  2.308628e+06  Limegreen   8.284510
# 386  2.170050e+06  Limegreen   8.691706
# 387  2.283757e+06  Limegreen   5.366200
# 388  2.407100e+06  Limegreen   8.712317
# 389  2.219438e+06        Red   8.574388
# 390  2.015284e+06        Red   4.636005
#
# [391 rows x 17 columns]
